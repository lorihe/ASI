# %%
from mplsoccer.pitch import Pitch
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import os
import json
import jsonlines
from skillcorner.client import SkillcornerClient
import pyarrow.parquet as pq

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
load_dotenv()
username = os.getenv('U')
password = os.getenv('P')
client = SkillcornerClient(username=username, password=password)

# %%
def load_json_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# %%
def load_jsonl_file(file_path):
    with jsonlines.open(file_path, 'r') as file:
        data = [line for line in file if line['timestamp'] is not None]
    return data

# %%
FA_matches = client.get_matches(params={'competition_edition': 574})
FA_match_ids = [m['id'] for m in FA_matches]

# %%
# Inspect the schema of the Parquet file
file_path = 'data/wyscout_events.parquet'
events_df = pd.read_parquet(file_path)

# %%
event_match_ids = list(set(events_df.sk_match_id))

# %%
FA_in_event = [i for i in FA_match_ids if i in event_match_ids]
len(FA_in_event)
# Out:
# 102

# %%
cols = ['frame', 'minute', 'player_name', 'pass_recipient_name', 'pass_recipient_id',
       'pass_recipient_position', 'sk_player_id', 'pass_angle','type_primary', 'type_secondary', 'location_x', 'location_y', 'pass_accurate',
       'pass_endlocation_x', 'pass_endlocation_y', 'player_position', 'sk_match_id', 
       'possession_team_name', 'possession_types']

# %%
FA_match_ids = FA_in_event

# %%
events_df = events_df[events_df['sk_match_id'].isin(FA_match_ids)][cols]

# %%
events_df.head()
# Out:
#         frame  minute    player_name pass_recipient_name  pass_recipient_id  \
# 106932    107       0        H. Ladd            K. Zelem             134338
# 106933    126       0       K. Zelem           G. George             289914
# 106934    158       0      G. George           M. Turner             258929
# 106935    191       0      M. Turner       M. Le Tissier             559233
# 106936    222       0  M. Le Tissier           M. Turner             258929
#
#        pass_recipient_position  sk_player_id  pass_angle type_primary  \
# 106932                     DMF         64166        -153         pass
# 106933                      LB         68743        -104         pass
# 106934                     LCB         68681         104         pass
# 106935                     RCB         63767          93         pass
# 106936                     LCB         68697         -88         pass
#
#                               type_secondary  location_x  location_y  \
# 106932     [back_pass, short_or_medium_pass]          51          50
# 106933  [lateral_pass, short_or_medium_pass]          38          40
# 106934  [lateral_pass, short_or_medium_pass]          33          10
# 106935  [lateral_pass, short_or_medium_pass]          29          39
# 106936  [lateral_pass, short_or_medium_pass]          28          70
#
#         pass_accurate  pass_endlocation_x  pass_endlocation_y player_position  \
# 106932           True                  38                  40            RCMF
# 106933           True                  33                  10             DMF
# 106934           True                  29                  39              LB
# 106935           True                  28                  70             LCB
# 106936           True                  29                  37             RCB
#
#         sk_match_id  possession_id  possession_team_id possession_team_name  \
# 106932      1133203     1783543568               63195    Manchester United
# 106933      1133203     1783543568               63195    Manchester United
# 106934      1133203     1783543568               63195    Manchester United
# 106935      1133203     1783543568               63195    Manchester United
# 106936      1133203     1783543568               63195    Manchester United
#
#        possession_types
# 106932             None
# 106933             None
# 106934             None
# 106935             None
# 106936             None

# %%
match_id = 1133203

# %%
match_data = load_json_file(rf'data/FA/match/{match_id}.json')

# %%
match_data
# Out:
# {'id': 1133203,
#  'home_team_score': 1,
#  'away_team_score': 2,
#  'date_time': '2023-10-01T11:30:00Z',
#  'stadium': {'id': 488,
#   'name': 'Villa Park',
#   'city': 'Birmingham',
#   'capacity': 42682},
#  'home_team': {'id': 2029,
#   'name': 'Aston Villa, Women',
#   'short_name': 'Aston Villa',
#   'acronym': 'AVL'},
#  'home_team_kit': {'id': 5450,
#   'team_id': 2029,
#   'season': {'id': 6,
#    'start_year': 2019,
#    'end_year': 2020,
#    'name': '2019/2020'},
#   'name': 'Home',
#   'jersey_color': '#a50521',
#   'number_color': '#ffffff'},
#  'away_team': {'id': 2027,
#   'name': 'Manchester United, Women',
#   'short_name': 'Man Utd, W',
#   'acronym': 'MUN'},
#  'away_team_kit': {'id': 6537,
#   'team_id': 2027,
#   'season': {'id': 8,
#    'start_year': 2021,
#    'end_year': 2022,
#    'name': '2021/2022'},
#   'name': 'Away',
#   'jersey_color': '#ffffff',
#   'number_color': '#ff0000'},
#  'home_team_coach': None,
#  'away_team_coach': None,
#  'competition_edition': {'id': 574,
#   'competition': {'id': 127,
#    'area': 'ENG',
#    'name': 'FA Women`s Super League',
#    'gender': 'female',
#    'age_group': 'adult'},
#   'season': {'id': 28,
#    'start_year': 2023,
#    'end_year': 2024,
#    'name': '2023/2024'},
#   'name': 'ENG - FA Women`s Super League - 2023/2024'},
#  'competition_round': {'id': 1885,
#   'name': 'Round 1',
#   'round_number': 1,
#   'potential_overtime': False},
#  'referees': [],
#  'players': [{'player_role': {'id': 7,
#     'position_group': 'Midfield',
#     'name': 'Defensive Midfield',
#     'acronym': 'DM'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 10,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102120,
#    'team_id': 2027,
#    'id': 68743,
#    'first_name': 'Katie',
#    'last_name': 'Zelem',
#    'short_name': 'K. Zelem',
#    'birthday': '1996-01-20',
#    'trackable_object': 69869,
#    'gender': 'female'},
#   {'player_role': {'id': 19,
#     'position_group': 'Full Back',
#     'name': 'Left Back',
#     'acronym': 'LB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 14,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 375202,
#    'team_id': 2029,
#    'id': 68680,
#    'first_name': 'Danielle',
#    'last_name': 'Turner',
#    'short_name': 'D. Turner',
#    'birthday': '1991-09-10',
#    'trackable_object': 69806,
#    'gender': 'female'},
#   {'player_role': {'id': 4,
#     'position_group': 'Central Defender',
#     'name': 'Right Center Back',
#     'acronym': 'RCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 4,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 198947,
#    'team_id': 2029,
#    'id': 68719,
#    'first_name': 'Anna',
#    'last_name': 'Patten',
#    'short_name': 'A. Patten',
#    'birthday': '1999-04-20',
#    'trackable_object': 69845,
#    'gender': 'female'},
#   {'player_role': {'id': 22,
#     'position_group': 'Midfield',
#     'name': 'Right Defensive Midfield',
#     'acronym': 'RDM'},
#    'start_time': '00:00:00',
#    'end_time': '01:34:58',
#    'number': 15,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153050,
#    'team_id': 2029,
#    'id': 68661,
#    'first_name': 'Lucy',
#    'last_name': 'Parker',
#    'short_name': 'L. Parker',
#    'birthday': '1998-11-18',
#    'trackable_object': 69787,
#    'gender': 'female'},
#   {'player_role': {'id': 11,
#     'position_group': 'Midfield',
#     'name': 'Attacking Midfield',
#     'acronym': 'AM'},
#    'start_time': '00:45:00',
#    'end_time': None,
#    'number': 17,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153052,
#    'team_id': 2029,
#    'id': 62646,
#    'first_name': 'Ebony',
#    'last_name': 'Salmon',
#    'short_name': 'E. Salmon',
#    'birthday': '2001-01-27',
#    'trackable_object': 63772,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '01:10:17',
#    'end_time': None,
#    'number': 22,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 401798,
#    'team_id': 2027,
#    'id': 22608,
#    'first_name': 'Nikita',
#    'last_name': 'Parris',
#    'short_name': 'N. Parris',
#    'birthday': '1994-03-10',
#    'trackable_object': 23166,
#    'gender': 'female'},
#   {'player_role': {'id': 4,
#     'position_group': 'Central Defender',
#     'name': 'Right Center Back',
#     'acronym': 'RCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 4,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 401795,
#    'team_id': 2027,
#    'id': 68697,
#    'first_name': 'Maya',
#    'last_name': 'Le Tissier',
#    'short_name': 'M. Le Tissier',
#    'birthday': '2002-04-18',
#    'trackable_object': 69823,
#    'gender': 'female'},
#   {'player_role': {'id': 9,
#     'position_group': 'Midfield',
#     'name': 'Left Midfield',
#     'acronym': 'LM'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 7,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101950,
#    'team_id': 2027,
#    'id': 62411,
#    'first_name': 'Ella',
#    'last_name': 'Toone',
#    'short_name': 'E. Toone',
#    'birthday': '1999-09-02',
#    'trackable_object': 63537,
#    'gender': 'female'},
#   {'player_role': {'id': 3,
#     'position_group': 'Central Defender',
#     'name': 'Left Center Back',
#     'acronym': 'LCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 21,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102129,
#    'team_id': 2027,
#    'id': 63767,
#    'first_name': 'Millie',
#    'last_name': 'Turner',
#    'short_name': 'M. Turner',
#    'birthday': '1996-07-07',
#    'trackable_object': 64893,
#    'gender': 'female'},
#   {'player_role': {'id': 12,
#     'position_group': 'Wide Attacker',
#     'name': 'Left Winger',
#     'acronym': 'LW'},
#    'start_time': '00:00:00',
#    'end_time': '01:14:20',
#    'number': 20,
#    'yellow_card': 0,
#    'red_card': 1,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 375204,
#    'team_id': 2029,
#    'id': 64066,
#    'first_name': 'Kirsty',
#    'last_name': 'Hanson',
#    'short_name': 'K. Hanson',
#    'birthday': '1998-04-17',
#    'trackable_object': 65192,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '01:05:53',
#    'end_time': None,
#    'number': 23,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153051,
#    'team_id': 2029,
#    'id': 22735,
#    'first_name': 'Adriana',
#    'last_name': 'Leon',
#    'short_name': 'A. Leon',
#    'birthday': '1992-10-02',
#    'trackable_object': 23420,
#    'gender': 'female'},
#   {'player_role': {'id': 10,
#     'position_group': 'Midfield',
#     'name': 'Right Midfield',
#     'acronym': 'RM'},
#    'start_time': '01:19:57',
#    'end_time': None,
#    'number': 20,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153059,
#    'team_id': 2027,
#    'id': 62505,
#    'first_name': 'Hinata',
#    'last_name': 'Miyazawa',
#    'short_name': 'H. Miyazawa',
#    'birthday': '1999-11-28',
#    'trackable_object': 63631,
#    'gender': 'female'},
#   {'player_role': {'id': 21,
#     'position_group': 'Midfield',
#     'name': 'Left Defensive Midfield',
#     'acronym': 'LDM'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 5,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 758945,
#    'team_id': 2029,
#    'id': 22624,
#    'first_name': 'Lucy',
#    'last_name': 'Staniforth',
#    'short_name': 'L. Staniforth',
#    'birthday': '1992-10-02',
#    'trackable_object': 23198,
#    'gender': 'female'},
#   {'player_role': {'id': 22,
#     'position_group': 'Midfield',
#     'name': 'Right Defensive Midfield',
#     'acronym': 'RDM'},
#    'start_time': '01:34:58',
#    'end_time': None,
#    'number': 8,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 758944,
#    'team_id': 2029,
#    'id': 63765,
#    'first_name': 'Jordan',
#    'last_name': 'Nobbs',
#    'short_name': 'J. Nobbs',
#    'birthday': '1992-12-08',
#    'trackable_object': 64891,
#    'gender': 'female'},
#   {'player_role': {'id': 19,
#     'position_group': 'Full Back',
#     'name': 'Left Back',
#     'acronym': 'LB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 3,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153054,
#    'team_id': 2027,
#    'id': 68681,
#    'first_name': 'Gabrielle',
#    'last_name': 'George',
#    'short_name': 'G. George',
#    'birthday': '1997-02-02',
#    'trackable_object': 69807,
#    'gender': 'female'},
#   {'player_role': {'id': 20,
#     'position_group': 'Full Back',
#     'name': 'Right Back',
#     'acronym': 'RB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 2,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101991,
#    'team_id': 2029,
#    'id': 68672,
#    'first_name': 'Sarah Emma',
#    'last_name': 'Mayling',
#    'short_name': 'S. Mayling',
#    'birthday': '1997-03-20',
#    'trackable_object': 69798,
#    'gender': 'female'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 9,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 375205,
#    'team_id': 2029,
#    'id': 22618,
#    'first_name': 'Rachel',
#    'last_name': 'Daly',
#    'short_name': 'R. Daly',
#    'birthday': '1991-12-06',
#    'trackable_object': 23186,
#    'gender': 'female'},
#   {'player_role': {'id': 3,
#     'position_group': 'Central Defender',
#     'name': 'Left Center Back',
#     'acronym': 'LCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 6,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 198911,
#    'team_id': 2029,
#    'id': 22628,
#    'first_name': 'Rachel',
#    'last_name': 'Corsie',
#    'short_name': 'R. Corsie',
#    'birthday': '1989-08-17',
#    'trackable_object': 23206,
#    'gender': 'female'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '01:05:44',
#    'end_time': None,
#    'number': 28,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 485472,
#    'team_id': 2027,
#    'id': 68734,
#    'first_name': 'Rachel',
#    'last_name': 'Williams',
#    'short_name': 'R. Williams',
#    'birthday': '1988-01-10',
#    'trackable_object': 69860,
#    'gender': 'female'},
#   {'player_role': {'id': 12,
#     'position_group': 'Wide Attacker',
#     'name': 'Left Winger',
#     'acronym': 'LW'},
#    'start_time': '00:00:00',
#    'end_time': '01:10:17',
#    'number': 11,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102121,
#    'team_id': 2027,
#    'id': 68744,
#    'first_name': 'Leah',
#    'last_name': 'Galton',
#    'short_name': 'L. Galton',
#    'birthday': '1994-05-24',
#    'trackable_object': 69870,
#    'gender': 'female'},
#   {'player_role': {'id': 20,
#     'position_group': 'Full Back',
#     'name': 'Right Back',
#     'acronym': 'RB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 6,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101954,
#    'team_id': 2027,
#    'id': 57096,
#    'first_name': 'Hannah',
#    'last_name': 'Blundell',
#    'short_name': 'H. Blundell',
#    'birthday': '1994-05-25',
#    'trackable_object': 58222,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 91,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153058,
#    'team_id': 2027,
#    'id': 151604,
#    'first_name': 'Phallon',
#    'last_name': 'Tullis-Joyce',
#    'short_name': 'P. Tullis-Joyce',
#    'birthday': '1996-10-19',
#    'trackable_object': 153159,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 16,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 854887,
#    'team_id': 2027,
#    'id': 63932,
#    'first_name': 'Lisa Fjeldstad',
#    'last_name': 'Naalsund',
#    'short_name': 'L. Naalsund',
#    'birthday': '1995-06-11',
#    'trackable_object': 65058,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 14,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 897627,
#    'team_id': 2027,
#    'id': 22724,
#    'first_name': 'Jayde Yuk Fun',
#    'last_name': 'Riviere',
#    'short_name': 'J. Riviere',
#    'birthday': '2001-01-22',
#    'trackable_object': 23398,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 8,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153057,
#    'team_id': 2027,
#    'id': 68199,
#    'first_name': 'Irene ',
#    'last_name': 'Guerrero Sanmartín',
#    'short_name': 'Irene Guerrero',
#    'birthday': '1996-12-12',
#    'trackable_object': 69325,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 15,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153056,
#    'team_id': 2027,
#    'id': 64156,
#    'first_name': 'Gemma Jayne',
#    'last_name': 'Evans',
#    'short_name': 'G. Evans',
#    'birthday': '1996-08-01',
#    'trackable_object': 65282,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 25,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153055,
#    'team_id': 2027,
#    'id': 153392,
#    'first_name': 'Evie',
#    'last_name': 'Rabjohn',
#    'short_name': 'E. Rabjohn',
#    'birthday': '2005-04-28',
#    'trackable_object': 154947,
#    'gender': 'female'},
#   {'player_role': {'id': 0,
#     'position_group': 'Other',
#     'name': 'Goalkeeper',
#     'acronym': 'GK'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 27,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102122,
#    'team_id': 2027,
#    'id': 22622,
#    'first_name': 'Mary',
#    'last_name': 'Earps',
#    'short_name': 'M. Earps',
#    'birthday': '1993-03-07',
#    'trackable_object': 23194,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 17,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 401794,
#    'team_id': 2027,
#    'id': 22457,
#    'first_name': 'Lucía',
#    'last_name': 'García Córdoba',
#    'short_name': 'Lucía García',
#    'birthday': '1998-07-14',
#    'trackable_object': 22864,
#    'gender': 'female'},
#   {'player_role': {'id': 10,
#     'position_group': 'Midfield',
#     'name': 'Right Midfield',
#     'acronym': 'RM'},
#    'start_time': '00:00:00',
#    'end_time': '01:19:57',
#    'number': 12,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102126,
#    'team_id': 2027,
#    'id': 64166,
#    'first_name': 'Hayley',
#    'last_name': 'Ladd',
#    'short_name': 'H. Ladd',
#    'birthday': '1993-10-06',
#    'trackable_object': 65292,
#    'gender': 'female'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '00:00:00',
#    'end_time': '01:05:44',
#    'number': 23,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153053,
#    'team_id': 2027,
#    'id': 22555,
#    'first_name': '',
#    'last_name': 'Geyse',
#    'short_name': 'Geyse',
#    'birthday': '1998-03-27',
#    'trackable_object': 23060,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 22,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 946461,
#    'team_id': 2029,
#    'id': 62772,
#    'first_name': 'Simone',
#    'last_name': 'Magill',
#    'short_name': 'S. Magill',
#    'birthday': '1994-11-01',
#    'trackable_object': 63898,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 16,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102138,
#    'team_id': 2029,
#    'id': 68749,
#    'first_name': 'Olivia',
#    'last_name': 'McLoughlin',
#    'short_name': 'O. McLoughlin',
#    'birthday': '2004-10-15',
#    'trackable_object': 69875,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 33,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101989,
#    'team_id': 2029,
#    'id': 68670,
#    'first_name': 'Mayumi',
#    'last_name': 'Pacheco',
#    'short_name': 'M. Pacheco',
#    'birthday': '1998-08-25',
#    'trackable_object': 69796,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 18,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 644248,
#    'team_id': 2029,
#    'id': 424697,
#    'first_name': 'Georgia',
#    'last_name': 'Mullett',
#    'short_name': 'G. Mullett',
#    'birthday': '2005-09-16',
#    'trackable_object': 426254,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 21,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 375206,
#    'team_id': 2029,
#    'id': 59723,
#    'first_name': 'Anna Jessica',
#    'last_name': 'Leat',
#    'short_name': 'A. Leat',
#    'birthday': '2001-06-26',
#    'trackable_object': 60849,
#    'gender': 'female'},
#   {'player_role': {'id': 0,
#     'position_group': 'Other',
#     'name': 'Goalkeeper',
#     'acronym': 'GK'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 1,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153049,
#    'team_id': 2029,
#    'id': 63552,
#    'first_name': 'Daphne',
#    'last_name': 'van Domselaar',
#    'short_name': 'D. van Domselaar',
#    'birthday': '2000-03-06',
#    'trackable_object': 64678,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '00:00:00',
#    'end_time': '01:05:53',
#    'number': 7,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101982,
#    'team_id': 2029,
#    'id': 64130,
#    'first_name': 'Alisha',
#    'last_name': 'Lehmann',
#    'short_name': 'A. Lehmann',
#    'birthday': '1999-01-21',
#    'trackable_object': 65256,
#    'gender': 'female'},
#   {'player_role': {'id': 11,
#     'position_group': 'Midfield',
#     'name': 'Attacking Midfield',
#     'acronym': 'AM'},
#    'start_time': '00:00:00',
#    'end_time': '00:45:00',
#    'number': 19,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101994,
#    'team_id': 2029,
#    'id': 68675,
#    'first_name': 'Laura Madison',
#    'last_name': 'Blindkilde Brown',
#    'short_name': 'L. Blindkilde Brown',
#    'birthday': '2003-09-09',
#    'trackable_object': 69801,
#    'gender': 'female'}],
#  'status': 'closed',
#  'home_team_side': ['left_to_right', 'right_to_left'],
#  'ball': {'trackable_object': 55},
#  'pitch_length': 105,
#  'pitch_width': 68}

# %%
home_id = match_data['home_team']['id']
away_id = match_data['away_team']['id']

# %%
home_p_ids = [p['id'] for p in match_data['players'] if p['team_id'] == home_id]
away_p_ids = [p['id'] for p in match_data['players'] if p['team_id'] == away_id]

# %%
match_event_df = events_df[(events_df['sk_match_id'] == match_id) & (events_df['type_primary'] == 'pass')].reset_index(drop = True)

# %%
# field_length = 105
# field_width = 68

# # Adjust coordinates to center [0, 0]
# match_event_df['pass_endlocation_x'] =  match_event_df['pass_endlocation_x'] * field_length / 100 - field_length / 2
# match_event_df['pass_endlocation_y'] =  field_width / 2 - match_event_df['pass_endlocation_y'] * field_width / 100

# match_event_df['location_x'] =  match_event_df['location_x'] * field_length / 100 - field_length / 2
# match_event_df['location_y'] =  field_width / 2 - match_event_df['location_y'] * field_width / 100

# %%
match_event_df.head()
# Out:
#    frame  minute    player_name pass_recipient_name  pass_recipient_id  \
# 0    107       0        H. Ladd            K. Zelem             134338
# 1    126       0       K. Zelem           G. George             289914
# 2    158       0      G. George           M. Turner             258929
# 3    191       0      M. Turner       M. Le Tissier             559233
# 4    222       0  M. Le Tissier           M. Turner             258929
#
#   pass_recipient_position  sk_player_id  pass_angle type_primary  \
# 0                     DMF         64166        -153         pass
# 1                      LB         68743        -104         pass
# 2                     LCB         68681         104         pass
# 3                     RCB         63767          93         pass
# 4                     LCB         68697         -88         pass
#
#                          type_secondary  location_x  location_y  \
# 0     [back_pass, short_or_medium_pass]          51          50
# 1  [lateral_pass, short_or_medium_pass]          38          40
# 2  [lateral_pass, short_or_medium_pass]          33          10
# 3  [lateral_pass, short_or_medium_pass]          29          39
# 4  [lateral_pass, short_or_medium_pass]          28          70
#
#    pass_accurate  pass_endlocation_x  pass_endlocation_y player_position  \
# 0           True                  38                  40            RCMF
# 1           True                  33                  10             DMF
# 2           True                  29                  39              LB
# 3           True                  28                  70             LCB
# 4           True                  29                  37             RCB
#
#    sk_match_id
# 0      1133203
# 1      1133203
# 2      1133203
# 3      1133203
# 4      1133203

# %%
match_event_df['team'] = match_event_df['sk_player_id'].apply(lambda x: 'home' if x in home_p_ids else
                                                                  'away' if x in away_p_ids else None)

# %%
tracking_path = f'data/FA/tracking/{match_id}.jsonl'

# %%
with jsonlines.open(tracking_path, 'r') as file:
    frame_to_period = {line['frame']: line['period'] for line in file}

# Map the period to each row using the pre-built dictionary
match_event_df['period'] = match_event_df['frame'].map(frame_to_period)

# %%
# wt_json =[p for p in match_info['players'] if p['player_role']['position_group'] == 'Wide Attacker']

# %%
# wt_info = [p['first_name']+ ' '+ p['last_name'] for p in wt_json]

# %%
# wt_ids = [p['id'] for p in wt_json]
# wt_ids

# %% [markdown]
# Box length = 40.3, width = 16.5
# L = 103.125, W = 65

# %%
W = 68
L = 105

# %%
((W - 40.3)/2)/W
# Out:
# 0.20367647058823532

# %%
(40.3/2+W/2)/W
# Out:
# 0.7963235294117647

# %%
match_event_df['in_wide_channel'] = match_event_df.apply(
    lambda row: True if row['pass_endlocation_x'] >= 66 and (row['pass_endlocation_y'] > 81 or row['pass_endlocation_y'] < 19) and row['pass_recipient_id'] != 0 else False, axis = 1)

# %%
match_event_df.in_wide_channel.value_counts()
# Out:
# in_wide_channel
# False    677
# True      98
# Name: count, dtype: int64

# %%
result_df.columns
# Out:
# Index(['frame', 'minute', 'player_name', 'pass_recipient_name',
#        'pass_recipient_id', 'pass_recipient_position', 'sk_player_id',
#        'pass_angle', 'type_primary', 'type_secondary', 'location_x',
#        'location_y', 'pass_accurate', 'pass_endlocation_x',
#        'pass_endlocation_y', 'player_position', 'sk_match_id', 'team',
#        'period', 'in_wide_channel'],
#       dtype='object')

# %%
W*0.82-W/2, L*0.72-L/2
# Out:
# (21.759999999999998, 23.099999999999994)

# %%
true_indices = match_event_df[match_event_df['in_wide_channel'] == True].index
all_indices = true_indices.tolist() + (true_indices + 1).tolist()
all_indices = list(set(all_indices))
all_indices = [idx for idx in all_indices if idx < len(match_event_df)]
result_df = match_event_df.loc[all_indices]
result_df = result_df.sort_index()
result_df[['frame', 'minute', 'player_name', 'pass_recipient_name','location_x','location_y',
    'pass_endlocation_x', 'pass_endlocation_y']]
# Out:
#      frame  minute          player_name  pass_recipient_name  location_x  \
# 26    1199       1            G. George           S. Mayling          35
# 27    1245       1            L. Galton             E. Toone          71
# 28    1274       1             E. Toone            L. Galton          77
# 29    1297       1            L. Galton              R. Daly          93
# 68    4214       6            L. Galton            G. George          70
# 69    4249       6            G. George            L. Galton          77
# 70    4265       6            L. Galton             K. Zelem          69
# 77    4453       7            L. Galton             E. Toone          65
# 78    4545       7             E. Toone             K. Zelem          95
# 108   6514      10             K. Zelem            L. Galton          65
# 109   6527      10            L. Galton             E. Toone          68
# 111   6784      11              R. Daly  L. Blindkilde Brown          36
# 112   6981      11        M. Le Tissier            M. Turner          25
# 130   7810      12             E. Toone            L. Galton          62
# 131   7839      12            L. Galton             E. Toone          64
# 147  10346      17            D. Turner            K. Hanson          60
# 148  10369      17            K. Hanson  L. Blindkilde Brown          70
# 149  10387      17  L. Blindkilde Brown        M. Le Tissier          74
# 164  10983      18          H. Blundell              H. Ladd          74
# 165  11001      18              H. Ladd             K. Zelem          72
# 166  11013      18             K. Zelem              H. Ladd          70
# 167  11030      18              H. Ladd            M. Turner          66
# 174  11222      18            M. Turner             K. Zelem          59
# 175  11270      18             K. Zelem            L. Galton          70
# 176  11289      18            L. Galton            G. George          75
# 177  11317      18            G. George             E. Toone          79
# 178  11369      18             E. Toone            G. George          82
# 179  11408      18            G. George       Geyse Ferreira          97
# 180  11484      18       Geyse Ferreira                 <NA>          88
# 181  11552      19             E. Toone            G. George          94
# 182  11581      19            G. George             K. Zelem          83
# 216  13129      21             E. Toone         Lucía García          70
# 217  13154      21         Lucía García                 <NA>          91
# 218  13402      22       Geyse Ferreira            G. George          99
# 219  13471      22            G. George            M. Turner          71
# 237  14800      24          H. Blundell         Lucía García          58
# 238  14987      24          H. Blundell             K. Zelem          79
# 244  15396      25            K. Hanson            D. Turner          74
# 245  15469      25         Lucía García          H. Blundell           6
# 262  17400      28            K. Hanson              R. Daly          52
# 263  17444      28          H. Blundell             K. Zelem          30
# 282  18413      30             E. Toone            L. Galton          43
# 283  18444      30            L. Galton         Lucía García          72
# 285  19052      31         Lucía García          H. Blundell          67
# 286  19070      31          H. Blundell       Geyse Ferreira          66
# 287  19231      31  L. Blindkilde Brown            D. Turner          32
# 291  19326      32             E. Toone            G. George          68
# 292  19395      32            G. George           S. Mayling          92
# 318  21187      35       Geyse Ferreira         Lucía García          83
# 319  21254      35         Lucía García             K. Zelem          97
# 324  21488      35            L. Parker           A. Lehmann          58
# 325  21645      35            M. Turner        M. Le Tissier          13
# 329  21806      36              H. Ladd            L. Galton          40
# 330  21900      36            L. Galton             K. Zelem          72
# 331  21920      36             K. Zelem              H. Ladd          67
# 339  22158      36        M. Le Tissier         Lucía García          46
# 340  22529      37            L. Parker           A. Lehmann          66
# 349  23267      38        L. Staniforth           S. Mayling          64
# 350  23298      38           S. Mayling              R. Daly          83
# 365  23895      39            G. George            L. Galton          35
# 366  23977      39            L. Galton       Geyse Ferreira          87
# 380  25085      41            M. Turner            G. George          60
# 381  25131      41            G. George            M. Turner          73
# 384  25230      41       Geyse Ferreira         Lucía García          81
# 385  25269      41         Lucía García       Geyse Ferreira          89
# 388  25398      42             K. Zelem         Lucía García          77
# 389  25425      42         Lucía García             K. Zelem          84
# 390  25435      42             K. Zelem             E. Toone          73
# 391  25453      42             E. Toone         Lucía García          92
# 395  26456      43            A. Patten           S. Mayling          31
# 396  26506      44           S. Mayling           A. Lehmann          67
# 397  26793      44  L. Blindkilde Brown              H. Ladd          81
# 398  27083      44        L. Staniforth           A. Lehmann          72
# 399  27106      45            L. Galton             K. Zelem          19
# 409  27401      45           A. Lehmann           S. Mayling          93
# 410  27681      45            L. Galton            A. Patten          33
# 414  27950      45            R. Corsie            K. Hanson          35
# 415  28016      45            K. Hanson             M. Earps          96
# 422  28444      46             K. Zelem            R. Corsie          56
# 423  28507      46            R. Corsie            D. Turner           4
# 443  29518      47        M. Le Tissier       Geyse Ferreira          63
# 444  29605      47       Geyse Ferreira         Lucía García          92
# 445  29746      48            R. Corsie            K. Hanson           2
# 447  29792      48       Geyse Ferreira          H. Blundell          92
# 448  29803      48          H. Blundell            L. Parker          87
# 449  29974      48         Lucía García          H. Blundell          83
# 450  29987      48          H. Blundell              H. Ladd          75
# 451  30010      48            K. Hanson            D. Turner          18
# 457  30235      48            E. Salmon            M. Turner          62
# 458  30465      49              R. Daly           S. Mayling          77
# 459  30472      49           S. Mayling           A. Lehmann          79
# 462  30511      49        L. Staniforth            G. George          79
# 463  30522      49            G. George        L. Staniforth          20
# 470  31212      50            M. Turner            L. Galton          44
# 471  31228      50            L. Galton            L. Parker          74
# 473  31323      50            G. George            L. Galton          81
# 474  31342      50            L. Galton             E. Toone          88
# 475  31373      50             E. Toone            L. Galton          88
# 476  31388      50            L. Galton            G. George          86
# 477  31396      50            G. George             E. Toone          89
# 478  31930      51            R. Corsie            E. Salmon          18
# 483  32372      52            M. Turner            L. Galton          59
# 484  32431      52            L. Galton            G. George          77
# 485  32462      52            G. George                 <NA>          66
# 491  32648      53             K. Zelem            G. George          63
# 492  32698      53            G. George            L. Galton          68
# 515  34626      56        L. Staniforth            K. Hanson          72
# 516  34948      56             M. Earps            G. George           7
# 527  36221      58        M. Le Tissier            L. Galton          43
# 528  36302      59            L. Galton       Geyse Ferreira          89
# 548  37195      60           A. Lehmann           S. Mayling          65
# 549  37233      60            L. Galton       Geyse Ferreira          34
# 555  38417      62            L. Parker           A. Lehmann          62
# 556  38442      62           A. Lehmann                 <NA>          90
# 563  39845      65            K. Hanson        L. Staniforth          72
# 564  39882      65        L. Staniforth            D. Turner          75
# 565  39897      65            D. Turner            K. Hanson          88
# 566  39933      65            K. Hanson        L. Staniforth          83
# 576  42346      69           S. Mayling              A. Leon          58
# 577  42365      69              A. Leon             E. Toone          69
# 578  42389      69            M. Turner                 <NA>          24
# 583  42595      69              A. Leon              R. Daly          80
# 584  42613      69              R. Daly           S. Mayling          81
# 585  42634      69           S. Mayling              R. Daly          82
# 586  43435      70     D. van Domselaar            A. Patten          18
# 594  43772      71          R. Williams         Lucía García          65
# 595  43819      71         Lucía García             E. Toone          75
# 600  44064      72            M. Turner             E. Toone          43
# 601  44112      72              A. Leon         Lucía García          21
# 614  45837      74             E. Toone            N. Parris          71
# 615  45870      75            N. Parris                 <NA>          94
# 629  48882      80                 <NA>          H. Blundell          50
# 630  48922      80          H. Blundell             M. Earps          14
# 634  49034      80             E. Toone         Lucía García          64
# 635  49099      80         Lucía García          R. Williams          97
# 662  51863      85             E. Toone            G. George          73
# 663  51907      85            G. George     D. van Domselaar          89
# 673  52816      86             K. Zelem         Lucía García          63
# 674  52872      86         Lucía García            G. George          83
# 675  52892      86            G. George     D. van Domselaar          91
# 684  53618      87            N. Parris          H. Miyazawa          70
# 685  53658      88          H. Miyazawa         Lucía García          86
# 686  53732      88         Lucía García             E. Toone          93
# 693  54259      89          H. Blundell            N. Parris          64
# 694  54284      89            N. Parris             E. Toone          88
# 700  55213      90          H. Blundell            N. Parris          62
# 701  55275      90            N. Parris          H. Blundell          89
# 705  55368      90             K. Zelem            G. George          69
# 706  55399      90            G. George         Lucía García          72
# 707  55461      91         Lucía García          H. Miyazawa          79
# 717  56770      93             E. Toone            R. Corsie          60
# 718  56785      93            R. Corsie            L. Parker          33
# 734  57470      94          H. Blundell            N. Parris          75
# 735  57500      94            N. Parris          H. Miyazawa          87
# 741  58180      95            G. George             E. Toone          55
# 742  58333      95             J. Nobbs           S. Mayling          30
# 761  58930      96             J. Nobbs            E. Salmon          65
# 762  58939      96            E. Salmon              A. Leon          75
# 769  59909      98             J. Nobbs              A. Leon          89
# 770  59946      98              A. Leon             J. Nobbs          95
# 771  59958      98             J. Nobbs         Lucía García          87
# 772  60032      98           S. Mayling             J. Nobbs          45
# 773  60326      99          R. Williams         Lucía García          40
# 774  60692      99           S. Mayling             K. Zelem          64
#
#      location_y  pass_endlocation_x  pass_endlocation_y
# 26           12                  72                   8
# 27           20                  77                   4
# 28            4                  93                  16
# 29           16                  62                  74
# 68           19                  78                   8
# 69            8                  69                   7
# 70            7                  63                  28
# 77            2                  87                   9
# 78           18                  78                  24
# 108          39                  68                  18
# 109          18                  74                  40
# 111          13                  72                  10
# 112          68                  27                  34
# 130          26                  77                   7
# 131           6                  58                   6
# 147           9                  70                   3
# 148           3                  74                   6
# 149           6                  62                  17
# 164          98                  72                  82
# 165          82                  70                  81
# 166          81                  66                  87
# 167          87                  65                  43
# 174          41                  70                  18
# 175          18                  75                  16
# 176          16                  79                   5
# 177           5                  77                  35
# 178          14                  93                   7
# 179          12                  88                  93
# 180          93                  98                  43
# 181          11                  83                  11
# 182          11                  73                  23
# 216          72                  91                  89
# 217          89                 100                 100
# 218          71                  71                  16
# 219          16                  67                  38
# 237          94                  67                  96
# 238          86                  73                  65
# 244          13                  88                  10
# 245          85                   5                  74
# 262           6                  72                  14
# 263          85                  14                  90
# 282          22                  72                   8
# 283           8                  79                  30
# 285          86                  66                  96
# 286          96                  73                  97
# 287          12                  23                   3
# 291          50                  98                  16
# 292          27                  95                  32
# 318          35                  97                  14
# 319          14                  81                  23
# 324          97                  73                  94
# 325          28                  13                  44
# 329           8                  72                  15
# 330          15                  67                  15
# 331          15                  64                   5
# 339          61                  72                  97
# 340          64                  79                  55
# 349          80                  83                  95
# 350          95                  87                  56
# 365           5                  71                  13
# 366          13                  83                  52
# 380          26                  79                   5
# 381          18                  66                  21
# 384          94                  89                  88
# 385          93                  87                  77
# 388          86                  84                  96
# 389          96                  73                  88
# 390          88                  92                  86
# 391          86                  97                  76
# 395          69                  67                  92
# 396          92                  80                  82
# 397          90                  77                  90
# 398          90                  85                  93
# 399          10                  20                  16
# 409          95                  83                  93
# 410           3                  46                   5
# 414          26                  96                   7
# 415           7                  97                  54
# 422          82                  96                  87
# 423          13                  23                   6
# 443          94                  94                  91
# 444          91                  86                  93
# 445          17                   4                   7
# 447          84                  87                  90
# 448          90                  89                  69
# 449          87                  75                  96
# 450          96                  79                  82
# 451          10                  13                  17
# 457          97                  83                  93
# 458          83                  79                  98
# 459          98                  80                  80
# 462          69                  80                  89
# 463          11                  25                  28
# 470          24                  74                  18
# 471          18                  65                  42
# 473          15                  88                  10
# 474          10                  79                  15
# 475          11                  86                   6
# 476           6                  89                  14
# 477          14                  95                  11
# 478          16                  55                  26
# 483          13                  77                   2
# 484           2                  66                   5
# 485           5                  69                  30
# 491          40                  68                  13
# 492          13                  76                  46
# 515          61                  81                  18
# 516          46                  12                   9
# 527          52                  79                  13
# 528          10                  83                  21
# 548          75                  70                  93
# 549           4                  60                  20
# 555          92                  90                  86
# 556          86                  81                  56
# 563          22                  75                   8
# 564           8                  88                   4
# 565           4                  76                   8
# 566          18                  84                  28
# 576          97                  69                  97
# 577          97                  70                  92
# 578          21                  50                   0
# 583          68                  81                  82
# 584          82                  82                  95
# 585          95                  72                  87
# 586          36                  25                  61
# 594          35                  71                  17
# 595          26                  73                  34
# 600          25                  67                   3
# 601          94                  21                  90
# 614          55                  94                  84
# 615          84                 100                 100
# 629          49                  86                  14
# 630          86                   6                  54
# 634          16                  75                   3
# 635          28                  95                  41
# 662          35                  89                   7
# 663           7                  95                  46
# 673          42                  83                   9
# 674           9                  91                  13
# 675          13                  84                  37
# 684          76                  89                  87
# 685          85                  93                  16
# 686          16                  89                  23
# 693          72                  88                  91
# 694          91                  95                  67
# 700          67                  90                  82
# 701          74                  78                  77
# 705          55                  72                  10
# 706          10                  83                   5
# 707          37                  80                  49
# 717          68                  67                  84
# 718          16                  43                  64
# 734          71                  87                  88
# 735          88                  84                  67
# 741           5                  74                   4
# 742          86                  33                  97
# 761          79                  75                  90
# 762          90                  77                  73
# 769          85                  97                  83
# 770          92                  87                  91
# 771          91                  91                  54
# 772          70                  72                  90
# 773           5                  48                   2
# 774          95                  70                  85

# %%
match_event_df[match_event_df['frame'] == 11013]
# Out:
#      frame  minute player_name pass_recipient_name  pass_recipient_id  \
# 166  11013      18    K. Zelem             H. Ladd              11164
#
#     pass_recipient_position  sk_player_id  pass_angle type_primary  \
# 166                    RCMF         68743         141         pass
#
#                         type_secondary  location_x  location_y  pass_accurate  \
# 166  [back_pass, short_or_medium_pass]          70          81           True
#
#      pass_endlocation_x  pass_endlocation_y player_position  sk_match_id  \
# 166                  66                  87             DMF      1133203
#
#      team  period  in_wide_channel
# 166  away     1.0            False
