# %%
from mplsoccer.pitch import Pitch
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import os
import json
import math
import jsonlines
from skillcorner.client import SkillcornerClient
import pyarrow.parquet as pq

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
def load_json_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# %%
def load_jsonl_file(file_path):
    with jsonlines.open(file_path, 'r') as file:
        data = [line for line in file if line['timestamp'] is not None]
    return data

# %%
def explode_data(row):
    # Extract player data into a DataFrame
    players = pd.DataFrame(row['player_data'])
    players['object'] = 'player'
    
    # Extract ball data into a DataFrame
    ball = pd.DataFrame([row['ball_data']])
    ball['object'] = 'ball'
    ball['player_id'] = 0  
   
    # Combine player and ball data
    combined = pd.concat([players, ball], ignore_index=True)
    
    # Add other columns from the original row
    for col in row.index:
        if col not in ['player_data', 'ball_data']:
            combined[col] = row[col]
    
    return combined

# %%
def euclidean_distance(x1, y1, x2, y2):
    """Calculate the Euclidean distance between two points."""
    return math.sqrt((x1 - x2)**2 + (y1 - y2)**2)

# %%
match_id = 1133203
tracking_path = f'data/FA/tracking/{match_id}.jsonl'

file_path = f'data/FA/match/{match_id}.json'
match_data = load_json_file(file_path)
file_path = 'data/wyscout_events.parquet'
events_df = pd.read_parquet(file_path)
match_event_df = events_df[events_df['sk_match_id'] == match_id]

# %%
id_map = {player['short_name']: player['id'] for player in match_data['players']}

# %%
cols = ['frame', 'minute', 'player_name', 'pass_recipient_name', 'pass_recipient_id',
       'pass_recipient_position', 'sk_player_id', 'pass_angle','type_primary', 'type_secondary', 'location_x', 'location_y', 'pass_accurate',
       'pass_endlocation_x', 'pass_endlocation_y', 'player_position', 'sk_match_id', 
       'possession_team_name', 'possession_types']
match_event_df = match_event_df[cols]

# %%
match_event_pass = match_event_df[match_event_df['type_primary'] == 'pass'].reset_index(drop = True)

# %%
match_event_pass.head()
# Out:
#    frame  minute    player_name pass_recipient_name  pass_recipient_id  \
# 0    107       0        H. Ladd            K. Zelem             134338
# 1    126       0       K. Zelem           G. George             289914
# 2    158       0      G. George           M. Turner             258929
# 3    191       0      M. Turner       M. Le Tissier             559233
# 4    222       0  M. Le Tissier           M. Turner             258929
#
#   pass_recipient_position  sk_player_id  pass_angle type_primary  \
# 0                     DMF         64166        -153         pass
# 1                      LB         68743        -104         pass
# 2                     LCB         68681         104         pass
# 3                     RCB         63767          93         pass
# 4                     LCB         68697         -88         pass
#
#                          type_secondary  location_x  location_y  \
# 0     [back_pass, short_or_medium_pass]          51          50
# 1  [lateral_pass, short_or_medium_pass]          38          40
# 2  [lateral_pass, short_or_medium_pass]          33          10
# 3  [lateral_pass, short_or_medium_pass]          29          39
# 4  [lateral_pass, short_or_medium_pass]          28          70
#
#    pass_accurate  pass_endlocation_x  pass_endlocation_y player_position  \
# 0           True                  38                  40            RCMF
# 1           True                  33                  10             DMF
# 2           True                  29                  39              LB
# 3           True                  28                  70             LCB
# 4           True                  29                  37             RCB
#
#    sk_match_id possession_team_name possession_types
# 0      1133203    Manchester United             None
# 1      1133203    Manchester United             None
# 2      1133203    Manchester United             None
# 3      1133203    Manchester United             None
# 4      1133203    Manchester United             None

# %%
match_event_pass[match_event_pass['pass_recipient_name'].isna()]
# Out:
#      frame  minute     player_name pass_recipient_name  pass_recipient_id  \
# 6      295       0   M. Le Tissier                <NA>                  0
# 39    2750       4     H. Blundell                <NA>                  0
# 79    4573       7        K. Zelem                <NA>                  0
# 100   6034       9       R. Corsie                <NA>                  0
# 121   7272      11         R. Daly                <NA>                  0
# 139   9150      15   L. Staniforth                <NA>                  0
# 140   9211      15      A. Lehmann                <NA>                  0
# 180  11484      18  Geyse Ferreira                <NA>                  0
# 192  12195      20      S. Mayling                <NA>                  0
# 217  13154      21    Lucía García                <NA>                  0
# 383  25206      41    Lucía García                <NA>                  0
# 453  30090      48       L. Parker                <NA>                  0
# 485  32462      52       G. George                <NA>                  0
# 519  35020      56       G. George                <NA>                  0
# 556  38442      62      A. Lehmann                <NA>                  0
# 568  39960      65       K. Hanson                <NA>                  0
# 574  42186      68        K. Zelem                <NA>                  0
# 578  42389      69       M. Turner                <NA>                  0
# 615  45870      75       N. Parris                <NA>                  0
# 625  47439      77     H. Blundell                <NA>                  0
# 646  51128      83    Lucía García                <NA>                  0
# 667  52293      85   M. Le Tissier                <NA>                  0
# 668  52547      86         R. Daly                <NA>                  0
# 687  53750      88        E. Toone                <NA>                  0
# 688  54000      88         R. Daly                <NA>                  0
# 736  57507      94     H. Miyazawa                <NA>                  0
# 748  58386      95        K. Zelem                <NA>                  0
# 766  59264      97         A. Leon                <NA>                  0
# 768  59879      98        J. Nobbs                <NA>                  0
#
#     pass_recipient_position  sk_player_id  pass_angle type_primary  \
# 6                      <NA>         68697          26         pass
# 39                     <NA>         57096          56         pass
# 79                     <NA>         68743          68         pass
# 100                    <NA>         22628         -20         pass
# 121                    <NA>         22618         -49         pass
# 139                    <NA>         22624          27         pass
# 140                    <NA>         64130        -148         pass
# 180                    <NA>         22555         -72         pass
# 192                    <NA>         68672         180         pass
# 217                    <NA>         22457          38         pass
# 383                    <NA>         22457         -51         pass
# 453                    <NA>         68661         180         pass
# 485                    <NA>         68681          80         pass
# 519                    <NA>         68681         -22         pass
# 556                    <NA>         64130        -117         pass
# 568                    <NA>         64066        -170         pass
# 574                    <NA>         68743         -28         pass
# 578                    <NA>         63767         -27         pass
# 615                    <NA>         22608          61         pass
# 625                    <NA>         57096          63         pass
# 646                    <NA>         22457          84         pass
# 667                    <NA>         68697         -39         pass
# 668                    <NA>         22618          79         pass
# 687                    <NA>         62411        -144         pass
# 688                    <NA>         22618          48         pass
# 736                    <NA>         62505          13         pass
# 748                    <NA>         68743         -25         pass
# 766                    <NA>         22735        -151         pass
# 768                    <NA>         63765        -151         pass
#
#                                                                           type_secondary  \
# 6                                         [forward_pass, long_pass, pass_to_final_third]
# 39                              [progressive_pass, short_or_medium_pass, under_pressure]
# 79                                                                [cross, cross_blocked]
# 100                                          [forward_pass, long_pass, progressive_pass]
# 121                            [lateral_pass, pass_to_final_third, short_or_medium_pass]
# 139                     [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 140                                                               [cross, cross_blocked]
# 180  [cross, deep_completed_cross, lateral_pass, pass_to_penalty_area, progressive_pass]
# 192                                                    [back_pass, short_or_medium_pass]
# 217                                                               [cross, cross_blocked]
# 383                           [recovery, counterpressing_recovery, short_or_medium_pass]
# 453                                                    [back_pass, short_or_medium_pass]
# 485          [lateral_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 519                    [forward_pass, long_pass, loss, progressive_pass, under_pressure]
# 556                                                                [cross, lateral_pass]
# 568                                                 [cross, cross_blocked, touch_in_box]
# 574                                          [forward_pass, long_pass, progressive_pass]
# 578                                          [forward_pass, long_pass, progressive_pass]
# 615                                                               [cross, cross_blocked]
# 625                                                 [cross, cross_blocked, touch_in_box]
# 646                                                 [cross, cross_blocked, touch_in_box]
# 667                                 [forward_pass, long_pass, loss, pass_to_final_third]
# 668                                                               [short_or_medium_pass]
# 687                                              [back_pass, loss, short_or_medium_pass]
# 688                                            [lateral_pass, long_pass, under_pressure]
# 736                           [forward_pass, pass_to_penalty_area, short_or_medium_pass]
# 748                                       [forward_pass, long_pass, pass_to_final_third]
# 766                                                               [cross, cross_blocked]
# 768                                          [cross, cross_blocked, carry, touch_in_box]
#
#      location_x  location_y  pass_accurate  pass_endlocation_x  \
# 6            33          74          False                  69
# 39           32          96          False                  34
# 79           78          17          False                 100
# 100          29          21          False                  66
# 121          57          20          False                  69
# 139          30          45           True                  84
# 140          91          90          False                   0
# 180          88          93           True                  98
# 192          70          89           True                  67
# 217          91          89          False                 100
# 383          78          84           True                  82
# 453          39          53           True                  34
# 485          66           5           True                  69
# 519          19           3          False                  24
# 556          90          86           True                  81
# 568          95          25          False                   0
# 574          10          28          False                  44
# 578          24          21          False                  50
# 615          94          84          False                 100
# 625          91          73          False                 100
# 646          95          26          False                 100
# 667          37          41          False                  70
# 668          34          86          False                  36
# 687          88          12          False                  77
# 688          31          87          False                  39
# 736          84          67          False                 100
# 748          57          14          False                  77
# 766          96          83          False                   0
# 768          87          74          False                   0
#
#      pass_endlocation_y player_position  sk_match_id possession_team_name  \
# 6                   100             RCB      1133203    Manchester United
# 39                  100              RB      1133203    Manchester United
# 79                  100             DMF      1133203    Manchester United
# 100                   0             LCB      1133203          Aston Villa
# 121                   0              CF      1133203          Aston Villa
# 139                  87            LDMF      1133203          Aston Villa
# 140                   0            RAMF      1133203          Aston Villa
# 180                  43              CF      1133203    Manchester United
# 192                  89              RB      1133203          Aston Villa
# 217                 100              RW      1133203    Manchester United
# 383                  77              RW      1133203    Manchester United
# 453                  53            RDMF      1133203          Aston Villa
# 485                  30              LB      1133203    Manchester United
# 519                   0              LB      1133203    Manchester United
# 556                  56            RAMF      1133203          Aston Villa
# 568                   0            LAMF      1133203          Aston Villa
# 574                   0             DMF      1133203    Manchester United
# 578                   0             LCB      1133203    Manchester United
# 615                 100              RW      1133203    Manchester United
# 625                 100              RB      1133203    Manchester United
# 646                 100              LW      1133203    Manchester United
# 667                   0             RCB      1133203    Manchester United
# 668                 100              CF      1133203          Aston Villa
# 687                   0            LCMF      1133203    Manchester United
# 688                 100              CF      1133203          Aston Villa
# 736                  74            RCMF      1133203    Manchester United
# 748                   0             DMF      1133203    Manchester United
# 766                   0              RW      1133203          Aston Villa
# 768                   0            RCMF      1133203          Aston Villa
#
#                           possession_types
# 6                                     None
# 39                              [throw_in]
# 79               [attack, transition_high]
# 100                                   None
# 121                                   None
# 139                               [attack]
# 140                               [attack]
# 180            [attack, transition_medium]
# 192  [set_piece_attack, attack, free_kick]
# 217            [attack, transition_medium]
# 383                     [attack, throw_in]
# 453                       [transition_low]
# 485                               [attack]
# 519          [set_piece_attack, free_kick]
# 556               [attack, transition_low]
# 568            [attack, transition_medium]
# 574                                   None
# 578                                   None
# 615  [set_piece_attack, attack, free_kick]
# 625                [counterattack, attack]
# 646            [attack, transition_medium]
# 667                               [attack]
# 668                             [throw_in]
# 687                               [attack]
# 688                             [throw_in]
# 736                               [attack]
# 748                                   None
# 766                     [attack, throw_in]
# 768              [attack, transition_high]

# %%
passing_frames = match_event_pass.frame.to_list()

# %%
for i in range(len(passing_frames)):
    start_frame = passing_frames[i]
    end_frame = passing_frames[i+1]
    row = match_event_pass.iloc[i]
    target_player_id = id_map[row['pass_recipient_name']]
    print(row['pass_recipient_name'])
    print(target_player_id)
# Out:
# K. Zelem
# 68743
# G. George
# 68681
# M. Turner
# 63767
# M. Le Tissier
# 68697
# M. Turner
# 63767
# M. Le Tissier
# 68697
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 5
#       3 end_frame = passing_frames[i+1]
#       4 row = match_event_pass.iloc[i]
# ----> 5 target_player_id = id_map[row['pass_recipient_name']]
#       6 print(row['pass_recipient_name'])
#       7 print(target_player_id)
#
# KeyError: <NA>

# %%
start_frame = 158  # Example frame number
end_frame = 191
target_player_id = id_map['M. Turner']  # Target player_id
distance_threshold = 2

# %%
target_player_id
# Out:
# 68743

# %%
matching_line = None

with jsonlines.open(tracking_path, 'r') as file:
    start_checking = False  # Flag to start processing lines after the starting frame
    
    for line in file:
        frame = line.get('frame')
        
        # Stop processing if end_frame is reached
        if frame and frame >= end_frame:
            break
        
        # Check if we've reached the starting frame
        if not start_checking:
            if frame == start_frame:
                start_checking = True
                print(frame)
            continue

        # Process lines after the starting frame
        player_data = line.get('player_data', [])
        ball_data = line.get('ball_data', None)

        ball_x, ball_y = ball_data['x'], ball_data['y']
        
        for player in player_data:
            # Ensure the player_id matches
            if player.get('player_id') == target_player_id:
                # Extract player's coordinates
                player_x, player_y = player['x'], player['y']
                
                # Check the distance condition
                dist = euclidean_distance(player_x, player_y, ball_x, ball_y)
                print(dist)
                if dist <= distance_threshold:
                    matching_line = line
                    break

        if matching_line:
            break
# Out:
# 158
# 11.464065596462712
# 10.113317952086742
# 8.714883820223882
# 7.405356169692313
# 6.143850584120679
# 4.961370778323267
# 3.8657082145449086
# 2.912902332725902
# 2.0163581031156137
# 1.260158720161869

# %%
matching_line
# Out:
# {'frame': 168,
#  'timestamp': '00:00:06.80',
#  'period': 1,
#  'ball_data': {'x': 25.09, 'y': -15.82, 'z': 0.04, 'is_detected': True},
#  'possession': {'player_id': 63767, 'group': 'away team'},
#  'image_corners_projection': {'x_top_left': 6.67,
#   'y_top_left': 35.11,
#   'x_bottom_left': 1.42,
#   'y_bottom_left': -27.5,
#   'x_bottom_right': 20.55,
#   'y_bottom_right': -33.53,
#   'x_top_right': 53.26,
#   'y_top_right': 20.97},
#  'player_data': [{'x': -37.66,
#    'y': -2.31,
#    'player_id': 63552,
#    'is_detected': False},
#   {'x': -10.57, 'y': -11.08, 'player_id': 68719, 'is_detected': False},
#   {'x': -10.75, 'y': -1.59, 'player_id': 22628, 'is_detected': False},
#   {'x': -10.2, 'y': -21.86, 'player_id': 68672, 'is_detected': False},
#   {'x': -12.12, 'y': 11.49, 'player_id': 68680, 'is_detected': False},
#   {'x': 0.4, 'y': -5.01, 'player_id': 22624, 'is_detected': False},
#   {'x': -0.34, 'y': -14.84, 'player_id': 68661, 'is_detected': False},
#   {'x': 8.82, 'y': -12.65, 'player_id': 68675, 'is_detected': True},
#   {'x': 6.13, 'y': -21.63, 'player_id': 64130, 'is_detected': True},
#   {'x': 1.41, 'y': 4.85, 'player_id': 64066, 'is_detected': False},
#   {'x': 13.25, 'y': -3.09, 'player_id': 22618, 'is_detected': True},
#   {'x': 38.54, 'y': -1.09, 'player_id': 22622, 'is_detected': True},
#   {'x': 22.99, 'y': 9.01, 'player_id': 68697, 'is_detected': True},
#   {'x': 26.11, 'y': -15.08, 'player_id': 63767, 'is_detected': True},
#   {'x': 9.57, 'y': 21.0, 'player_id': 57096, 'is_detected': True},
#   {'x': 16.06, 'y': -25.84, 'player_id': 68681, 'is_detected': True},
#   {'x': 8.92, 'y': -9.16, 'player_id': 68743, 'is_detected': True},
#   {'x': 7.15, 'y': -18.79, 'player_id': 62411, 'is_detected': True},
#   {'x': 0.91, 'y': 2.05, 'player_id': 64166, 'is_detected': False},
#   {'x': -5.92, 'y': 21.45, 'player_id': 22457, 'is_detected': False},
#   {'x': -9.47, 'y': -23.13, 'player_id': 68744, 'is_detected': False},
#   {'x': -8.58, 'y': -8.48, 'player_id': 22555, 'is_detected': False}]}
