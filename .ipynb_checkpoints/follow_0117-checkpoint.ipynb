# %%
import matplotlib.pyplot as plt
from dotenv import load_dotenv
from scipy.optimize import minimize
import pandas as pd
import numpy as np
import seaborn as sns
import os
import json
import math
import jsonlines
import pyarrow.parquet as pq
from utils import load_json_file, load_jsonl_file, euclidean_distance, check_target_area, get_receive_frame, explode_data
import plotly.graph_objects as go
import soccerfield

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
events_path = 'data/wyscout_events.parquet'
events_df = pd.read_parquet(events_path)

# %%
events_df =events_df[~events_df['type_primary'].isin(['duel', 'touch'])]

# %%
pass_files = os.listdir('data/pass_data')
len(pass_files)
# Out:
# 76

# %%
pass_file = pass_files[1]
pass_df = pd.read_csv(f'data/pass_data/{pass_file}')

# %%
match_id = pass_df.loc[0, 'sk_match_id']
match_id
# Out:
# 1150610

# %%
match_event_df = events_df[events_df['sk_match_id'] == match_id].reset_index(drop = True)

# %%
cols = ['frame', 'minute', 'player_name', 'pass_recipient_name', 'type_primary', 'team_name', 'possession_team_name', 'possession_team_name_src', 'wy_team_id', 'possession_team_id_src']

# %%
pass_df = pass_df[pass_df['team_name'] == pass_df['possession_team_name_src']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\asi12\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'team_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ...

# %%
for i in pass_df.frame.to_list():
    pass_idx = match_event_df.index[match_event_df['frame'] == i].tolist()[0]
    segment_df = match_event_df.iloc[pass_idx:pass_idx+6]
    display(segment_df[cols])
# Out:
#    frame  minute   player_name pass_recipient_name       type_primary  \
# 4  20512      34     V. Asseyi            K. Smith               pass
# 5  20557      34      K. Smith                <NA>               pass
# 6  20585      34          <NA>                <NA>  game_interruption
# 7  20731      34  G. Bergsvand            S. Cooke           throw_in
# 8  20753      34      S. Cooke                <NA>       interception
# 9  20766      34          <NA>                <NA>  game_interruption
#
#                 team_name    possession_team_name possession_team_name_src  \
# 4         West Ham United         West Ham United               In Contest
# 5         West Ham United         West Ham United               In Contest
# 6  Brighton & Hove Albion         West Ham United               In Contest
# 7  Brighton & Hove Albion  Brighton & Hove Albion   Brighton & Hove Albion
# 8         West Ham United         West Ham United               In Contest
# ...
