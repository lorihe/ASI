# %%
from mplsoccer.pitch import Pitch
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import os
import json
import jsonlines
from skillcorner.client import SkillcornerClient
import pyarrow.parquet as pq

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
load_dotenv()
username = os.getenv('U')
password = os.getenv('P')
client = SkillcornerClient(username=username, password=password)

# %%
def load_json_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# %%
def load_jsonl_file(file_path):
    with jsonlines.open(file_path, 'r') as file:
        data = [line for line in file if line['timestamp'] is not None]
    return data

# %%
FA_matches = client.get_matches(params={'competition_edition': 574})
FA_match_ids = [m['id'] for m in FA_matches]

# %%
NWSL_matches = client.get_matches(params={'competition_edition': 800})
NWSL_match_ids = [m['id'] for m in NWSL_matches]

# %%
# Inspect the schema of the Parquet file
file_path = 'data/wyscout_events.parquet'
events_df = pd.read_parquet(file_path)

# %%
event_match_ids = list(set(events_df.sk_match_id))

# %%
FA_in_event = [i for i in FA_match_ids if i in event_match_ids]
len(FA_in_event)
# Out:
# 102

# %%
FA_not_in_event = [i for i in FA_match_ids if i not in event_match_ids]
len(FA_not_in_event)
# Out:
# 30

# %%
NWSL_in_event = [i for i in NWSL_match_ids if i in event_match_ids]
len(NWSL_in_event)
# Out:
# 0

# %%
NWSL_not_in_event = [i for i in NWSL_match_ids if i not in event_match_ids]
len(NWSL_not_in_event)
# Out:
# 189

# %%
cols = ['sk_match_id', 'frame', 'minute', 'player_name', 'pass_recipient_name', 'pass_recipient_id',
       'pass_recipient_position', 'sk_player_id', 'pass_angle','type_primary', 'location_x', 'location_y', 'pass_accurate',
       'pass_endlocation_x', 'pass_endlocation_y',
       'type_secondary', 'player_position']

# %%
FA_match_ids = FA_in_event

# %%
events_df = events_df[events_df['sk_match_id'].isin(FA_match_ids)][cols]

# %%
match_id = 1133203

# %%
match_data = load_json_file(rf'data/FA/match/{match_id}.json')

# %%
match_data
# Out:
# {'id': 1133203,
#  'home_team_score': 1,
#  'away_team_score': 2,
#  'date_time': '2023-10-01T11:30:00Z',
#  'stadium': {'id': 488,
#   'name': 'Villa Park',
#   'city': 'Birmingham',
#   'capacity': 42682},
#  'home_team': {'id': 2029,
#   'name': 'Aston Villa, Women',
#   'short_name': 'Aston Villa',
#   'acronym': 'AVL'},
#  'home_team_kit': {'id': 5450,
#   'team_id': 2029,
#   'season': {'id': 6,
#    'start_year': 2019,
#    'end_year': 2020,
#    'name': '2019/2020'},
#   'name': 'Home',
#   'jersey_color': '#a50521',
#   'number_color': '#ffffff'},
#  'away_team': {'id': 2027,
#   'name': 'Manchester United, Women',
#   'short_name': 'Man Utd, W',
#   'acronym': 'MUN'},
#  'away_team_kit': {'id': 6537,
#   'team_id': 2027,
#   'season': {'id': 8,
#    'start_year': 2021,
#    'end_year': 2022,
#    'name': '2021/2022'},
#   'name': 'Away',
#   'jersey_color': '#ffffff',
#   'number_color': '#ff0000'},
#  'home_team_coach': None,
#  'away_team_coach': None,
#  'competition_edition': {'id': 574,
#   'competition': {'id': 127,
#    'area': 'ENG',
#    'name': 'FA Women`s Super League',
#    'gender': 'female',
#    'age_group': 'adult'},
#   'season': {'id': 28,
#    'start_year': 2023,
#    'end_year': 2024,
#    'name': '2023/2024'},
#   'name': 'ENG - FA Women`s Super League - 2023/2024'},
#  'competition_round': {'id': 1885,
#   'name': 'Round 1',
#   'round_number': 1,
#   'potential_overtime': False},
#  'referees': [],
#  'players': [{'player_role': {'id': 7,
#     'position_group': 'Midfield',
#     'name': 'Defensive Midfield',
#     'acronym': 'DM'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 10,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102120,
#    'team_id': 2027,
#    'id': 68743,
#    'first_name': 'Katie',
#    'last_name': 'Zelem',
#    'short_name': 'K. Zelem',
#    'birthday': '1996-01-20',
#    'trackable_object': 69869,
#    'gender': 'female'},
#   {'player_role': {'id': 19,
#     'position_group': 'Full Back',
#     'name': 'Left Back',
#     'acronym': 'LB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 14,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 375202,
#    'team_id': 2029,
#    'id': 68680,
#    'first_name': 'Danielle',
#    'last_name': 'Turner',
#    'short_name': 'D. Turner',
#    'birthday': '1991-09-10',
#    'trackable_object': 69806,
#    'gender': 'female'},
#   {'player_role': {'id': 4,
#     'position_group': 'Central Defender',
#     'name': 'Right Center Back',
#     'acronym': 'RCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 4,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 198947,
#    'team_id': 2029,
#    'id': 68719,
#    'first_name': 'Anna',
#    'last_name': 'Patten',
#    'short_name': 'A. Patten',
#    'birthday': '1999-04-20',
#    'trackable_object': 69845,
#    'gender': 'female'},
#   {'player_role': {'id': 22,
#     'position_group': 'Midfield',
#     'name': 'Right Defensive Midfield',
#     'acronym': 'RDM'},
#    'start_time': '00:00:00',
#    'end_time': '01:34:58',
#    'number': 15,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153050,
#    'team_id': 2029,
#    'id': 68661,
#    'first_name': 'Lucy',
#    'last_name': 'Parker',
#    'short_name': 'L. Parker',
#    'birthday': '1998-11-18',
#    'trackable_object': 69787,
#    'gender': 'female'},
#   {'player_role': {'id': 11,
#     'position_group': 'Midfield',
#     'name': 'Attacking Midfield',
#     'acronym': 'AM'},
#    'start_time': '00:45:00',
#    'end_time': None,
#    'number': 17,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153052,
#    'team_id': 2029,
#    'id': 62646,
#    'first_name': 'Ebony',
#    'last_name': 'Salmon',
#    'short_name': 'E. Salmon',
#    'birthday': '2001-01-27',
#    'trackable_object': 63772,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '01:10:17',
#    'end_time': None,
#    'number': 22,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 401798,
#    'team_id': 2027,
#    'id': 22608,
#    'first_name': 'Nikita',
#    'last_name': 'Parris',
#    'short_name': 'N. Parris',
#    'birthday': '1994-03-10',
#    'trackable_object': 23166,
#    'gender': 'female'},
#   {'player_role': {'id': 4,
#     'position_group': 'Central Defender',
#     'name': 'Right Center Back',
#     'acronym': 'RCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 4,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 401795,
#    'team_id': 2027,
#    'id': 68697,
#    'first_name': 'Maya',
#    'last_name': 'Le Tissier',
#    'short_name': 'M. Le Tissier',
#    'birthday': '2002-04-18',
#    'trackable_object': 69823,
#    'gender': 'female'},
#   {'player_role': {'id': 9,
#     'position_group': 'Midfield',
#     'name': 'Left Midfield',
#     'acronym': 'LM'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 7,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101950,
#    'team_id': 2027,
#    'id': 62411,
#    'first_name': 'Ella',
#    'last_name': 'Toone',
#    'short_name': 'E. Toone',
#    'birthday': '1999-09-02',
#    'trackable_object': 63537,
#    'gender': 'female'},
#   {'player_role': {'id': 3,
#     'position_group': 'Central Defender',
#     'name': 'Left Center Back',
#     'acronym': 'LCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 21,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102129,
#    'team_id': 2027,
#    'id': 63767,
#    'first_name': 'Millie',
#    'last_name': 'Turner',
#    'short_name': 'M. Turner',
#    'birthday': '1996-07-07',
#    'trackable_object': 64893,
#    'gender': 'female'},
#   {'player_role': {'id': 12,
#     'position_group': 'Wide Attacker',
#     'name': 'Left Winger',
#     'acronym': 'LW'},
#    'start_time': '00:00:00',
#    'end_time': '01:14:20',
#    'number': 20,
#    'yellow_card': 0,
#    'red_card': 1,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 375204,
#    'team_id': 2029,
#    'id': 64066,
#    'first_name': 'Kirsty',
#    'last_name': 'Hanson',
#    'short_name': 'K. Hanson',
#    'birthday': '1998-04-17',
#    'trackable_object': 65192,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '01:05:53',
#    'end_time': None,
#    'number': 23,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153051,
#    'team_id': 2029,
#    'id': 22735,
#    'first_name': 'Adriana',
#    'last_name': 'Leon',
#    'short_name': 'A. Leon',
#    'birthday': '1992-10-02',
#    'trackable_object': 23420,
#    'gender': 'female'},
#   {'player_role': {'id': 10,
#     'position_group': 'Midfield',
#     'name': 'Right Midfield',
#     'acronym': 'RM'},
#    'start_time': '01:19:57',
#    'end_time': None,
#    'number': 20,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153059,
#    'team_id': 2027,
#    'id': 62505,
#    'first_name': 'Hinata',
#    'last_name': 'Miyazawa',
#    'short_name': 'H. Miyazawa',
#    'birthday': '1999-11-28',
#    'trackable_object': 63631,
#    'gender': 'female'},
#   {'player_role': {'id': 21,
#     'position_group': 'Midfield',
#     'name': 'Left Defensive Midfield',
#     'acronym': 'LDM'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 5,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 758945,
#    'team_id': 2029,
#    'id': 22624,
#    'first_name': 'Lucy',
#    'last_name': 'Staniforth',
#    'short_name': 'L. Staniforth',
#    'birthday': '1992-10-02',
#    'trackable_object': 23198,
#    'gender': 'female'},
#   {'player_role': {'id': 22,
#     'position_group': 'Midfield',
#     'name': 'Right Defensive Midfield',
#     'acronym': 'RDM'},
#    'start_time': '01:34:58',
#    'end_time': None,
#    'number': 8,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 758944,
#    'team_id': 2029,
#    'id': 63765,
#    'first_name': 'Jordan',
#    'last_name': 'Nobbs',
#    'short_name': 'J. Nobbs',
#    'birthday': '1992-12-08',
#    'trackable_object': 64891,
#    'gender': 'female'},
#   {'player_role': {'id': 19,
#     'position_group': 'Full Back',
#     'name': 'Left Back',
#     'acronym': 'LB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 3,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153054,
#    'team_id': 2027,
#    'id': 68681,
#    'first_name': 'Gabrielle',
#    'last_name': 'George',
#    'short_name': 'G. George',
#    'birthday': '1997-02-02',
#    'trackable_object': 69807,
#    'gender': 'female'},
#   {'player_role': {'id': 20,
#     'position_group': 'Full Back',
#     'name': 'Right Back',
#     'acronym': 'RB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 2,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101991,
#    'team_id': 2029,
#    'id': 68672,
#    'first_name': 'Sarah Emma',
#    'last_name': 'Mayling',
#    'short_name': 'S. Mayling',
#    'birthday': '1997-03-20',
#    'trackable_object': 69798,
#    'gender': 'female'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 9,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 375205,
#    'team_id': 2029,
#    'id': 22618,
#    'first_name': 'Rachel',
#    'last_name': 'Daly',
#    'short_name': 'R. Daly',
#    'birthday': '1991-12-06',
#    'trackable_object': 23186,
#    'gender': 'female'},
#   {'player_role': {'id': 3,
#     'position_group': 'Central Defender',
#     'name': 'Left Center Back',
#     'acronym': 'LCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 6,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 198911,
#    'team_id': 2029,
#    'id': 22628,
#    'first_name': 'Rachel',
#    'last_name': 'Corsie',
#    'short_name': 'R. Corsie',
#    'birthday': '1989-08-17',
#    'trackable_object': 23206,
#    'gender': 'female'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '01:05:44',
#    'end_time': None,
#    'number': 28,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 485472,
#    'team_id': 2027,
#    'id': 68734,
#    'first_name': 'Rachel',
#    'last_name': 'Williams',
#    'short_name': 'R. Williams',
#    'birthday': '1988-01-10',
#    'trackable_object': 69860,
#    'gender': 'female'},
#   {'player_role': {'id': 12,
#     'position_group': 'Wide Attacker',
#     'name': 'Left Winger',
#     'acronym': 'LW'},
#    'start_time': '00:00:00',
#    'end_time': '01:10:17',
#    'number': 11,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102121,
#    'team_id': 2027,
#    'id': 68744,
#    'first_name': 'Leah',
#    'last_name': 'Galton',
#    'short_name': 'L. Galton',
#    'birthday': '1994-05-24',
#    'trackable_object': 69870,
#    'gender': 'female'},
#   {'player_role': {'id': 20,
#     'position_group': 'Full Back',
#     'name': 'Right Back',
#     'acronym': 'RB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 6,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101954,
#    'team_id': 2027,
#    'id': 57096,
#    'first_name': 'Hannah',
#    'last_name': 'Blundell',
#    'short_name': 'H. Blundell',
#    'birthday': '1994-05-25',
#    'trackable_object': 58222,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 91,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153058,
#    'team_id': 2027,
#    'id': 151604,
#    'first_name': 'Phallon',
#    'last_name': 'Tullis-Joyce',
#    'short_name': 'P. Tullis-Joyce',
#    'birthday': '1996-10-19',
#    'trackable_object': 153159,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 16,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 854887,
#    'team_id': 2027,
#    'id': 63932,
#    'first_name': 'Lisa Fjeldstad',
#    'last_name': 'Naalsund',
#    'short_name': 'L. Naalsund',
#    'birthday': '1995-06-11',
#    'trackable_object': 65058,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 14,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 897627,
#    'team_id': 2027,
#    'id': 22724,
#    'first_name': 'Jayde Yuk Fun',
#    'last_name': 'Riviere',
#    'short_name': 'J. Riviere',
#    'birthday': '2001-01-22',
#    'trackable_object': 23398,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 8,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153057,
#    'team_id': 2027,
#    'id': 68199,
#    'first_name': 'Irene ',
#    'last_name': 'Guerrero Sanmartín',
#    'short_name': 'Irene Guerrero',
#    'birthday': '1996-12-12',
#    'trackable_object': 69325,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 15,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153056,
#    'team_id': 2027,
#    'id': 64156,
#    'first_name': 'Gemma Jayne',
#    'last_name': 'Evans',
#    'short_name': 'G. Evans',
#    'birthday': '1996-08-01',
#    'trackable_object': 65282,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 25,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153055,
#    'team_id': 2027,
#    'id': 153392,
#    'first_name': 'Evie',
#    'last_name': 'Rabjohn',
#    'short_name': 'E. Rabjohn',
#    'birthday': '2005-04-28',
#    'trackable_object': 154947,
#    'gender': 'female'},
#   {'player_role': {'id': 0,
#     'position_group': 'Other',
#     'name': 'Goalkeeper',
#     'acronym': 'GK'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 27,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102122,
#    'team_id': 2027,
#    'id': 22622,
#    'first_name': 'Mary',
#    'last_name': 'Earps',
#    'short_name': 'M. Earps',
#    'birthday': '1993-03-07',
#    'trackable_object': 23194,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 17,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 401794,
#    'team_id': 2027,
#    'id': 22457,
#    'first_name': 'Lucía',
#    'last_name': 'García Córdoba',
#    'short_name': 'Lucía García',
#    'birthday': '1998-07-14',
#    'trackable_object': 22864,
#    'gender': 'female'},
#   {'player_role': {'id': 10,
#     'position_group': 'Midfield',
#     'name': 'Right Midfield',
#     'acronym': 'RM'},
#    'start_time': '00:00:00',
#    'end_time': '01:19:57',
#    'number': 12,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102126,
#    'team_id': 2027,
#    'id': 64166,
#    'first_name': 'Hayley',
#    'last_name': 'Ladd',
#    'short_name': 'H. Ladd',
#    'birthday': '1993-10-06',
#    'trackable_object': 65292,
#    'gender': 'female'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '00:00:00',
#    'end_time': '01:05:44',
#    'number': 23,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153053,
#    'team_id': 2027,
#    'id': 22555,
#    'first_name': '',
#    'last_name': 'Geyse',
#    'short_name': 'Geyse',
#    'birthday': '1998-03-27',
#    'trackable_object': 23060,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 22,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 946461,
#    'team_id': 2029,
#    'id': 62772,
#    'first_name': 'Simone',
#    'last_name': 'Magill',
#    'short_name': 'S. Magill',
#    'birthday': '1994-11-01',
#    'trackable_object': 63898,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 16,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102138,
#    'team_id': 2029,
#    'id': 68749,
#    'first_name': 'Olivia',
#    'last_name': 'McLoughlin',
#    'short_name': 'O. McLoughlin',
#    'birthday': '2004-10-15',
#    'trackable_object': 69875,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 33,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101989,
#    'team_id': 2029,
#    'id': 68670,
#    'first_name': 'Mayumi',
#    'last_name': 'Pacheco',
#    'short_name': 'M. Pacheco',
#    'birthday': '1998-08-25',
#    'trackable_object': 69796,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 18,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 644248,
#    'team_id': 2029,
#    'id': 424697,
#    'first_name': 'Georgia',
#    'last_name': 'Mullett',
#    'short_name': 'G. Mullett',
#    'birthday': '2005-09-16',
#    'trackable_object': 426254,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 21,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 375206,
#    'team_id': 2029,
#    'id': 59723,
#    'first_name': 'Anna Jessica',
#    'last_name': 'Leat',
#    'short_name': 'A. Leat',
#    'birthday': '2001-06-26',
#    'trackable_object': 60849,
#    'gender': 'female'},
#   {'player_role': {'id': 0,
#     'position_group': 'Other',
#     'name': 'Goalkeeper',
#     'acronym': 'GK'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 1,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153049,
#    'team_id': 2029,
#    'id': 63552,
#    'first_name': 'Daphne',
#    'last_name': 'van Domselaar',
#    'short_name': 'D. van Domselaar',
#    'birthday': '2000-03-06',
#    'trackable_object': 64678,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '00:00:00',
#    'end_time': '01:05:53',
#    'number': 7,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101982,
#    'team_id': 2029,
#    'id': 64130,
#    'first_name': 'Alisha',
#    'last_name': 'Lehmann',
#    'short_name': 'A. Lehmann',
#    'birthday': '1999-01-21',
#    'trackable_object': 65256,
#    'gender': 'female'},
#   {'player_role': {'id': 11,
#     'position_group': 'Midfield',
#     'name': 'Attacking Midfield',
#     'acronym': 'AM'},
#    'start_time': '00:00:00',
#    'end_time': '00:45:00',
#    'number': 19,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101994,
#    'team_id': 2029,
#    'id': 68675,
#    'first_name': 'Laura Madison',
#    'last_name': 'Blindkilde Brown',
#    'short_name': 'L. Blindkilde Brown',
#    'birthday': '2003-09-09',
#    'trackable_object': 69801,
#    'gender': 'female'}],
#  'status': 'closed',
#  'home_team_side': ['left_to_right', 'right_to_left'],
#  'ball': {'trackable_object': 55},
#  'pitch_length': 105,
#  'pitch_width': 68}

# %%
home_id = match_data['home_team']['id']
away_id = match_data['away_team']['id']

# %%
home_p_ids = [p['id'] for p in match_data['players'] if p['team_id'] == home_id]
away_p_ids = [p['id'] for p in match_data['players'] if p['team_id'] == away_id]

# %%
match_event_df = events_df[(events_df['sk_match_id'] == match_id) & (events_df['type_primary'] == 'pass')]

# %%
# field_length = 105
# field_width = 68

# # Adjust coordinates to center [0, 0]
# match_event_df['pass_endlocation_x'] =  match_event_df['pass_endlocation_x'] * field_length / 100 - field_length / 2
# match_event_df['pass_endlocation_y'] =  field_width / 2 - match_event_df['pass_endlocation_y'] * field_width / 100

# match_event_df['location_x'] =  match_event_df['location_x'] * field_length / 100 - field_length / 2
# match_event_df['location_y'] =  field_width / 2 - match_event_df['location_y'] * field_width / 100

# %%
match_event_df.head()
# Out:
#         sk_match_id  frame  minute    player_name pass_recipient_name  \
# 106932      1133203    107       0        H. Ladd            K. Zelem
# 106933      1133203    126       0       K. Zelem           G. George
# 106934      1133203    158       0      G. George           M. Turner
# 106935      1133203    191       0      M. Turner       M. Le Tissier
# 106936      1133203    222       0  M. Le Tissier           M. Turner
#
#         pass_recipient_id pass_recipient_position  sk_player_id  pass_angle  \
# 106932             134338                     DMF         64166        -153
# 106933             289914                      LB         68743        -104
# 106934             258929                     LCB         68681         104
# 106935             559233                     RCB         63767          93
# 106936             258929                     LCB         68697         -88
#
#        type_primary  location_x  location_y  pass_accurate  \
# 106932         pass          51          50           True
# 106933         pass          38          40           True
# 106934         pass          33          10           True
# 106935         pass          29          39           True
# 106936         pass          28          70           True
#
#         pass_endlocation_x  pass_endlocation_y  \
# 106932                  38                  40
# 106933                  33                  10
# 106934                  29                  39
# 106935                  28                  70
# 106936                  29                  37
#
#                               type_secondary player_position
# 106932     [back_pass, short_or_medium_pass]            RCMF
# 106933  [lateral_pass, short_or_medium_pass]             DMF
# 106934  [lateral_pass, short_or_medium_pass]              LB
# 106935  [lateral_pass, short_or_medium_pass]             LCB
# 106936  [lateral_pass, short_or_medium_pass]             RCB

# %%
match_event_df['team'] = match_event_df['sk_player_id'].apply(lambda x: 'home' if x in home_p_ids else
                                                                  'away' if x in away_p_ids else None)

# %%
tracking_path = f'data/FA/tracking/{match_id}.jsonl'

# %%
with jsonlines.open(tracking_path, 'r') as file:
    frame_to_period = {line['frame']: line['period'] for line in file}

# Map the period to each row using the pre-built dictionary
match_event_df['period'] = match_event_df['frame'].map(frame_to_period)

# %%
# wt_json =[p for p in match_info['players'] if p['player_role']['position_group'] == 'Wide Attacker']

# %%
# wt_info = [p['first_name']+ ' '+ p['last_name'] for p in wt_json]

# %%
# wt_ids = [p['id'] for p in wt_json]
# wt_ids

# %%
match_event_df['in_wide_channel'] = match_event_df.apply(
    lambda row: True if row['pass_endlocation_x'] >= 66 and (row['pass_endlocation_y'] >= 81 or row['pass_endlocation_y'] <= 19) and row['pass_recipient_id'] != 0 else False, axis = 1)

# %%
match_event_df.in_wide_channel.value_counts()
# Out:
# in_wide_channel
# False    675
# True     100
# Name: count, dtype: int64

# %%
match_event_df[match_event_df['in_wide_channel'] == True]
# Out:
#         sk_match_id  frame  minute          player_name  pass_recipient_name  \
# 106975      1133203   1199       1            G. George           S. Mayling
# 106977      1133203   1245       1            L. Galton             E. Toone
# 106978      1133203   1274       1             E. Toone            L. Galton
# 107051      1133203   3688       5        M. Le Tissier            D. Turner
# 107067      1133203   4214       6            L. Galton            G. George
# 107070      1133203   4249       6            G. George            L. Galton
# 107079      1133203   4453       7            L. Galton             E. Toone
# 107129      1133203   6514      10             K. Zelem            L. Galton
# 107133      1133203   6784      11              R. Daly  L. Blindkilde Brown
# 107167      1133203   7810      12             E. Toone            L. Galton
# 107226      1133203  10346      17            D. Turner            K. Hanson
# 107227      1133203  10369      17            K. Hanson  L. Blindkilde Brown
# 107248      1133203  10983      18          H. Blundell              H. Ladd
# 107249      1133203  11001      18              H. Ladd             K. Zelem
# 107250      1133203  11013      18             K. Zelem              H. Ladd
# 107258      1133203  11222      18            M. Turner             K. Zelem
# 107259      1133203  11270      18             K. Zelem            L. Galton
# 107260      1133203  11289      18            L. Galton            G. George
# 107263      1133203  11369      18             E. Toone            G. George
# 107266      1133203  11408      18            G. George       Geyse Ferreira
# 107271      1133203  11552      19             E. Toone            G. George
# 107332      1133203  13129      21             E. Toone         Lucía García
# 107337      1133203  13402      22       Geyse Ferreira            G. George
# 107370      1133203  14800      24          H. Blundell         Lucía García
# 107389      1133203  15396      25            K. Hanson            D. Turner
# 308958      1133203  17400      28            K. Hanson              R. Daly
# 308992      1133203  18413      30             E. Toone            L. Galton
# 309006      1133203  19052      31         Lucía García          H. Blundell
# 309007      1133203  19070      31          H. Blundell       Geyse Ferreira
# 309019      1133203  19326      32             E. Toone            G. George
# 309075      1133203  21187      35       Geyse Ferreira         Lucía García
# 309091      1133203  21488      35            L. Parker           A. Lehmann
# 309102      1133203  21806      36              H. Ladd            L. Galton
# 309103      1133203  21900      36            L. Galton             K. Zelem
# 309112      1133203  22158      36        M. Le Tissier         Lucía García
# 309138      1133203  23267      38        L. Staniforth           S. Mayling
# 309161      1133203  23895      39            G. George            L. Galton
# 309205      1133203  25085      41            M. Turner            G. George
# 309213      1133203  25230      41       Geyse Ferreira         Lucía García
# 309229      1133203  25398      42             K. Zelem         Lucía García
# 309695             230789                      RB         22618          84
# 309696              11461                      CF         68672        -149
# 309713             369460                      LW         68734         -60
# 309724             401062                    LCMF         63767         -31
# 309762              11203                      RW         62411          40
# 309813             263847                      RB          <NA>         -32
# 309818             369460                      LW         62411         -37
# 309874             289914                      LB         62411         -50
# 309903             369460                      LW         68743         -48
# 309904             289914                      LB         22457          18
# 309925             476718                    RCMF         22608          20
# 309928             369460                      LW         62505         -80
# 309943              11203                      RW         57096          27
# 309966              11203                      RW         57096          18
# 309973             289914                      LB         68743         -82
# 309974             369460                      LW         68681         -20
# 310003              62833                     LCB         62411          58
# 310024              11203                      RW         57096          45
# 310036             401062                    LCMF         68681           0
# 310077             543994                      LW         63765          32
# 310107             138911                      RW         63765         -13
# 310110              11172                    RCMF         22735        -174
# 310114              11172                    RCMF         68672          24
# 310126             134338                     DMF         68672         -45
#
#        type_primary  location_x  location_y  pass_accurate  \
# 106975         pass          35          12          False
# 106977         pass          71          20           True
# 106978         pass          77           4           True
# 107051         pass          42          68          False
# 107067         pass          70          19           True
# 107070         pass          77           8           True
# 107079         pass          65           2           True
# 107129         pass          65          39           True
# 107133         pass          36          13          False
# 107167         pass          62          26           True
# 107226         pass          60           9           True
# 107227         pass          70           3           True
# 107248         pass          74          98           True
# 107249         pass          72          82           True
# 107250         pass          70          81           True
# 107258         pass          59          41           True
# 107259         pass          70          18           True
# 107260         pass          75          16           True
# 107263         pass          82          14           True
# 107266         pass          97          12           True
# 107271         pass          94          11           True
# 107332         pass          70          72           True
# 107337         pass          99          71           True
# 107370         pass          58          94           True
# 107389         pass          74          13           True
# 308958         pass          52           6           True
# 308992         pass          43          22           True
# 309006         pass          67          86           True
# 309007         pass          66          96           True
# 309019         pass          68          50           True
# 309075         pass          83          35           True
# 309091         pass          58          97          False
# 309102         pass          40           8           True
# 309103         pass          72          15           True
# 309112         pass          46          61           True
# 309138         pass          64          80           True
# 309161         pass          35           5           True
# 309205         pass          60          26           True
# 309213         pass          81          94           True
# 309229         pass          77          86           True
# 309230         pass          84          96           True
# 309231         pass          73          88           True
# 309247         pass          31          69           True
# 309248         pass          67          92           True
# 309263         pass          81          90          False
# 309275         pass          72          90           True
# 309299         pass          93          95           True
# 309311         pass          35          26           True
# 309326         pass          56          82          False
# 309364         pass          63          94           True
# 309367         pass          92          91           True
# 309379         pass          92          84           True
# 309386         pass          83          87           True
# 309387         pass          75          96           True
# 309409         pass          62          97          False
# 309413         pass          77          83           True
# 309419         pass          79          69          False
# 309448         pass          44          24           True
# 309453         pass          81          15           True
# 309454         pass          88          10           True
# 309457         pass          88          11           True
# 309458         pass          86           6           True
# 309459         pass          89          14           True
# 309483         pass          59          13           True
# 309484         pass          77           2           True
# 309495         pass          63          40           True
# 309550         pass          72          61           True
# 309584         pass          43          52           True
# 309619         pass          65          75           True
# 309634         pass          62          92           True
# 309651         pass          72          22           True
# 309652         pass          75           8           True
# 309653         pass          88           4           True
# 309682         pass          58          97           True
# 309683         pass          69          97          False
pass, recovery, counterpressing_recovery, short_or_medium_pass]
# 106978                                                    [forward_pass, progressive_pass, short_or_medium_pass]
# 107051                                                      [forward_pass, long_pass, loss, pass_to_final_third]
# 107067                                                                      [forward_pass, short_or_medium_pass]
# 107070                                                                         [back_pass, short_or_medium_pass]
# 107079               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass, under_pressure]
# 107129                                                 [lateral_pass, pass_to_final_third, short_or_medium_pass]
# 107133                                          [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 107167                                 [forward_pass, pass_to_final_third, short_or_medium_pass, under_pressure]
# 107226                                                 [forward_pass, pass_to_final_third, short_or_medium_pass]
# 107227                                                                      [forward_pass, short_or_medium_pass]
# 107248                                                [recovery, counterpressing_recovery, short_or_medium_pass]
# 107249                                                                         [back_pass, short_or_medium_pass]
# 107250                                                                         [back_pass, short_or_medium_pass]
# 107258                                                 [lateral_pass, pass_to_final_third, short_or_medium_pass]
# 107259                                                                      [forward_pass, short_or_medium_pass]
# 107260                                                                       [linkup_play, short_or_medium_pass]
# 107263                                                                      [forward_pass, short_or_medium_pass]
# 107266                                                                          [cross, lateral_pass, long_pass]
# 107271                                                               [back_pass, recovery, short_or_medium_pass]
# 107332                                                                      [forward_pass, short_or_medium_pass]
# 107337                                                            [cross, lateral_pass, long_pass, touch_in_box]
# 107370                                                 [forward_pass, pass_to_final_third, short_or_medium_pass]
# 107389                                  [forward_pass, recovery, counterpressing_recovery, short_or_medium_pass]
# 308958                                          [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 308992               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass, under_pressure]
# 309006                                                                                    [short_or_medium_pass]
# 309007                                                 [forward_pass, pass_to_final_third, short_or_medium_pass]
# 309019                                                               [forward_pass, long_pass, progressive_pass]
# 309075                                                                      [forward_pass, short_or_medium_pass]
# 309091                               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309102                               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309103                                                                         [back_pass, short_or_medium_pass]
# 309112                                                            [forward_pass, long_pass, pass_to_final_third]
# 309138                                                 [forward_pass, pass_to_final_third, short_or_medium_pass]
# 309161                                          [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 309205                                                 [forward_pass, pass_to_final_third, short_or_medium_pass]
# 309213                                                                      [forward_pass, short_or_medium_pass]
# 309229                                                                      [forward_pass, short_or_medium_pass]
# 309230                                                                         [back_pass, short_or_medium_pass]
# 309231                                                    [forward_pass, progressive_pass, short_or_medium_pass]
# 309247                               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309248                                                    [forward_pass, progressive_pass, short_or_medium_pass]
# 309263                                                                   [back_pass, loss, short_or_medium_pass]
# 309275                                                                      [forward_pass, short_or_medium_pass]
# 309299                                                                         [back_pass, short_or_medium_pass]
# 309311                                          [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 309326                                                            [forward_pass, long_pass, pass_to_final_third]
# 309364                               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309367                                                                         [back_pass, short_or_medium_pass]
# 309379                                                                         [back_pass, short_or_medium_pass]
# 309386                                                                         [back_pass, short_or_medium_pass]
# 309387                                                                                    [short_or_medium_pass]
# 309409                                           [forward_pass, loss, pass_to_final_third, short_or_medium_pass]
# 309413                                                                                    [short_or_medium_pass]
# 309419                                                                [lateral_pass, loss, short_or_medium_pass]
# 309448                          [forward_pass, long_pass, pass_to_final_third, progressive_pass, under_pressure]
# 309453                                                            [forward_pass, recovery, short_or_medium_pass]
# 309454                                                                         [back_pass, short_or_medium_pass]
# 309457                                                                                    [short_or_medium_pass]
# 309458                                                                                    [short_or_medium_pass]
# 309459                                                                      [forward_pass, short_or_medium_pass]
# 309483                                 [forward_pass, pass_to_final_third, short_or_medium_pass, under_pressure]
# 309484                                                            [back_pass, linkup_play, short_or_medium_pass]
# 309495                                                 [lateral_pass, pass_to_final_third, short_or_medium_pass]
# 309550                     [lateral_pass, recovery, counterpressing_recovery, short_or_medium_pass, shot_assist]
# 309584                                          [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 309619                                                 [lateral_pass, pass_to_final_third, short_or_medium_pass]
# 309634                               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309651                                                                                    [short_or_medium_pass]
# 309652                                                                      [forward_pass, short_or_medium_pass]
# 309653                                                                         [back_pass, short_or_medium_pass]
# 309682                                                 [forward_pass, pass_to_final_third, short_or_medium_pass]
# 309683                                                                              [loss, short_or_medium_pass]
# 309694                                                                                    [short_or_medium_pass]
# 309695                                                                                    [short_or_medium_pass]
# 309696                                                                         [back_pass, short_or_medium_pass]
# 309713                                       [lateral_pass, pass_to_final_third, recovery, short_or_medium_pass]
# 309724                               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309762                                                                                 [forward_pass, long_pass]
# 309813                                                 [forward_pass, pass_to_final_third, short_or_medium_pass]
# 309818                                                 [forward_pass, pass_to_final_third, short_or_medium_pass]
# 309874                                                                      [lateral_pass, short_or_medium_pass]
# 309903                                                            [lateral_pass, long_pass, pass_to_final_third]
# 309904                                                                      [forward_pass, short_or_medium_pass]
# 309925                                                            [forward_pass, recovery, short_or_medium_pass]
# 309928                                                                          [cross, lateral_pass, long_pass]
# 309943                               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309966                               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309973                                                                      [lateral_pass, short_or_medium_pass]
# 309974                                                                      [forward_pass, short_or_medium_pass]
# 310003                                           [lateral_pass, loss, pass_to_final_third, short_or_medium_pass]
# 310024                                                                      [forward_pass, short_or_medium_pass]
# 310036                               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 310077  [forward_pass, head_pass, pass_to_final_third, recovery, counterpressing_recovery, short_or_medium_pass]
# 310107                                                                      [forward_pass, short_or_medium_pass]
# 310110                                                                         [back_pass, short_or_medium_pass]
# 310114                                [forward_pass, long_pass, pass_to_final_third, progressive_pass, recovery]
# 310126                                                         [loss, pass_to_final_third, short_or_medium_pass]
#
#        player_position  team  period  in_wide_channel
# 106975              LB  away     1.0             True
# 106977              LW  away     1.0             True
# 106978            LCMF  away     1.0             True
# 107051             RCB  away     1.0             True
# 107067              LW  away     1.0             True
# 107070              LB  away     1.0             True
# 107079              LW  away     1.0             True
# 107129             DMF  away     1.0             True
# 107133              CF  home     1.0             True
# 107167            LCMF  away     1.0             True
# 107226              LB  home     1.0             True
# 107227            LAMF  home     1.0             True
# 107248              RB  away     1.0             True
# 107249            RCMF  away     1.0             True
# 107250             DMF  away     1.0             True
# 107258             LCB  away     1.0             True
# 107259             DMF  away     1.0             True
# 107260              LW  away     1.0             True
# 107263            LCMF  away     1.0             True
# 107266              LB  away     1.0             True
# 107271            LCMF  away     1.0             True
# 107332            LCMF  away     1.0             True
# 107337              CF  away     1.0             True
# 107370              RB  away     1.0             True
# 107389            LAMF  home     1.0             True
# 308958            LAMF  home     1.0             True
# 308992            LCMF  away     1.0             True
# 309006              RW  away     1.0             True
# 309007              RB  away     1.0             True
# 309019            LCMF  away     1.0             True
# 309075              CF  away     1.0             True
# 309091            RDMF  home     1.0             True
# 309102            RCMF  away     1.0             True
# 309103              LW  away     1.0             True
# 309112             RCB  away     1.0             True
# 309138            LDMF  home     1.0             True
# 309161              LB  away     1.0             True
# 309205             LCB  away     1.0             True
# 309213              CF  away     1.0             True
# 309229             DMF  away     1.0             True
# 309230              RW  away     1.0             True
# 309231             DMF  away     1.0             True
# 309247             RCB  home     1.0             True
# 309248              RB  home     1.0             True
# 309263             AMF  home     1.0             True
# 309275            LDMF  home     1.0             True
# 309299            RAMF  home     1.0             True
# 309311             LCB  home     2.0             True
# 309326             DMF  away     2.0             True
# 309364             RCB  away     2.0             True
# 309367              CF  away     2.0             True
# 309379              CF  away     2.0             True
# 309386              RW  away     2.0             True
# 309387              RB  away     2.0             True
# 309409             AMF  home     2.0             True
# 309413              CF  home     2.0             True
# 309419            LDMF  home     2.0             True
# 309448             LCB  away     2.0             True
# 309453              LB  away     2.0             True
# 309454              LW  away     2.0             True
# 309457            LCMF  away     2.0             True
# 309458              LW  away     2.0             True
# 309459              LB  away     2.0             True
# 309483             LCB  away     2.0             True
# 309484              LW  away     2.0             True
# 309495             DMF  away     2.0             True
# 309550            LDMF  home     2.0             True
# 309584             RCB  away     2.0             True
# 309619            RAMF  home     2.0             True
# 309634            RDMF  home     2.0             True
# 309651            LAMF  home     2.0             True
# 309652            LDMF  home     2.0             True
# 309653              LB  home     2.0             True
# 309682              RB  home     2.0             True
# 309683            RAMF  home     2.0             True
# 309694            RAMF  home     2.0             True
# 309695              CF  home     2.0             True
# 309696              RB  home     2.0             True
# 309713              CF  away     2.0             True
# 309724             LCB  away     2.0             True
# 309762            LCMF  away     2.0             True
# 309813            <NA>  None     2.0             True
# 309818            LCMF  away     2.0             True
# 309874            LCMF  away     2.0             True
# 309903             DMF  away     2.0             True
# 309904              LW  away     2.0             True
# 309925              RW  away     2.0             True
# 309928            RCMF  away     2.0             True
# 309943              RB  away     2.0             True
# 309966              RB  away     2.0             True
# 309973             DMF  away     2.0             True
# 309974              LB  away     2.0             True
# 310003            LCMF  away     2.0             True
# 310024              RB  away     2.0             True
# 310036              LB  away     2.0             True
# 310077            RCMF  home     2.0             True
# 310107            RCMF  home     2.0             True
# 310110              RW  home     2.0             True
# 310114              RB  home     2.0             True
# 310126              RB  home     2.0             True

# %%
match_event_df[match_event_df['frame'] == 21900]
# Out:
#         sk_match_id  frame  minute player_name pass_recipient_name  \
# 309103      1133203  21900      36   L. Galton            K. Zelem
#
#         pass_recipient_id pass_recipient_position  sk_player_id  pass_angle  \
# 309103             134338                     DMF         68744         180
#
#        type_primary  location_x  location_y  pass_accurate  \
# 309103         pass          72          15           True
#
#         pass_endlocation_x  pass_endlocation_y  \
# 309103                  67                  15
#
#                            type_secondary player_position  team  period  \
# 309103  [back_pass, short_or_medium_pass]              LW  away     1.0
#
#         in_wide_channel
# 309103             True
