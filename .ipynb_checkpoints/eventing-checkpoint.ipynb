# %%
from mplsoccer.pitch import Pitch
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import os
import json
import math
import jsonlines
from skillcorner.client import SkillcornerClient
import pyarrow.parquet as pq

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
def load_json_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# %%
def load_jsonl_file(file_path):
    with jsonlines.open(file_path, 'r') as file:
        data = [line for line in file if line['timestamp'] is not None]
    return data

# %%
def explode_data(row):
    # Extract player data into a DataFrame
    players = pd.DataFrame(row['player_data'])
    players['object'] = 'player'
    
    # Extract ball data into a DataFrame
    ball = pd.DataFrame([row['ball_data']])
    ball['object'] = 'ball'
    ball['player_id'] = 0  
   
    # Combine player and ball data
    combined = pd.concat([players, ball], ignore_index=True)
    
    # Add other columns from the original row
    for col in row.index:
        if col not in ['player_data', 'ball_data']:
            combined[col] = row[col]
    
    return combined

# %%
def euclidean_distance(x1, y1, x2, y2):
    """Calculate the Euclidean distance between two points."""
    return math.sqrt((x1 - x2)**2 + (y1 - y2)**2)

# %%
match_id = 1133203
tracking_path = f'data/FA/tracking/{match_id}.jsonl'

file_path = f'data/FA/match/{match_id}.json'
match_data = load_json_file(file_path)
file_path = 'data/wyscout_events.parquet'
events_df = pd.read_parquet(file_path)
match_event_df = events_df[events_df['sk_match_id'] == match_id].reset_index(drop = True)

# %%
match_data
# Out:
# {'id': 1133203,
#  'home_team_score': 1,
#  'away_team_score': 2,
#  'date_time': '2023-10-01T11:30:00Z',
#  'stadium': {'id': 488,
#   'name': 'Villa Park',
#   'city': 'Birmingham',
#   'capacity': 42682},
#  'home_team': {'id': 2029,
#   'name': 'Aston Villa, Women',
#   'short_name': 'Aston Villa',
#   'acronym': 'AVL'},
#  'home_team_kit': {'id': 5450,
#   'team_id': 2029,
#   'season': {'id': 6,
#    'start_year': 2019,
#    'end_year': 2020,
#    'name': '2019/2020'},
#   'name': 'Home',
#   'jersey_color': '#a50521',
#   'number_color': '#ffffff'},
#  'away_team': {'id': 2027,
#   'name': 'Manchester United, Women',
#   'short_name': 'Man Utd, W',
#   'acronym': 'MUN'},
#  'away_team_kit': {'id': 6537,
#   'team_id': 2027,
#   'season': {'id': 8,
#    'start_year': 2021,
#    'end_year': 2022,
#    'name': '2021/2022'},
#   'name': 'Away',
#   'jersey_color': '#ffffff',
#   'number_color': '#ff0000'},
#  'home_team_coach': None,
#  'away_team_coach': None,
#  'competition_edition': {'id': 574,
#   'competition': {'id': 127,
#    'area': 'ENG',
#    'name': 'FA Women`s Super League',
#    'gender': 'female',
#    'age_group': 'adult'},
#   'season': {'id': 28,
#    'start_year': 2023,
#    'end_year': 2024,
#    'name': '2023/2024'},
#   'name': 'ENG - FA Women`s Super League - 2023/2024'},
#  'competition_round': {'id': 1885,
#   'name': 'Round 1',
#   'round_number': 1,
#   'potential_overtime': False},
#  'referees': [],
#  'players': [{'player_role': {'id': 7,
#     'position_group': 'Midfield',
#     'name': 'Defensive Midfield',
#     'acronym': 'DM'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 10,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102120,
#    'team_id': 2027,
#    'id': 68743,
#    'first_name': 'Katie',
#    'last_name': 'Zelem',
#    'short_name': 'K. Zelem',
#    'birthday': '1996-01-20',
#    'trackable_object': 69869,
#    'gender': 'female'},
#   {'player_role': {'id': 19,
#     'position_group': 'Full Back',
#     'name': 'Left Back',
#     'acronym': 'LB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 14,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 375202,
#    'team_id': 2029,
#    'id': 68680,
#    'first_name': 'Danielle',
#    'last_name': 'Turner',
#    'short_name': 'D. Turner',
#    'birthday': '1991-09-10',
#    'trackable_object': 69806,
#    'gender': 'female'},
#   {'player_role': {'id': 4,
#     'position_group': 'Central Defender',
#     'name': 'Right Center Back',
#     'acronym': 'RCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 4,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 198947,
#    'team_id': 2029,
#    'id': 68719,
#    'first_name': 'Anna',
#    'last_name': 'Patten',
#    'short_name': 'A. Patten',
#    'birthday': '1999-04-20',
#    'trackable_object': 69845,
#    'gender': 'female'},
#   {'player_role': {'id': 22,
#     'position_group': 'Midfield',
#     'name': 'Right Defensive Midfield',
#     'acronym': 'RDM'},
#    'start_time': '00:00:00',
#    'end_time': '01:34:58',
#    'number': 15,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153050,
#    'team_id': 2029,
#    'id': 68661,
#    'first_name': 'Lucy',
#    'last_name': 'Parker',
#    'short_name': 'L. Parker',
#    'birthday': '1998-11-18',
#    'trackable_object': 69787,
#    'gender': 'female'},
#   {'player_role': {'id': 11,
#     'position_group': 'Midfield',
#     'name': 'Attacking Midfield',
#     'acronym': 'AM'},
#    'start_time': '00:45:00',
#    'end_time': None,
#    'number': 17,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153052,
#    'team_id': 2029,
#    'id': 62646,
#    'first_name': 'Ebony',
#    'last_name': 'Salmon',
#    'short_name': 'E. Salmon',
#    'birthday': '2001-01-27',
#    'trackable_object': 63772,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '01:10:17',
#    'end_time': None,
#    'number': 22,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 401798,
#    'team_id': 2027,
#    'id': 22608,
#    'first_name': 'Nikita',
#    'last_name': 'Parris',
#    'short_name': 'N. Parris',
#    'birthday': '1994-03-10',
#    'trackable_object': 23166,
#    'gender': 'female'},
#   {'player_role': {'id': 4,
#     'position_group': 'Central Defender',
#     'name': 'Right Center Back',
#     'acronym': 'RCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 4,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 401795,
#    'team_id': 2027,
#    'id': 68697,
#    'first_name': 'Maya',
#    'last_name': 'Le Tissier',
#    'short_name': 'M. Le Tissier',
#    'birthday': '2002-04-18',
#    'trackable_object': 69823,
#    'gender': 'female'},
#   {'player_role': {'id': 9,
#     'position_group': 'Midfield',
#     'name': 'Left Midfield',
#     'acronym': 'LM'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 7,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101950,
#    'team_id': 2027,
#    'id': 62411,
#    'first_name': 'Ella',
#    'last_name': 'Toone',
#    'short_name': 'E. Toone',
#    'birthday': '1999-09-02',
#    'trackable_object': 63537,
#    'gender': 'female'},
#   {'player_role': {'id': 3,
#     'position_group': 'Central Defender',
#     'name': 'Left Center Back',
#     'acronym': 'LCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 21,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102129,
#    'team_id': 2027,
#    'id': 63767,
#    'first_name': 'Millie',
#    'last_name': 'Turner',
#    'short_name': 'M. Turner',
#    'birthday': '1996-07-07',
#    'trackable_object': 64893,
#    'gender': 'female'},
#   {'player_role': {'id': 12,
#     'position_group': 'Wide Attacker',
#     'name': 'Left Winger',
#     'acronym': 'LW'},
#    'start_time': '00:00:00',
#    'end_time': '01:14:20',
#    'number': 20,
#    'yellow_card': 0,
#    'red_card': 1,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 375204,
#    'team_id': 2029,
#    'id': 64066,
#    'first_name': 'Kirsty',
#    'last_name': 'Hanson',
#    'short_name': 'K. Hanson',
#    'birthday': '1998-04-17',
#    'trackable_object': 65192,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '01:05:53',
#    'end_time': None,
#    'number': 23,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153051,
#    'team_id': 2029,
#    'id': 22735,
#    'first_name': 'Adriana',
#    'last_name': 'Leon',
#    'short_name': 'A. Leon',
#    'birthday': '1992-10-02',
#    'trackable_object': 23420,
#    'gender': 'female'},
#   {'player_role': {'id': 10,
#     'position_group': 'Midfield',
#     'name': 'Right Midfield',
#     'acronym': 'RM'},
#    'start_time': '01:19:57',
#    'end_time': None,
#    'number': 20,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153059,
#    'team_id': 2027,
#    'id': 62505,
#    'first_name': 'Hinata',
#    'last_name': 'Miyazawa',
#    'short_name': 'H. Miyazawa',
#    'birthday': '1999-11-28',
#    'trackable_object': 63631,
#    'gender': 'female'},
#   {'player_role': {'id': 21,
#     'position_group': 'Midfield',
#     'name': 'Left Defensive Midfield',
#     'acronym': 'LDM'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 5,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 758945,
#    'team_id': 2029,
#    'id': 22624,
#    'first_name': 'Lucy',
#    'last_name': 'Staniforth',
#    'short_name': 'L. Staniforth',
#    'birthday': '1992-10-02',
#    'trackable_object': 23198,
#    'gender': 'female'},
#   {'player_role': {'id': 22,
#     'position_group': 'Midfield',
#     'name': 'Right Defensive Midfield',
#     'acronym': 'RDM'},
#    'start_time': '01:34:58',
#    'end_time': None,
#    'number': 8,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 758944,
#    'team_id': 2029,
#    'id': 63765,
#    'first_name': 'Jordan',
#    'last_name': 'Nobbs',
#    'short_name': 'J. Nobbs',
#    'birthday': '1992-12-08',
#    'trackable_object': 64891,
#    'gender': 'female'},
#   {'player_role': {'id': 19,
#     'position_group': 'Full Back',
#     'name': 'Left Back',
#     'acronym': 'LB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 3,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153054,
#    'team_id': 2027,
#    'id': 68681,
#    'first_name': 'Gabrielle',
#    'last_name': 'George',
#    'short_name': 'G. George',
#    'birthday': '1997-02-02',
#    'trackable_object': 69807,
#    'gender': 'female'},
#   {'player_role': {'id': 20,
#     'position_group': 'Full Back',
#     'name': 'Right Back',
#     'acronym': 'RB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 2,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101991,
#    'team_id': 2029,
#    'id': 68672,
#    'first_name': 'Sarah Emma',
#    'last_name': 'Mayling',
#    'short_name': 'S. Mayling',
#    'birthday': '1997-03-20',
#    'trackable_object': 69798,
#    'gender': 'female'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 9,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 375205,
#    'team_id': 2029,
#    'id': 22618,
#    'first_name': 'Rachel',
#    'last_name': 'Daly',
#    'short_name': 'R. Daly',
#    'birthday': '1991-12-06',
#    'trackable_object': 23186,
#    'gender': 'female'},
#   {'player_role': {'id': 3,
#     'position_group': 'Central Defender',
#     'name': 'Left Center Back',
#     'acronym': 'LCB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 6,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 198911,
#    'team_id': 2029,
#    'id': 22628,
#    'first_name': 'Rachel',
#    'last_name': 'Corsie',
#    'short_name': 'R. Corsie',
#    'birthday': '1989-08-17',
#    'trackable_object': 23206,
#    'gender': 'female'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '01:05:44',
#    'end_time': None,
#    'number': 28,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 485472,
#    'team_id': 2027,
#    'id': 68734,
#    'first_name': 'Rachel',
#    'last_name': 'Williams',
#    'short_name': 'R. Williams',
#    'birthday': '1988-01-10',
#    'trackable_object': 69860,
#    'gender': 'female'},
#   {'player_role': {'id': 12,
#     'position_group': 'Wide Attacker',
#     'name': 'Left Winger',
#     'acronym': 'LW'},
#    'start_time': '00:00:00',
#    'end_time': '01:10:17',
#    'number': 11,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102121,
#    'team_id': 2027,
#    'id': 68744,
#    'first_name': 'Leah',
#    'last_name': 'Galton',
#    'short_name': 'L. Galton',
#    'birthday': '1994-05-24',
#    'trackable_object': 69870,
#    'gender': 'female'},
#   {'player_role': {'id': 20,
#     'position_group': 'Full Back',
#     'name': 'Right Back',
#     'acronym': 'RB'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 6,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101954,
#    'team_id': 2027,
#    'id': 57096,
#    'first_name': 'Hannah',
#    'last_name': 'Blundell',
#    'short_name': 'H. Blundell',
#    'birthday': '1994-05-25',
#    'trackable_object': 58222,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 91,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153058,
#    'team_id': 2027,
#    'id': 151604,
#    'first_name': 'Phallon',
#    'last_name': 'Tullis-Joyce',
#    'short_name': 'P. Tullis-Joyce',
#    'birthday': '1996-10-19',
#    'trackable_object': 153159,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 16,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 854887,
#    'team_id': 2027,
#    'id': 63932,
#    'first_name': 'Lisa Fjeldstad',
#    'last_name': 'Naalsund',
#    'short_name': 'L. Naalsund',
#    'birthday': '1995-06-11',
#    'trackable_object': 65058,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 14,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 897627,
#    'team_id': 2027,
#    'id': 22724,
#    'first_name': 'Jayde Yuk Fun',
#    'last_name': 'Riviere',
#    'short_name': 'J. Riviere',
#    'birthday': '2001-01-22',
#    'trackable_object': 23398,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 8,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153057,
#    'team_id': 2027,
#    'id': 68199,
#    'first_name': 'Irene ',
#    'last_name': 'Guerrero Sanmartín',
#    'short_name': 'Irene Guerrero',
#    'birthday': '1996-12-12',
#    'trackable_object': 69325,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 15,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153056,
#    'team_id': 2027,
#    'id': 64156,
#    'first_name': 'Gemma Jayne',
#    'last_name': 'Evans',
#    'short_name': 'G. Evans',
#    'birthday': '1996-08-01',
#    'trackable_object': 65282,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 25,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153055,
#    'team_id': 2027,
#    'id': 153392,
#    'first_name': 'Evie',
#    'last_name': 'Rabjohn',
#    'short_name': 'E. Rabjohn',
#    'birthday': '2005-04-28',
#    'trackable_object': 154947,
#    'gender': 'female'},
#   {'player_role': {'id': 0,
#     'position_group': 'Other',
#     'name': 'Goalkeeper',
#     'acronym': 'GK'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 27,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102122,
#    'team_id': 2027,
#    'id': 22622,
#    'first_name': 'Mary',
#    'last_name': 'Earps',
#    'short_name': 'M. Earps',
#    'birthday': '1993-03-07',
#    'trackable_object': 23194,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 17,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 1,
#    'own_goal': 0,
#    'team_player_id': 401794,
#    'team_id': 2027,
#    'id': 22457,
#    'first_name': 'Lucía',
#    'last_name': 'García Córdoba',
#    'short_name': 'Lucía García',
#    'birthday': '1998-07-14',
#    'trackable_object': 22864,
#    'gender': 'female'},
#   {'player_role': {'id': 10,
#     'position_group': 'Midfield',
#     'name': 'Right Midfield',
#     'acronym': 'RM'},
#    'start_time': '00:00:00',
#    'end_time': '01:19:57',
#    'number': 12,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102126,
#    'team_id': 2027,
#    'id': 64166,
#    'first_name': 'Hayley',
#    'last_name': 'Ladd',
#    'short_name': 'H. Ladd',
#    'birthday': '1993-10-06',
#    'trackable_object': 65292,
#    'gender': 'female'},
#   {'player_role': {'id': 15,
#     'position_group': 'Center Forward',
#     'name': 'Center Forward',
#     'acronym': 'CF'},
#    'start_time': '00:00:00',
#    'end_time': '01:05:44',
#    'number': 23,
#    'yellow_card': 1,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153053,
#    'team_id': 2027,
#    'id': 22555,
#    'first_name': '',
#    'last_name': 'Geyse',
#    'short_name': 'Geyse',
#    'birthday': '1998-03-27',
#    'trackable_object': 23060,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 22,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 946461,
#    'team_id': 2029,
#    'id': 62772,
#    'first_name': 'Simone',
#    'last_name': 'Magill',
#    'short_name': 'S. Magill',
#    'birthday': '1994-11-01',
#    'trackable_object': 63898,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 16,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 102138,
#    'team_id': 2029,
#    'id': 68749,
#    'first_name': 'Olivia',
#    'last_name': 'McLoughlin',
#    'short_name': 'O. McLoughlin',
#    'birthday': '2004-10-15',
#    'trackable_object': 69875,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 33,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101989,
#    'team_id': 2029,
#    'id': 68670,
#    'first_name': 'Mayumi',
#    'last_name': 'Pacheco',
#    'short_name': 'M. Pacheco',
#    'birthday': '1998-08-25',
#    'trackable_object': 69796,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 18,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 644248,
#    'team_id': 2029,
#    'id': 424697,
#    'first_name': 'Georgia',
#    'last_name': 'Mullett',
#    'short_name': 'G. Mullett',
#    'birthday': '2005-09-16',
#    'trackable_object': 426254,
#    'gender': 'female'},
#   {'player_role': {'id': 17,
#     'position_group': 'Other',
#     'name': 'Substitute',
#     'acronym': 'SUB'},
#    'start_time': None,
#    'end_time': None,
#    'number': 21,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 375206,
#    'team_id': 2029,
#    'id': 59723,
#    'first_name': 'Anna Jessica',
#    'last_name': 'Leat',
#    'short_name': 'A. Leat',
#    'birthday': '2001-06-26',
#    'trackable_object': 60849,
#    'gender': 'female'},
#   {'player_role': {'id': 0,
#     'position_group': 'Other',
#     'name': 'Goalkeeper',
#     'acronym': 'GK'},
#    'start_time': '00:00:00',
#    'end_time': None,
#    'number': 1,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 1153049,
#    'team_id': 2029,
#    'id': 63552,
#    'first_name': 'Daphne',
#    'last_name': 'van Domselaar',
#    'short_name': 'D. van Domselaar',
#    'birthday': '2000-03-06',
#    'trackable_object': 64678,
#    'gender': 'female'},
#   {'player_role': {'id': 13,
#     'position_group': 'Wide Attacker',
#     'name': 'Right Winger',
#     'acronym': 'RW'},
#    'start_time': '00:00:00',
#    'end_time': '01:05:53',
#    'number': 7,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101982,
#    'team_id': 2029,
#    'id': 64130,
#    'first_name': 'Alisha',
#    'last_name': 'Lehmann',
#    'short_name': 'A. Lehmann',
#    'birthday': '1999-01-21',
#    'trackable_object': 65256,
#    'gender': 'female'},
#   {'player_role': {'id': 11,
#     'position_group': 'Midfield',
#     'name': 'Attacking Midfield',
#     'acronym': 'AM'},
#    'start_time': '00:00:00',
#    'end_time': '00:45:00',
#    'number': 19,
#    'yellow_card': 0,
#    'red_card': 0,
#    'injured': False,
#    'goal': 0,
#    'own_goal': 0,
#    'team_player_id': 101994,
#    'team_id': 2029,
#    'id': 68675,
#    'first_name': 'Laura Madison',
#    'last_name': 'Blindkilde Brown',
#    'short_name': 'L. Blindkilde Brown',
#    'birthday': '2003-09-09',
#    'trackable_object': 69801,
#    'gender': 'female'}],
#  'status': 'closed',
#  'home_team_side': ['left_to_right', 'right_to_left'],
#  'ball': {'trackable_object': 55},
#  'pitch_length': 105,
#  'pitch_width': 68}

# %%
home_id = match_data['home_team']['id']
away_id = match_data['away_team']['id']
home_p_ids = [p['id'] for p in match_data['players'] if p['team_id'] == home_id]
away_p_ids = [p['id'] for p in match_data['players'] if p['team_id'] == away_id]

# %%
id_map = {player['short_name']: player['id'] for player in match_data['players']}

# %%
cols = ['index','frame', 'minute', 'player_name', 'pass_recipient_name', 'pass_recipient_id',
       'pass_recipient_position', 'sk_player_id', 'pass_angle','type_primary', 'type_secondary', 'location_x', 'location_y', 'pass_accurate',
       'pass_endlocation_x', 'pass_endlocation_y', 'player_position', 'sk_match_id', 
       'possession_team_name', 'possession_types']
match_event_df = match_event_df[cols].reset_index()

# %%
match_event_df.head()
# Out:
#    index  frame  minute    player_name pass_recipient_name  pass_recipient_id  \
# 0      0    107       0        H. Ladd            K. Zelem             134338
# 1      1    126       0       K. Zelem           G. George             289914
# 2      2    158       0      G. George           M. Turner             258929
# 3      3    191       0      M. Turner       M. Le Tissier             559233
# 4      4    222       0  M. Le Tissier           M. Turner             258929
#
#   pass_recipient_position  sk_player_id  pass_angle type_primary  \
# 0                     DMF         64166        -153         pass
# 1                      LB         68743        -104         pass
# 2                     LCB         68681         104         pass
# 3                     RCB         63767          93         pass
# 4                     LCB         68697         -88         pass
#
#                          type_secondary  location_x  location_y  \
# 0     [back_pass, short_or_medium_pass]          51          50
# 1  [lateral_pass, short_or_medium_pass]          38          40
# 2  [lateral_pass, short_or_medium_pass]          33          10
# 3  [lateral_pass, short_or_medium_pass]          29          39
# 4  [lateral_pass, short_or_medium_pass]          28          70
#
#    pass_accurate  pass_endlocation_x  pass_endlocation_y player_position  \
# 0           True                  38                  40            RCMF
# 1           True                  33                  10             DMF
# 2           True                  29                  39              LB
# 3           True                  28                  70             LCB
# 4           True                  29                  37             RCB
#
#    sk_match_id possession_team_name possession_types
# 0      1133203    Manchester United             None
# 1      1133203    Manchester United             None
# 2      1133203    Manchester United             None
# 3      1133203    Manchester United             None
# 4      1133203    Manchester United             None

# %%
match_event_pass = match_event_df[match_event_df['type_primary'] == 'pass'].reset_index(drop = True)

# %%
# pass_indices = match_event_df.index[match_event_df['type_primary'] == 'pass']
# pass_indices_filtered = []
# for i in pass_indices:
#     next_row = match_event_df.iloc[i+1]
#     next_type = next_row['type_primary']
#     if next_type is in ['pass', 'duel', 'touch']
# Out:
# pass
# pass
# pass
# pass
# pass
# pass
# game_interruption
# pass
# touch
# pass
# pass
# pass
# pass
# duel
# duel
# pass
# pass
# pass
# pass
# touch
# pass
# duel
# pass
# pass
# pass
# pass
# touch
# pass
# pass
# interception
# duel
# touch
# shot
# duel
# touch
# pass
# pass
# duel
# interception
# game_interruption
# pass
# pass
# interception
# duel
# pass
# pass
# pass
# duel
# pass
# pass
# pass
# pass
# pass
# duel
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# duel
# duel
# pass
# interception
# duel
# pass
# pass
# pass
# touch
# pass
# pass
# pass
# pass
# touch
# duel
# interception
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# interception
# pass
# pass
# pass
# pass
# touch
# pass
# pass
# pass
# pass
# interception
# game_interruption
# pass
# pass
# interception
# pass
# pass
# duel
# pass
# pass
# pass
# interception
# offside
# pass
# pass
# pass
# pass
# pass
# duel
# pass
# acceleration
# pass
# game_interruption
# pass
# interception
# pass
# pass
# pass
# touch
# touch
# pass
# duel
# duel
# interception
# pass
# touch
# pass
# pass
# pass
# pass
# duel
# interception
# pass
# pass
# interception
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# acceleration
# pass
# pass
# pass
# pass
# pass
# acceleration
# interception
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# touch
# duel
# pass
# duel
# pass
# pass
# duel
# interception
# pass
# duel
# pass
# pass
# pass
# touch
# touch
# duel
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# interception
# pass
# interception
# pass
# pass
# interception
# touch
# pass
# touch
# interception
# pass
# touch
# pass
# interception
# pass
# pass
# interception
# touch
# pass
# pass
# offside
# pass
# duel
# pass
# pass
# pass
# touch
# pass
# touch
# pass
# pass
# pass
# pass
# acceleration
# pass
# interception
# duel
# pass
# acceleration
# interception
# duel
# pass
# pass
# pass
# pass
# duel
# duel
# touch
# pass
# duel
# interception
# pass
# pass
# duel
# interception
# pass
# touch
# duel
# duel
# pass
# pass
# touch
# pass
# duel
# pass
# pass
# touch
# pass
# pass
# shot
# duel
# pass
# pass
# touch
# pass
# pass
# pass
# pass
# pass
# offside
# touch
# pass
# duel
# pass
# duel
# pass
# pass
# touch
# pass
# pass
# duel
# pass
# duel
# duel
# interception
# pass
# interception
# touch
# interception
# pass
# touch
# pass
# pass
# pass
# pass
# duel
# pass
# touch
# pass
# pass
# interception
# pass
# pass
# duel
# pass
# duel
# interception
# touch
# touch
# duel
# duel
# touch
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# acceleration
# touch
# pass
# pass
# pass
# touch
# pass
# duel
# interception
# pass
# pass
# duel
# pass
# interception
# pass
# pass
# pass
# pass
# touch
# pass
# pass
# pass
# pass
# touch
# pass
# pass
# touch
# duel
# duel
# touch
# touch
# touch
# duel
# interception
# pass
# pass
# pass
# pass
# touch
# pass
# touch
# touch
# pass
# interception
# pass
# duel
# duel
# interception
# duel
# pass
# pass
# pass
# duel
# pass
# pass
# pass
# pass
# duel
# interception
# duel
# pass
# duel
# duel
# duel
# pass
# duel
# pass
# pass
# pass
# interception
# duel
# duel
# pass
# pass
# touch
# pass
# goalkeeper_exit
# pass
# pass
# pass
# pass
# pass
# duel
# pass
# pass
# pass
# touch
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# interception
# pass
# interception
# interception
# touch
# acceleration
# pass
# touch
# duel
# duel
# pass
# interception
# pass
# interception
# pass
# touch
# pass
# duel
# duel
# pass
# pass
# duel
# clearance
# pass
# duel
# pass
# pass
# pass
# touch
# pass
# duel
# acceleration
# interception
# interception
# shot_against
# pass
# pass
# touch
# pass
# duel
# pass
# pass
# duel
# touch
# pass
# interception
# touch
# pass
# pass
# pass
# duel
# pass
# pass
# pass
# duel
# pass
# pass
# duel
# duel
# pass
# pass
# pass
# pass
# interception
# interception
# pass
# interception
# interception
# pass
# pass
# touch
# pass
# pass
# pass
# pass
# pass
# pass
# duel
# duel
# pass
# duel
# pass
# pass
# interception
# game_interruption
# pass
# acceleration
# duel
# duel
# pass
# interception
# pass
# touch
# duel
# touch
# touch
# pass
# touch
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# interception
# pass
# duel
# pass
# pass
# pass
# duel
# duel
# pass
# acceleration
# pass
# pass
# pass
# pass
# duel
# pass
# pass
# pass
# pass
# duel
# touch
# pass
# pass
# touch
# pass
# pass
# interception
# shot
# acceleration
# interception
# pass
# pass
# game_interruption
# pass
# pass
# interception
# game_interruption
# pass
# pass
# pass
# pass
# pass
# pass
# duel
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# touch
# duel
# pass
# pass
# interception
# pass
# pass
# duel
# interception
# pass
# pass
# pass
# pass
# touch
# pass
# duel
# duel
# pass
# acceleration
# touch
# duel
# pass
# interception
# pass
# duel
# pass
# duel
# pass
# touch
# interception
# pass
# pass
# interception
# duel
# duel
# shot
# pass
# pass
# pass
# pass
# pass
# acceleration
# shot
# pass
# interception
# touch
# touch
# pass
# pass
# pass
# pass
# pass
# duel
# interception
# interception
# pass
# pass
# pass
# pass
# pass
# pass
# touch
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# goalkeeper_exit
# duel
# touch
# pass
# game_interruption
# game_interruption
# touch
# duel
# interception
# pass
# pass
# pass
# touch
# pass
# pass
# interception
# duel
# pass
# duel
# pass
# touch
# duel
# pass
# touch
# game_interruption
# game_interruption
# touch
# pass
# pass
# pass
# pass
# duel
# interception
# shot
# touch
# pass
# pass
# touch
# pass
# interception
# pass
# pass
# pass
# duel
# shot
# duel
# pass
# touch
# duel
# pass
# touch
# pass
# pass
# duel
# pass
# pass
# pass
# pass
# pass
# pass
# touch
# interception
# pass
# pass
# pass
# touch
# pass
# pass
# touch
# pass
# pass
# pass
# pass
# game_interruption
# pass
# pass
# touch
# pass
# touch
# pass
# duel
# pass
# pass
# pass
# pass
# game_interruption
# pass
# duel
# duel
# pass
# pass
# pass
# pass
# pass
# duel
# pass
# pass
# pass
# pass
# touch
# pass
# pass
# duel
# interception
# interception
# interception
# duel
# pass
# interception
# touch
# duel
# interception

# %%
# pass_indices = match_event_df.index[match_event_df['type_primary'] == 'pass']
# rows_below_pass_indices = [i for i in (pass_indices + 1) if i not in pass_indices and i < len(match_event_df)]

# %%
# next_row_df = match_event_df.iloc[rows_below_pass_indices]

# %%
# next_row_df.type_primary.value_counts()
# Out:
# type_primary
# duel                 114
# touch                 84
# interception          73
# game_interruption     13
# acceleration          13
# shot                   7
# offside                3
# goalkeeper_exit        2
# clearance              1
# shot_against           1
# Name: count, dtype: Int64

# %%
#match_event_pass[match_event_pass['pass_recipient_name'].isna()]

# %%
passing_frames = match_event_pass.frame.to_list()

# %%
pitch_length = 105  # Length of the pitch
pitch_width = 68    # Width of the pitch
box_width = 40.3

# %%
def check_target_area(pitch_length, period, team, x, y, box_width = 40.3):
    third_boundary = pitch_length / 6  # Boundary for attacking third
    wide_channel_limit = box_width/2  # Wide channel boundary on y-axis

    if team == "home":
        if period ==1:
            return (x > third_boundary) and (
                abs(y) > wide_channel_limit)
        elif period ==2:
            return (x < -third_boundary) and (
                abs(y) > wide_channel_limit)  
    elif team == 'away':
        if period ==1:
            return (x < -third_boundary) and (
                abs(y) > wide_channel_limit)  
        elif period ==2:
            return (x > third_boundary) and (
                abs(y) > wide_channel_limit)

# %%
def get_receive_frame(tracking_path, team, pitch_length, start_frame, end_frame, target_player_id, distance_threshold = 2):
    matching_line = None
    
    with jsonlines.open(tracking_path, 'r') as file:
        start_checking = False  # Flag to start processing lines after the starting frame
        
        for line in file:
            frame = line.get('frame')
            
            # Stop processing if end_frame is reached
            if frame and frame >= end_frame:
                break
            
            # Check if we've reached the starting frame
            if not start_checking:
                if frame == start_frame:
                    start_checking = True
                continue
    
            # Process lines after the starting frame
            period = line['period']
            player_data = line.get('player_data', [])
            if len(player_data) == 0:
                continue
            ball_data = line.get('ball_data', None)
    
            ball_x, ball_y = ball_data['x'], ball_data['y']
            if not ball_x or not ball_y:
                continue
            
            for player in player_data:
                if player.get('player_id') == target_player_id:
                    player_x, player_y = player['x'], player['y']
                    
                    dist = euclidean_distance(player_x, player_y, ball_x, ball_y)
                    if dist <= distance_threshold:
                        matching_line = line
                        break
            
            target_area = check_target_area(pitch_length, period, team, player_x, player_y)
                
            if matching_line:
                break    
    if matching_line:
        return period, matching_line['frame'], player_x, player_y, target_area
    else: return None, None, None, None, None

# %%
id_map['Geyse Ferreira'] = 22555

# %%
# %%time
distance_threshold = 2
for i in range(len(passing_frames)-1):
    start_frame = passing_frames[i]
    end_frame = passing_frames[i+1]
    row = match_event_pass.iloc[i]
    recipient = row['pass_recipient_name']
    if pd.notna(recipient):
        target_player_id = id_map[recipient]
        team = 'home' if target_player_id in home_p_ids else 'away' if target_player_id in away_p_ids else None        
        period, receive_frame, player_x, player_y, target_area = get_receive_frame(tracking_path, team, pitch_length, start_frame, end_frame, target_player_id)
        match_event_pass.at[i, 'period'] = period
        match_event_pass.at[i, 'receive_frame'] = receive_frame
        match_event_pass.at[i, 'receive_x'] = player_x
        match_event_pass.at[i, 'receive_y'] = player_y      
        match_event_pass.at[i, 'target_area'] = target_area
# Out:
# CPU times: total: 10min 30s
# Wall time: 10min 38s

# %%
match_event_pass[cols_n].head(20)
# Out:
#     index  frame  receive_frame  minute          player_name  \
# 0       0    107          115.0       0              H. Ladd
# 1       1    126          145.0       0             K. Zelem
# 2       2    158          168.0       0            G. George
# 3       3    191          208.0       0            M. Turner
# 4       4    222          234.0       0        M. Le Tissier
# 5       5    262          276.0       0            M. Turner
# 6       6    295            NaN       0        M. Le Tissier
# 7       9    438            NaN       0        L. Staniforth
# 8      10    443          461.0       0            D. Turner
# 9      15    516          522.0       0        L. Staniforth
# 10     16    527          542.0       0            D. Turner
# 11     17    544          553.0       0            A. Patten
# 12     18    564          577.0       0            R. Corsie
# 13     19    607          646.0       0            A. Patten
# 14     24    679          680.0       0          H. Blundell
# 15     27    687          688.0       0  L. Blindkilde Brown
# 16     28    706          730.0       1        L. Staniforth
# 17     29    748          760.0       1     D. van Domselaar
# 18     30    773          788.0       1            A. Patten
# 19     31    807          825.0       1     D. van Domselaar
#
#     pass_recipient_name  pass_recipient_id pass_recipient_position  \
# 0              K. Zelem             134338                     DMF
# 1             G. George             289914                      LB
# 2             M. Turner             258929                     LCB
# 3         M. Le Tissier             559233                     RCB
# 4             M. Turner             258929                     LCB
# 5         M. Le Tissier             559233                     RCB
# 6                  <NA>                  0                    <NA>
# 7             D. Turner             212012                      LB
# 8             K. Hanson             369532                    LAMF
# 9             D. Turner             212012                      LB
# 10            A. Patten             353249                     RCB
# 11            R. Corsie              62833                     LCB
# 12            A. Patten             353249                     RCB
# 13  L. Blindkilde Brown             772422                     AMF
# 14  L. Blindkilde Brown             772422                     AMF
# 15        L. Staniforth              11471                    LDMF
# 16     D. van Domselaar             404766                      GK
# 17            A. Patten             353249                     RCB
# 18     D. van Domselaar             404766                      GK
# 19            R. Corsie              62833                     LCB
#
#     sk_player_id  pass_angle type_primary  \
# 0          64166        -153         pass
# 1          68743        -104         pass
# 2          68681         104         pass
# 3          63767          93         pass
# 4          68697         -88         pass
# 5          63767          79         pass
# 6          68697          26         pass
# 7          22624        -144         pass
# 8          68680          13         pass
# 9          22624        -150         pass
# 10         68680         111         pass
# 11         68719        -113         pass
# 12         22628          77         pass
# 13         68719         -26         pass
# 14         57096         -45         pass
# 15         68675         171         pass
# 16         22624         150         pass
# 17         63552          74         pass
# 18         68719        -113         pass
# 19         63552         -69         pass
#
#                                                            type_secondary  \
# 0                                       [back_pass, short_or_medium_pass]
# 1                                    [lateral_pass, short_or_medium_pass]
# 2                                    [lateral_pass, short_or_medium_pass]
# 3                                    [lateral_pass, short_or_medium_pass]
# 4                                    [lateral_pass, short_or_medium_pass]
# 5                                    [lateral_pass, short_or_medium_pass]
# 6                          [forward_pass, long_pass, pass_to_final_third]
# 7                                       [back_pass, short_or_medium_pass]
# 8                                               [forward_pass, long_pass]
# 9                                       [back_pass, short_or_medium_pass]
# 10                                   [lateral_pass, short_or_medium_pass]
# 11                                                 [short_or_medium_pass]
# 12                                   [lateral_pass, short_or_medium_pass]
# 13                            [forward_pass, long_pass, progressive_pass]
# 14                                   [forward_pass, short_or_medium_pass]
# 15  [back_pass, recovery, counterpressing_recovery, short_or_medium_pass]
# 16                                      [back_pass, short_or_medium_pass]
# 17                                   [lateral_pass, short_or_medium_pass]
# 18                                   [lateral_pass, short_or_medium_pass]
# 19                                   [lateral_pass, short_or_medium_pass]
#
#     location_x  location_y  pass_accurate  pass_endlocation_x  \
# 0           51          50           True                  38
# 1           38          40           True                  33
# 2           33          10           True                  29
# 3           29          39           True                  28
# 4           28          70           True                  29
# 5           29          37           True                  33
# 6           33          74          False                  69
# 7           35          10           True                  29
# 8           29           3           True                  41
# 9           37          12           True                  30
# 10          30           6           True                  25
# 11          25          30           True                  22
# 12          22          19           True                  27
# 13          27          50          False                  58
# 14          45          76          False                  49
# 15          48          30           True                  36
# 16          36          33           True                  16
# 17          16          50           True                  20
# 18          20          71           True                  15
# 19          15          53           True                  22
#
#     pass_endlocation_y player_position  sk_match_id possession_team_name  \
# 0                   40            RCMF      1133203    Manchester United
# 1                   10             DMF      1133203    Manchester United
# 2                   39              LB      1133203    Manchester United
# 3                   70             LCB      1133203    Manchester United
# 4                   37             RCB      1133203    Manchester United
# 5                   74             LCB      1133203    Manchester United
# 6                  100             RCB      1133203    Manchester United
# 7                    3            LDMF      1133203          Aston Villa
# 8                    7              LB      1133203          Aston Villa
# 9                    6            LDMF      1133203          Aston Villa
# 10                  30              LB      1133203          Aston Villa
# 11                  19             RCB      1133203          Aston Villa
# 12                  50             LCB      1133203          Aston Villa
# 13                  26             RCB      1133203          Aston Villa
# 14                  71              RB      1133203          Aston Villa
# 15                  33             AMF      1133203          Aston Villa
# 16                  50            LDMF      1133203          Aston Villa
# 17                  71              GK      1133203          Aston Villa
# 18                  53             RCB      1133203          Aston Villa
# 19                  26              GK      1133203          Aston Villa
#
#    possession_types
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# 5              None
# 6              None
# 7        [throw_in]
# 8        [throw_in]
# 9        [throw_in]
# 10       [throw_in]
# 11       [throw_in]
# 12       [throw_in]
# 13       [throw_in]
# 14       [throw_in]
# 15       [throw_in]
# 16       [throw_in]
# 17       [throw_in]
# 18       [throw_in]
# 19       [throw_in]

# %%
cols_n = ['index','frame', 'receive_frame', 'minute', 'player_name', 'pass_recipient_name',
       'pass_recipient_id', 'pass_recipient_position', 'sk_player_id',
       'pass_angle', 'type_primary', 'type_secondary', 'location_x',
       'location_y', 'pass_accurate', 'pass_endlocation_x',
       'pass_endlocation_y', 'player_position', 'sk_match_id',
       'possession_team_name', 'possession_types']

# %%
match_event_pass_target = match_event_pass[(match_event_pass['target_area'] == True) & (match_event_pass['pass_accurate'] == True)]

# %%
match_event_pass_target.shape
# Out:
# (84, 25)

# %%
match_event_pass_target[cols_n].head()
# Out:
#     index  frame  receive_frame  minute player_name pass_recipient_name  \
# 27     45   1245         1255.0       1   L. Galton            E. Toone
# 28     46   1274         1293.0       1    E. Toone           L. Galton
# 68    135   4214         4226.0       6   L. Galton           G. George
# 69    138   4249         4255.0       6   G. George           L. Galton
# 77    147   4453         4469.0       7   L. Galton            E. Toone
#
#     pass_recipient_id pass_recipient_position  sk_player_id  pass_angle  \
# 27             401062                    LCMF         68744         -61
# 28             134321                      LW         62411          25
# 68             289914                      LB         68744         -45
# 69             134321                      LW         68681         180
# 77             401062                    LCMF         68744          12
#
#    type_primary  \
# 27         pass
# 28         pass
# 68         pass
# 69         pass
# 77         pass
#
#                                                                                  type_secondary  \
# 27                     [lateral_pass, recovery, counterpressing_recovery, short_or_medium_pass]
# 28                                       [forward_pass, progressive_pass, short_or_medium_pass]
# 68                                                         [forward_pass, short_or_medium_pass]
# 69                                                            [back_pass, short_or_medium_pass]
# 77  [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass, under_pressure]
#
#     location_x  location_y  pass_accurate  pass_endlocation_x  \
# 27          71          20           True                  77
# 28          77           4           True                  93
# 68          70          19           True                  78
# 69          77           8           True                  69
# 77          65           2           True                  87
#
#     pass_endlocation_y player_position  sk_match_id possession_team_name  \
# 27                   4              LW      1133203    Manchester United
# 28                  16            LCMF      1133203    Manchester United
# 68                   8              LW      1133203    Manchester United
# 69                   7              LB      1133203    Manchester United
# 77                   9              LW      1133203    Manchester United
#
#                          possession_types
# 27  [set_piece_attack, attack, free_kick]
# 28  [set_piece_attack, attack, free_kick]
# 68              [attack, transition_high]
# 69              [attack, transition_high]
# 77              [attack, transition_high]

# %%
pass_idx = match_event_pass_target['index']
pass_next_idx = list(pass_idx + 1)

# %%
for idx, row in match_event_pass_target.iterrows():
    pass_idx = row['index']
    next_player, next_type = None, None  
    while True:
        next_row = match_event_df[match_event_df['index'] == pass_idx + 1]        
        if not next_row.empty:
            next_player = next_row['player_name'].item()
            next_type = next_row['type_primary'].item()
            next_possesion = next_row['possession_team_name'].item()
            
            if next_type in ['duel', 'touch']:
                pass_idx += 1
                continue
        else:
            next_player, next_type = None, None
        break
    
    # Assign values to the DataFrame
    match_event_pass_target.at[idx, 'next_player'] = next_player
    match_event_pass_target.at[idx, 'next_type'] = next_type
    match_event_pass_target.at[idx, 'next_possession'] = next_possesion

# %%
cols_2 = ['index','frame', 'receive_frame', 'minute', 'player_name', 'pass_recipient_name','next_player', 'next_type','possession_team_name', 'next_possession','possession_types',
       'pass_recipient_id', 'pass_recipient_position', 'sk_player_id',
       'pass_angle', 'type_primary', 'type_secondary', 'location_x',
       'location_y', 'pass_accurate', 'pass_endlocation_x',
       'pass_endlocation_y', 'player_position', 'sk_match_id',
       'possession_team_name', 'possession_types']

# %%
match_event_pass_target[cols_2]
# Out:
#      index  frame  receive_frame  minute     player_name  pass_recipient_name  \
# 27      45   1245         1255.0       1       L. Galton             E. Toone
# 28      46   1274         1293.0       1        E. Toone            L. Galton
# 68     135   4214         4226.0       6       L. Galton            G. George
# 69     138   4249         4255.0       6       G. George            L. Galton
# 77     147   4453         4469.0       7       L. Galton             E. Toone
# 78     149   4545         4557.0       7        E. Toone             K. Zelem
# 108    197   6514         6525.0      10        K. Zelem            L. Galton
# 130    235   7810         7819.0      12        E. Toone            L. Galton
# 147    294  10346        10356.0      17       D. Turner            K. Hanson
# 148    295  10369        10377.0      17       K. Hanson  L. Blindkilde Brown
# 164    316  10983        10991.0      18     H. Blundell              H. Ladd
# 166    318  11013        11021.0      18        K. Zelem              H. Ladd
# 170    322  11092        11105.0      18       G. George            L. Galton
# 175    327  11270        11277.0      18        K. Zelem            L. Galton
# 176    328  11289        11295.0      18       L. Galton            G. George
# 178    331  11369        11377.0      18        E. Toone            G. George
# 181    339  11552        11565.0      19        E. Toone            G. George
# 182    340  11581        11590.0      19       G. George             K. Zelem
# 216    400  13129        13147.0      21        E. Toone         Lucía García
# 218    405  13402        13466.0      22  Geyse Ferreira            G. George
# 226    417  14052        14067.0      23        E. Toone            L. Galton
# 244    457  15396        15409.0      25       K. Hanson            D. Turner
# 249    464  15556        16059.0      25        K. Zelem       Geyse Ferreira
# 262    510  17400        17429.0      28       K. Hanson              R. Daly
# 270    523  17655        17719.0      29       M. Turner            G. George
# 271    525  17721        17730.0      29       G. George             E. Toone
# 286    559  19070        19080.0      31     H. Blundell       Geyse Ferreira
# 291    571  19326        19355.0      32        E. Toone            G. George
# 331    656  21920        21926.0      36        K. Zelem              H. Ladd
# 339    664  22158        22181.0      36   M. Le Tissier         Lucía García
# 349    690  23267        23276.0      38   L. Staniforth           S. Mayling
# 365    713  23895        23914.0      39       G. George            L. Galton
# 380    757  25085        25103.0      41       M. Turner            G. George
# 384    765  25230        25231.0      41  Geyse Ferreira         Lucía García
# 385    768  25269        25276.0      41    Lucía García       Geyse Ferreira
# 388    781  25398        25407.0      42        K. Zelem         Lucía García
# 389    782  25425        25433.0      42    Lucía García             K. Zelem
# 390    783  25435        25440.0      42        K. Zelem             E. Toone
# 396    800  26506        26519.0      44      S. Mayling           A. Lehmann
# 409    851  27401        27432.0      45      A. Lehmann           S. Mayling
# 414    863  27950        27997.0      45       R. Corsie            K. Hanson
# 443    916  29518        29557.0      47   M. Le Tissier       Geyse Ferreira
# 444    919  29605        29609.0      47  Geyse Ferreira         Lucía García
# 447    931  29792        29799.0      48  Geyse Ferreira          H. Blundell
# 449    938  29974        29985.0      48    Lucía García          H. Blundell
# 450    939  29987        29995.0      48     H. Blundell              H. Ladd
# 458    965  30465        30466.0      49         R. Daly           S. Mayling
# 459    966  30472        30482.0      49      S. Mayling           A. Lehmann
# 460    969  30491        30497.0      49      A. Lehmann              R. Daly
# 473   1005  31323        31335.0      50       G. George            L. Galton
# 474   1006  31342        31352.0      50       L. Galton             E. Toone
# 475   1009  31373        31376.0      50        E. Toone            L. Galton
# 476   1010  31388        31394.0      50       L. Galton            G. George
# 477   1011  31396        31415.0      50       G. George             E. Toone
# 483   1035  32372        32381.0      52       M. Turner            L. Galton
# 484   1036  32431        32441.0      52       L. Galton            G. George
# 491   1047  32648        32672.0      53        K. Zelem            G. George
# 512   1087  33812        33834.0      54       A. Patten           A. Lehmann
# 527   1136  36221        36246.0      58   M. Le Tissier            L. Galton
# 548   1171  37195        37212.0      60      A. Lehmann           S. Mayling
# 555   1186  38417        38439.0      62       L. Parker           A. Lehmann
# 563   1203  39845        39862.0      65       K. Hanson        L. Staniforth
# 564   1204  39882        39889.0      65   L. Staniforth            D. Turner
# 565   1205  39897        39907.0      65       D. Turner            K. Hanson
# 583   1246  42595        42602.0      69         A. Leon              R. Daly
# 584   1247  42613        42631.0      69         R. Daly           S. Mayling
# 585   1248  42634        42642.0      69      S. Mayling              R. Daly
# 594   1265  43772        43799.0      71     R. Williams         Lucía García
# 613   1310  45044        45047.0      73         H. Ladd            N. Parris
# 614   1314  45837        45860.0      74        E. Toone            N. Parris
# 618   1331  46374        46386.0      75       L. Parker              A. Leon
# 634   1370  49034        49043.0      80        E. Toone         Lucía García
# 645   1403  51065        51085.0      83       G. George         Lucía García
# 662   1426  51863        51894.0      85        E. Toone            G. George
# 673   1455  52816        52840.0      86        K. Zelem         Lucía García
# 674   1456  52872        52883.0      86    Lucía García            G. George
# 684   1477  53618        53628.0      87       N. Parris          H. Miyazawa
# 693   1495  54259        54276.0      89     H. Blundell            N. Parris
# 700   1518  55213        55229.0      90     H. Blundell            N. Parris
# 705   1525  55368        55388.0      90        K. Zelem            G. George
# 706   1526  55399        55405.0      90       G. George         Lucía García
# 734   1576  57470        57480.0      94     H. Blundell            N. Parris
# 741   1588  58180        58189.0      95       G. George             E. Toone
# 770   1662  59946        59954.0      98         A. Leon             J. Nobbs
#
#              next_player          next_type possession_team_name  \
# 27              E. Toone               pass    Manchester United
# 28             L. Galton               pass    Manchester United
# 68             G. George               pass    Manchester United
# 69             L. Galton               pass    Manchester United
# 77              E. Toone               pass    Manchester United
# 78              K. Zelem               pass    Manchester United
# 108            L. Galton               pass    Manchester United
# 130            L. Galton               pass    Manchester United
# 147            K. Hanson               pass          Aston Villa
# 148  L. Blindkilde Brown               pass          Aston Villa
# 164              H. Ladd               pass    Manchester United
# 166              H. Ladd               pass    Manchester United
# 170            L. Galton               pass    Manchester United
# 175            L. Galton               pass    Manchester United
# 176            G. George               pass    Manchester United
# 178            G. George               pass    Manchester United
# 181            G. George               pass    Manchester United
# 182             K. Zelem               pass    Manchester United
# 216         Lucía García               pass    Manchester United
# 218            G. George               pass    Manchester United
# 226            L. Galton               shot    Manchester United
# 244         Lucía García               pass    Manchester United
# 249            R. Corsie         infraction    Manchester United
# 262          H. Blundell               pass    Manchester United
# 270            G. George               pass    Manchester United
# 271             E. Toone               pass    Manchester United
# 286                 <NA>  game_interruption    Manchester United
# 291            G. George               pass    Manchester United
# 331              H. Ladd               pass    Manchester United
# 339         Lucía García       acceleration    Manchester United
# 349           S. Mayling               pass          Aston Villa
# 365            L. Galton               pass    Manchester United
# 380            G. George               pass    Manchester United
# 384         Lucía García               pass    Manchester United
# 385       Geyse Ferreira               pass    Manchester United
# 388         Lucía García               pass    Manchester United
# 389             K. Zelem               pass    Manchester United
# 390             E. Toone               pass    Manchester United
# 396            G. George          clearance    Manchester United
# 409                 <NA>  game_interruption          Aston Villa
# 414            K. Hanson               pass          Aston Villa
# 443       Geyse Ferreira               pass    Manchester United
# 444                 <NA>  game_interruption    Manchester United
# 447          H. Blundell               pass    Manchester United
# 449          H. Blundell               pass    Manchester United
# 450            K. Hanson               pass          Aston Villa
# 458           S. Mayling               pass          Aston Villa
# 459           A. Lehmann               pass          Aston Villa
# 460              R. Daly               pass          Aston Villa
# 473            L. Galton               pass    Manchester United
# 474             E. Toone               pass    Manchester United
# 475            L. Galton               pass    Manchester United
# 476            G. George               pass    Manchester United
# 477             E. Toone               shot    Manchester United
# 483            L. Galton               pass    Manchester United
# 484            G. George               pass    Manchester United
# 491            G. George               pass    Manchester United
# 512            G. George         infraction          Aston Villa
# 527            L. Galton               pass    Manchester United
# 548            L. Galton               pass          Aston Villa
# 555           A. Lehmann               pass          Aston Villa
# 563        L. Staniforth               pass          Aston Villa
# 564            D. Turner               pass          Aston Villa
# 565            K. Hanson               pass          Aston Villa
# 583              R. Daly               pass          Aston Villa
# 584           S. Mayling               pass          Aston Villa
# 585         Lucía García         infraction          Aston Villa
# 594         Lucía García               pass    Manchester United
# 613            K. Hanson         infraction    Manchester United
# 614            N. Parris               pass    Manchester United
# 618              A. Leon               pass          Aston Villa
# 634         Lucía García       acceleration    Manchester United
# 645         Lucía García               pass    Manchester United
# 662            G. George               pass    Manchester United
# 673         Lucía García               pass    Manchester United
# 674            G. George               pass    Manchester United
# 684          H. Miyazawa               pass    Manchester United
# 693            N. Parris               pass    Manchester United
# 700            N. Parris               pass    Manchester United
# 705            G. George               pass    Manchester United
# 706         Lucía García               pass    Manchester United
# 734            N. Parris               pass    Manchester United
# 741                 <NA>  game_interruption    Manchester United
# 770             J. Nobbs               pass          Aston Villa
#
#        next_possession                       possession_types  \
# 27   Manchester United  [set_piece_attack, attack, free_kick]
# 28   Manchester United  [set_piece_attack, attack, free_kick]
# 68   Manchester United              [attack, transition_high]
# 69   Manchester United              [attack, transition_high]
# 77   Manchester United              [attack, transition_high]
# 78   Manchester United              [attack, transition_high]
# 108  Manchester United              [attack, transition_high]
# 130  Manchester United                             [throw_in]
# 147        Aston Villa            [attack, transition_medium]
# 148        Aston Villa            [attack, transition_medium]
# 164  Manchester United            [attack, transition_medium]
# 166  Manchester United            [attack, transition_medium]
# 170  Manchester United            [attack, transition_medium]
# 175  Manchester United            [attack, transition_medium]
# 176  Manchester United            [attack, transition_medium]
# 178  Manchester United            [attack, transition_medium]
# 181  Manchester United            [attack, transition_medium]
# 182  Manchester United            [attack, transition_medium]
# 216  Manchester United            [attack, transition_medium]
# 218  Manchester United                     [attack, throw_in]
# 226  Manchester United  [set_piece_attack, attack, free_kick]
# 244  Manchester United  [set_piece_attack, attack, free_kick]
# 249  Manchester United                                   None
# 262  Manchester United                    [transition_medium]
# 270  Manchester United                               [attack]
# 271  Manchester United                               [attack]
# 286  Manchester United                     [attack, throw_in]
# 291  Manchester United            [attack, transition_medium]
# 331  Manchester United                     [attack, throw_in]
# 339  Manchester United                     [attack, throw_in]
# 349        Aston Villa              [attack, transition_high]
# 365  Manchester United                               [attack]
# 380  Manchester United                     [attack, throw_in]
# 384  Manchester United                     [attack, throw_in]
# 385  Manchester United                     [attack, throw_in]
# 388  Manchester United                               [attack]
# 389  Manchester United                               [attack]
# 390  Manchester United                               [attack]
# 396  Manchester United                     [attack, throw_in]
# 409        Aston Villa                               [attack]
# 414        Aston Villa                                   None
# 443  Manchester United                               [attack]
# 444  Manchester United                               [attack]
# 447  Manchester United                     [attack, throw_in]
# 449  Manchester United                     [attack, throw_in]
# 450        Aston Villa                     [attack, throw_in]
# 458        Aston Villa                     [attack, throw_in]
# 459        Aston Villa                     [attack, throw_in]
# 460        Aston Villa                     [attack, throw_in]
# 473  Manchester United                               [attack]
# 474  Manchester United                               [attack]
# 475  Manchester United                               [attack]
# 476  Manchester United                               [attack]
# 477  Manchester United                               [attack]
# 483  Manchester United                               [attack]
# 484  Manchester United                               [attack]
# 491  Manchester United                               [attack]
# 512        Aston Villa                     [attack, throw_in]
# 527  Manchester United                     [attack, throw_in]
# 548        Aston Villa                                   None
# 555        Aston Villa               [attack, transition_low]
# 563        Aston Villa            [attack, transition_medium]
# 564        Aston Villa            [attack, transition_medium]
# 565        Aston Villa            [attack, transition_medium]
# 583        Aston Villa                     [attack, throw_in]
# 584        Aston Villa                     [attack, throw_in]
# 585        Aston Villa                     [attack, throw_in]
# 594  Manchester United            [attack, transition_medium]
# 613  Manchester United                                   None
# 614  Manchester United  [set_piece_attack, attack, free_kick]
# 618        Aston Villa                               [attack]
# 634  Manchester United                               [attack]
# 645  Manchester United            [attack, transition_medium]
# 662  Manchester United                               [attack]
# 673  Manchester United                     [attack, throw_in]
# 674  Manchester United                     [attack, throw_in]
# 684  Manchester United                               [attack]
# 693  Manchester United                     [attack, throw_in]
# 700  Manchester United                               [attack]
# 705  Manchester United                               [attack]
# 706  Manchester United                               [attack]
# 734  Manchester United                               [attack]
# 741  Manchester United                             [throw_in]
# 770        Aston Villa              [attack, transition_high]
#
#      pass_recipient_id pass_recipient_position  sk_player_id  pass_angle  \
# 27              401062                    LCMF         68744         -61
# 28              134321                      LW         62411          25
# 68              289914                      LB         68744         -45
# 69              134321                      LW         68681         180
# 77              401062                    LCMF         68744          12
# 78              134338                     DMF         62411         167
# 108             134321                      LW         68743         -79
# 130             134321                      LW         62411         -39
# 147             369532                    LAMF         68680         -20
# 148             772422                     AMF         64066          27
# 164              11164                    RCMF         57096        -100
# 166              11164                    RCMF         68743         141
# 170             134321                      LW         68681          48
# 175             134321                      LW         68743         -11
# 176             289914                      LB         68744         -63
# 178             289914                      LB         62411         -23
# 181             289914                      LB         62411         180
# 182             134338                     DMF         68681         138
# 216             369460                      RW         62411          29
# 218             289914                      LB         22555        -128
# 226             134321                      LW         62411          18
# 244             212012                      LB         64066          -8
# 249             416757                      CF         68743           6
# 262              11461                      CF         64066          16
# 270             289914                      LB         63767         -24
# 271             401062                    LCMF         68681         135
# 286             416757                      CF         57096           7
# 291             289914                      LB         62411         -36
# 331              11164                    RCMF         68743        -113
# 339             369460                      RW         68697          42
# 349             230789                      RB         22624          29
# 365             134321                      LW         68681           9
# 380             289914                      LB         63767         -37
# 384             369460                      RW         22555         -27
# 385             416757                      CF         22457        -100
# 388             369460                      RW         68743          45
# 389             134338                     DMF         22457        -156
# 390             401062                    LCMF         68743          -6
# 396             374550                    RAMF         68672         -27
# 409             230789                      RB         64130        -170
# 414             369532                    LAMF         22628         -11
# 443             416757                      CF         68697          -3
# 444             369460                      RW         22555         172
# 447             263847                      RB         22555         146
# 449             263847                      RB         22457         143
# 450              11164                    RCMF         57096         -66
# 458             230789                      RB         22618          80
# 459             374550                    RAMF         68672         -86
# 460              11461                      CF         64130         180
# 473             134321                      LW         68681         -23
# 474             401062                    LCMF         68744         162
# 475             134321                      LW         62411        -124
# 476             289914                      LB         68744          63
# 477             401062                    LCMF         68681         -23
# 483             134321                      LW         63767         -23
# 484             289914                      LB         68744         171
# 491             289914                      LB         68743         -74
# 512             374550                    RAMF         68719           7
# 527             134321                      LW         68697         -34
# 548             230789                      RB         64130          63
# 555             374550                    RAMF         68661          -9
# 563              11471                    LDMF         64066         -73
# 564             212012                      LB         22624          -9
# 565             369532                    LAMF         68680         171
# 583              11461                      CF         22735          84
# 584             230789                      RB         22618          84
# 585              11461                      CF         68672        -149
# 594             369460                      LW         68734         -60
# 613              11203                      RW         64166           0
# 614              11203                      RW         62411          40
# 618             138911                      RW         68661          15
# 634             369460                      LW         62411         -37
# 645             369460                      LW         68681          19
# 662             289914                      LB         62411         -50
# 673             369460                      LW         68743         -48
# 674             289914                      LB         22457          18
# 684             476718                    RCMF         22608          20
# 693              11203                      RW         57096          27
# 700              11203                      RW         57096          18
# 705             289914                      LB         68743         -82
# 706             369460                      LW         68681         -20
# 734              11203                      RW         57096          45
# 741             401062                    LCMF         68681           0
# 770              11172                    RCMF         22735        -174
#
#     type_primary  \
# 27          pass
# 28          pass
# 68          pass
# 69          pass
# 77          pass
# 78          pass
# 108         pass
# 130         pass
# 147         pass
# 148         pass
# 164         pass
# 166         pass
# 170         pass
# 175         pass
# 176         pass
# 178         pass
# 181         pass
# 182         pass
# 216         pass
# 218         pass
# 226         pass
# 244         pass
# 249         pass
# 262         pass
# 270         pass
# 271         pass
# 286         pass
# 291         pass
# 331         pass
# 339         pass
# 349         pass
# 365         pass
# 380         pass
# 384         pass
# 385         pass
# 388         pass
# 389         pass
# 390         pass
# 396         pass
# 409         pass
# 414         pass
# 443         pass
# 444         pass
# 447         pass
# 449         pass
# 450         pass
# 458         pass
# 459         pass
# 460         pass
# 473         pass
# 474         pass
# 475         pass
# 476         pass
# 477         pass
# 483         pass
# 484         pass
# 491         pass
# 512         pass
# 527         pass
# 548         pass
# 555         pass
# 563         pass
# 564         pass
# 565         pass
# 583         pass
# 584         pass
# 585         pass
# 594         pass
# 613         pass
# 614         pass
# 618         pass
# 634         pass
# 645         pass
# 662         pass
# 673         pass
# 674         pass
# 684         pass
# 693         pass
# 700         pass
# 705         pass
# 706         pass
# 734         pass
# 741         pass
# 770         pass
#
#                                                                                               type_secondary  \
# 27                                  [lateral_pass, recovery, counterpressing_recovery, short_or_medium_pass]
# 28                                                    [forward_pass, progressive_pass, short_or_medium_pass]
# 68                                                                      [forward_pass, short_or_medium_pass]
# 69                                                                         [back_pass, short_or_medium_pass]
# 77               [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass, under_pressure]
# 78                                                                         [back_pass, short_or_medium_pass]
# 108                                                [lateral_pass, pass_to_final_third, short_or_medium_pass]
# 130                                [forward_pass, pass_to_final_third, short_or_medium_pass, under_pressure]
# 147                                                [forward_pass, pass_to_final_third, short_or_medium_pass]
# 148                                                                     [forward_pass, short_or_medium_pass]
# 164                                               [recovery, counterpressing_recovery, short_or_medium_pass]
# 166                                                                        [back_pass, short_or_medium_pass]
# 170                              [lateral_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 175                                                                     [forward_pass, short_or_medium_pass]
# 176                                                                      [linkup_play, short_or_medium_pass]
# 178                                                                     [forward_pass, short_or_medium_pass]
# 181                                                              [back_pass, recovery, short_or_medium_pass]
# 182                                                                        [back_pass, short_or_medium_pass]
# 216                                                                     [forward_pass, short_or_medium_pass]
# 218                                                           [cross, lateral_pass, long_pass, touch_in_box]
# 226                                                                     [forward_pass, short_or_medium_pass]
# 244                                 [forward_pass, recovery, counterpressing_recovery, short_or_medium_pass]
# 249                                   [forward_pass, progressive_pass, short_or_medium_pass, under_pressure]
# 262                                         [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 270                                                   [forward_pass, progressive_pass, short_or_medium_pass]
# 271                                                                        [back_pass, short_or_medium_pass]
# 286                                                [forward_pass, pass_to_final_third, short_or_medium_pass]
# 291                                                              [forward_pass, long_pass, progressive_pass]
# 331                                                                                   [short_or_medium_pass]
# 339                                                           [forward_pass, long_pass, pass_to_final_third]
# 349                                                [forward_pass, pass_to_final_third, short_or_medium_pass]
# 365                                         [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 380                                                [forward_pass, pass_to_final_third, short_or_medium_pass]
# 384                                                                     [forward_pass, short_or_medium_pass]
# 385                                                             [pass_to_penalty_area, short_or_medium_pass]
# 388                                                                     [forward_pass, short_or_medium_pass]
# 389                                                                        [back_pass, short_or_medium_pass]
# 390                                                   [forward_pass, progressive_pass, short_or_medium_pass]
# 396                                                   [forward_pass, progressive_pass, short_or_medium_pass]
# 409                                                                        [back_pass, short_or_medium_pass]
# 414                                         [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 443                              [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 444                                                                        [back_pass, short_or_medium_pass]
# 447                                                                        [back_pass, short_or_medium_pass]
# 449                                                                        [back_pass, short_or_medium_pass]
# 450                                                                                   [short_or_medium_pass]
# 458                                                                                   [short_or_medium_pass]
# 459                                                   [lateral_pass, progressive_pass, short_or_medium_pass]
# 460                                                                        [back_pass, short_or_medium_pass]
# 473                                                           [forward_pass, recovery, short_or_medium_pass]
# 474                                                                        [back_pass, short_or_medium_pass]
# 475                                                                                   [short_or_medium_pass]
# 476                                                                                   [short_or_medium_pass]
# 477                                                                     [forward_pass, short_or_medium_pass]
# 483                                [forward_pass, pass_to_final_third, short_or_medium_pass, under_pressure]
# 484                                                           [back_pass, linkup_play, short_or_medium_pass]
# 491                                                [lateral_pass, pass_to_final_third, short_or_medium_pass]
# 512                                         [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 527                                         [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 548                                                [lateral_pass, pass_to_final_third, short_or_medium_pass]
# 555                              [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 563                                                                                   [short_or_medium_pass]
# 564                                                                     [forward_pass, short_or_medium_pass]
# 565                                                                        [back_pass, short_or_medium_pass]
# 583                                                                                   [short_or_medium_pass]
# 584                                                                                   [short_or_medium_pass]
# 585                                                                        [back_pass, short_or_medium_pass]
# 594                                      [lateral_pass, pass_to_final_third, recovery, short_or_medium_pass]
# 613                      [forward_pass, head_pass, recovery, counterpressing_recovery, short_or_medium_pass]
# 614                                                                                [forward_pass, long_pass]
# 618                                [forward_pass, pass_to_penalty_area, second_assist, short_or_medium_pass]
# 634                                                [forward_pass, pass_to_final_third, short_or_medium_pass]
# 645  [deep_completion, forward_pass, long_pass, pass_to_final_third, pass_to_penalty_area, progressive_pass]
# 662                                                                     [lateral_pass, short_or_medium_pass]
# 673                                                           [lateral_pass, long_pass, pass_to_final_third]
# 674                                                                     [forward_pass, short_or_medium_pass]
# 684                                                           [forward_pass, recovery, short_or_medium_pass]
# 693                              [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 700                              [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 705                                                                     [lateral_pass, short_or_medium_pass]
# 706                                                                     [forward_pass, short_or_medium_pass]
# 734                                                                     [forward_pass, short_or_medium_pass]
# 741                              [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 770                                                                        [back_pass, short_or_medium_pass]
#
#      location_x  location_y  pass_accurate  pass_endlocation_x  \
# 27           71          20           True                  77
# 28           77           4           True                  93
# 68           70          19           True                  78
# 69           77           8           True                  69
# 77           65           2           True                  87
# 78           95          18           True                  78
# 108          65          39           True                  68
# 130          62          26           True                  77
# 147          60           9           True                  70
# 148          70           3           True                  74
# 164          74          98           True                  72
# 166          70          81           True                  66
# 170          63          19           True                  72
# 175          70          18           True                  75
# 176          75          16           True                  79
# 178          82          14           True                  93
# 181          94          11           True                  83
# 182          83          11           True                  73
# 216          70          72           True                  91
# 218          99          71           True                  71
# 226          69          34           True                  74
# 244          74          13           True                  88
# 249          19          86           True                  61
# 262          52           6           True                  72
# 270          32          30           True                  60
# 271          81          11           True                  72
# 286          66          96           True                  73
# 291          68          50           True                  98
# 331          67          15           True                  64
# 339          46          61           True                  72
# 349          64          80           True                  83
# 365          35           5           True                  71
# 380          60          26           True                  79
# 384          81          94           True                  89
# 385          89          93           True                  87
# 388          77          86           True                  84
# 389          84          96           True                  73
# 390          73          88           True                  92
# 396          67          92           True                  80
# 409          93          95           True                  83
# 414          35          26           True                  96
# 443          63          94           True                  94
# 444          92          91           True                  86
# 447          92          84           True                  87
# 449          83          87           True                  75
# 450          75          96           True                  79
# 458          77          83           True                  79
# 459          79          98           True                  80
# 460          78          76           True                  73
# 473          81          15           True                  88
# 474          88          10           True                  79
# 475          88          11           True                  86
# 476          86           6           True                  89
# 477          89          14           True                  95
# 483          59          13           True                  77
# 484          77           2           True                  66
# 491          63          40           True                  68
# 512          41          73           True                  70
# 527          43          52           True                  79
# 548          65          75           True                  70
# 555          62          92           True                  90
# 563          72          22           True                  75
# 564          75           8           True                  88
# 565          88           4           True                  76
# 583          80          68           True                  81
# 584          81          82           True                  82
# 585          82          95           True                  72
# 594          65          35           True                  71
# 613          64          80           True                  65
# 614          71          55           True                  94
# 618          77          75           True                  88
# 634          64          16           True                  75
# 645          40           5           True                  90
# 662          73          35           True                  89
# 673          63          42           True                  83
# 674          83           9           True                  91
# 684          70          76           True                  89
# 693          64          72           True                  88
# 700          62          67           True                  90
# 705          69          55           True                  72
# 706          72          10           True                  83
# 734          75          71           True                  87
# 741          55           5           True                  74
# 770          95          92           True                  87
#
#      pass_endlocation_y player_position  sk_match_id possession_team_name  \
# 27                    4              LW      1133203    Manchester United
# 28                   16            LCMF      1133203    Manchester United
# 68                    8              LW      1133203    Manchester United
# 69                    7              LB      1133203    Manchester United
# 77                    9              LW      1133203    Manchester United
# 78                   24            LCMF      1133203    Manchester United
# 108                  18             DMF      1133203    Manchester United
# 130                   7            LCMF      1133203    Manchester United
# 147                   3              LB      1133203          Aston Villa
# 148                   6            LAMF      1133203          Aston Villa
# 164                  82              RB      1133203    Manchester United
# 166                  87             DMF      1133203    Manchester United
# 170                  36              LB      1133203    Manchester United
# 175                  16             DMF      1133203    Manchester United
# 176                   5              LW      1133203    Manchester United
# 178                   7            LCMF      1133203    Manchester United
# 181                  11            LCMF      1133203    Manchester United
# 182                  23              LB      1133203    Manchester United
# 216                  89            LCMF      1133203    Manchester United
# 218                  16              CF      1133203    Manchester United
# 226                  37            LCMF      1133203    Manchester United
# 244                  10            LAMF      1133203    Manchester United
# 249                  93             DMF      1133203    Manchester United
# 262                  14            LAMF      1133203    Manchester United
# 270                  11             LCB      1133203    Manchester United
# 271                  24              LB      1133203    Manchester United
# 286                  97              RB      1133203    Manchester United
# 291                  16            LCMF      1133203    Manchester United
# 331                   5             DMF      1133203    Manchester United
# 339                  97             RCB      1133203    Manchester United
# 349                  95            LDMF      1133203          Aston Villa
# 365                  13              LB      1133203    Manchester United
# 380                   5             LCB      1133203    Manchester United
# 384                  88              CF      1133203    Manchester United
# 385                  77              RW      1133203    Manchester United
# 388                  96             DMF      1133203    Manchester United
# 389                  88              RW      1133203    Manchester United
# 390                  86             DMF      1133203    Manchester United
# 396                  82              RB      1133203    Manchester United
# 409                  93            RAMF      1133203          Aston Villa
# 414                   7             LCB      1133203          Aston Villa
# 443                  91             RCB      1133203    Manchester United
# 444                  93              CF      1133203    Manchester United
# 447                  90              CF      1133203    Manchester United
# 449                  96              RW      1133203    Manchester United
# 450                  82              RB      1133203          Aston Villa
# 458                  98              CF      1133203          Aston Villa
# 459                  80              RB      1133203          Aston Villa
# 460                  77            RAMF      1133203          Aston Villa
# 473                  10              LB      1133203    Manchester United
# 474                  15              LW      1133203    Manchester United
# 475                   6            LCMF      1133203    Manchester United
# 476                  14              LW      1133203    Manchester United
# 477                  11              LB      1133203    Manchester United
# 483                   2             LCB      1133203    Manchester United
# 484                   5              LW      1133203    Manchester United
# 491                  13             DMF      1133203    Manchester United
# 512                  80             RCB      1133203          Aston Villa
# 527                  13             RCB      1133203    Manchester United
# 548                  93            RAMF      1133203          Aston Villa
# 555                  86            RDMF      1133203          Aston Villa
# 563                   8            LAMF      1133203          Aston Villa
# 564                   4            LDMF      1133203          Aston Villa
# 565                   8              LB      1133203          Aston Villa
# 583                  82            RAMF      1133203          Aston Villa
# 584                  95              CF      1133203          Aston Villa
# 585                  87              RB      1133203          Aston Villa
# 594                  17              CF      1133203    Manchester United
# 613                  80            RCMF      1133203    Manchester United
# 614                  84            LCMF      1133203    Manchester United
# 618                  79            RCMF      1133203          Aston Villa
# 634                   3            LCMF      1133203    Manchester United
# 645                  31              LB      1133203    Manchester United
# 662                   7            LCMF      1133203    Manchester United
# 673                   9             DMF      1133203    Manchester United
# 674                  13              LW      1133203    Manchester United
# 684                  87              RW      1133203    Manchester United
# 693                  91              RB      1133203    Manchester United
# 700                  82              RB      1133203    Manchester United
# 705                  10             DMF      1133203    Manchester United
# 706                   5              LB      1133203    Manchester United
# 734                  88              RB      1133203    Manchester United
# 741                   4              LB      1133203    Manchester United
# 770                  91              RW      1133203          Aston Villa
#
#                           possession_types
# 27   [set_piece_attack, attack, free_kick]
# 28   [set_piece_attack, attack, free_kick]
# 68               [attack, transition_high]
# 69               [attack, transition_high]
# 77               [attack, transition_high]
# 78               [attack, transition_high]
# 108              [attack, transition_high]
# 130                             [throw_in]
# 147            [attack, transition_medium]
# 148            [attack, transition_medium]
# 164            [attack, transition_medium]
# 166            [attack, transition_medium]
# 170            [attack, transition_medium]
# 175            [attack, transition_medium]
# 176            [attack, transition_medium]
# 178            [attack, transition_medium]
# 181            [attack, transition_medium]
# 182            [attack, transition_medium]
# 216            [attack, transition_medium]
# 218                     [attack, throw_in]
# 226  [set_piece_attack, attack, free_kick]
# 244  [set_piece_attack, attack, free_kick]
# 249                                   None
# 262                    [transition_medium]
# 270                               [attack]
# 271                               [attack]
# 286                     [attack, throw_in]
# 291            [attack, transition_medium]
# 331                     [attack, throw_in]
# 339                     [attack, throw_in]
# 349              [attack, transition_high]
# 365                               [attack]
# 380                     [attack, throw_in]
# 384                     [attack, throw_in]
# 385                     [attack, throw_in]
# 388                               [attack]
# 389                               [attack]
# 390                               [attack]
# 396                     [attack, throw_in]
# 409                               [attack]
# 414                                   None
# 443                               [attack]
# 444                               [attack]
# 447                     [attack, throw_in]
# 449                     [attack, throw_in]
# 450                     [attack, throw_in]
# 458                     [attack, throw_in]
# 459                     [attack, throw_in]
# 460                     [attack, throw_in]
# 473                               [attack]
# 474                               [attack]
# 475                               [attack]
# 476                               [attack]
# 477                               [attack]
# 483                               [attack]
# 484                               [attack]
# 491                               [attack]
# 512                     [attack, throw_in]
# 527                     [attack, throw_in]
# 548                                   None
# 555               [attack, transition_low]
# 563            [attack, transition_medium]
# 564            [attack, transition_medium]
# 565            [attack, transition_medium]
# 583                     [attack, throw_in]
# 584                     [attack, throw_in]
# 585                     [attack, throw_in]
# 594            [attack, transition_medium]
# 613                                   None
# 614  [set_piece_attack, attack, free_kick]
# 618                               [attack]
# 634                               [attack]
# 645            [attack, transition_medium]
# 662                               [attack]
# 673                     [attack, throw_in]
# 674                     [attack, throw_in]
# 684                               [attack]
# 693                     [attack, throw_in]
# 700                               [attack]
# 705                               [attack]
# 706                               [attack]
# 734                               [attack]
# 741                             [throw_in]
# 770              [attack, transition_high]

# %%
match_event_merge = pd.merge(match_event_df, match_event_pass[['frame', 'receive_frame']], on = 'frame', how = 'outer')

# %%
match_event_merge[cols_n].head(30)
# Out:
#     frame  receive_frame  minute          player_name  pass_recipient_name  \
# 0     107          115.0       0              H. Ladd             K. Zelem
# 1     126          145.0       0             K. Zelem            G. George
# 2     158          168.0       0            G. George            M. Turner
# 3     191          208.0       0            M. Turner        M. Le Tissier
# 4     222          234.0       0        M. Le Tissier            M. Turner
# 5     262          276.0       0            M. Turner        M. Le Tissier
# 6     295            NaN       0        M. Le Tissier                 <NA>
# 7     329            NaN       0                 <NA>                 <NA>
# 8     409            NaN       0            D. Turner        L. Staniforth
# 9     438            NaN       0        L. Staniforth            D. Turner
# 10    443          461.0       0            D. Turner            K. Hanson
# 11    459            NaN       0            K. Hanson                 <NA>
# 12    477            NaN       0          H. Blundell         Lucía García
# 13    505            NaN       0            K. Hanson                 <NA>
# 14    505            NaN       0         Lucía García                 <NA>
# 15    516          522.0       0        L. Staniforth            D. Turner
# 16    527          542.0       0            D. Turner            A. Patten
# 17    544          553.0       0            A. Patten            R. Corsie
# 18    564          577.0       0            R. Corsie            A. Patten
# 19    607          646.0       0            A. Patten  L. Blindkilde Brown
# 20    647            NaN       0  L. Blindkilde Brown                 <NA>
# 21    649            NaN       0          H. Blundell                 <NA>
# 22    652            NaN       0            K. Hanson                 <NA>
# 23    656            NaN       0          H. Blundell                 <NA>
# 24    679          680.0       0          H. Blundell  L. Blindkilde Brown
# 25    682            NaN       0  L. Blindkilde Brown                 <NA>
# 26    682            NaN       0                 <NA>                 <NA>
# 27    687          688.0       0  L. Blindkilde Brown        L. Staniforth
# 28    706          730.0       1        L. Staniforth     D. van Domselaar
# 29    748          760.0       1     D. van Domselaar            A. Patten
#
#     pass_recipient_id pass_recipient_position  sk_player_id  pass_angle  \
# 0              134338                     DMF         64166        -153
# 1              289914                      LB         68743        -104
# 2              258929                     LCB         68681         104
# 3              559233                     RCB         63767          93
# 4              258929                     LCB         68697         -88
# 5              559233                     RCB         63767          79
# 6                   0                    <NA>         68697          26
# 7                <NA>                    <NA>          <NA>        <NA>
# 8               11471                    LDMF         68680          67
# 9              212012                      LB         22624        -144
# 10             369532                    LAMF         68680          13
# 11               <NA>                    <NA>         64066        <NA>
# 12             369460                      RW         57096          22
# 13               <NA>                    <NA>         64066        <NA>
# 14               <NA>                    <NA>         22457        <NA>
# 15             212012                      LB         22624        -150
# 16             353249                     RCB         68680         111
# 17              62833                     LCB         68719        -113
# 18             353249                     RCB         22628          77
# 19             772422                     AMF         68719         -26
# 20               <NA>                    <NA>         68675        <NA>
# 21               <NA>                    <NA>         57096        <NA>
# 22               <NA>                    <NA>         64066        <NA>
# 23               <NA>                    <NA>         57096        <NA>
# 24             772422                     AMF         57096         -45
# 25               <NA>                    <NA>         68675        <NA>
# 26               <NA>                    <NA>          <NA>        <NA>
# 27              11471                    LDMF         68675         171
# 28             404766                      GK         22624         150
# 29             353249                     RCB         63552          74
#
#          type_primary  \
# 0                pass
# 1                pass
# 2                pass
# 3                pass
# 4                pass
# 5                pass
# 6                pass
# 7   game_interruption
# 8            throw_in
# 9                pass
# 10               pass
# 11              touch
# 12       interception
# 13               duel
# 14               duel
# 15               pass
# 16               pass
# 17               pass
# 18               pass
# 19               pass
# 20               duel
# 21               duel
# 22               duel
# 23               duel
# 24               pass
# 25               duel
# 26               duel
# 27               pass
# 28               pass
# 29               pass
#
#                                                                type_secondary  \
# 0                                           [back_pass, short_or_medium_pass]
# 1                                        [lateral_pass, short_or_medium_pass]
# 2                                        [lateral_pass, short_or_medium_pass]
# 3                                        [lateral_pass, short_or_medium_pass]
# 4                                        [lateral_pass, short_or_medium_pass]
# 5                                        [lateral_pass, short_or_medium_pass]
# 6                              [forward_pass, long_pass, pass_to_final_third]
# 7                                                                  [ball_out]
# 8                                                                        None
# 9                                           [back_pass, short_or_medium_pass]
# 10                                                  [forward_pass, long_pass]
# 11                                                              [loss, carry]
# 12  [forward_pass, pass, pass_to_final_third, recovery, short_or_medium_pass]
# 13          [defensive_duel, ground_duel, recovery, counterpressing_recovery]
# 14                                        [ground_duel, loss, offensive_duel]
# 15                                          [back_pass, short_or_medium_pass]
# 16                                       [lateral_pass, short_or_medium_pass]
# 17                                                     [short_or_medium_pass]
# 18                                       [lateral_pass, short_or_medium_pass]
# 19                                [forward_pass, long_pass, progressive_pass]
# 20                                              [defensive_duel, ground_duel]
# 21                                     [dribble, ground_duel, offensive_duel]
# 22                               [dribble, ground_duel, loss, offensive_duel]
# 23             [defensive_duel, dribbled_past_attempt, ground_duel, recovery]
# 24                                       [forward_pass, short_or_medium_pass]
# 25                                [ground_duel, interception, offensive_duel]
# 26                                              [defensive_duel, ground_duel]
# 27      [back_pass, recovery, counterpressing_recovery, short_or_medium_pass]
# 28                                          [back_pass, short_or_medium_pass]
# 29                                       [lateral_pass, short_or_medium_pass]
#
#     location_x  location_y  pass_accurate  pass_endlocation_x  \
# 0           51          50           True                  38
# 1           38          40           True                  33
# 2           33          10           True                  29
# 3           29          39           True                  28
# 4           28          70           True                  29
# 5           29          37           True                  33
# 6           33          74          False                  69
# 7           31           0           <NA>                <NA>
# 8           32           0           True                  35
# 9           35          10           True                  29
# 10          29           3           True                  41
# 11          41           7           <NA>                <NA>
# 12          57          92           True                  67
# 13          33           2           <NA>                <NA>
# 14          67          98           <NA>                <NA>
# 15          37          12           True                  30
# 16          30           6           True                  25
# 17          25          30           True                  22
# 18          22          19           True                  27
# 19          27          50          False                  58
# 20          58          26           <NA>                <NA>
# 21          42          74           <NA>                <NA>
# 22          56          24           <NA>                <NA>
# 23          44          76           <NA>                <NA>
# 24          45          76          False                  49
# 25          51          29           <NA>                <NA>
# 26          49          71           <NA>                <NA>
# 27          48          30           True                  36
# 28          36          33           True                  16
# 29          16          50           True                  20
#
#     pass_endlocation_y player_position  sk_match_id possession_team_name  \
# 0                   40            RCMF      1133203    Manchester United
# 1                   10             DMF      1133203    Manchester United
# 2                   39              LB      1133203    Manchester United
# 3                   70             LCB      1133203    Manchester United
# 4                   37             RCB      1133203    Manchester United
# 5                   74             LCB      1133203    Manchester United
# 6                  100             RCB      1133203    Manchester United
# 7                 <NA>            <NA>      1133203    Manchester United
# 8                   10              LB      1133203          Aston Villa
# 9                    3            LDMF      1133203          Aston Villa
# 10                   7              LB      1133203          Aston Villa
# 11                <NA>            LAMF      1133203          Aston Villa
# 12                  98              RB      1133203          Aston Villa
# 13                <NA>            LAMF      1133203          Aston Villa
# 14                <NA>              RW      1133203          Aston Villa
# 15                   6            LDMF      1133203          Aston Villa
# 16                  30              LB      1133203          Aston Villa
# 17                  19             RCB      1133203          Aston Villa
# 18                  50             LCB      1133203          Aston Villa
# 19                  26             RCB      1133203          Aston Villa
# 20                <NA>             AMF      1133203          Aston Villa
# 21                <NA>              RB      1133203          Aston Villa
# 22                <NA>            LAMF      1133203          Aston Villa
# 23                <NA>              RB      1133203          Aston Villa
# 24                  71              RB      1133203          Aston Villa
# 25                <NA>             AMF      1133203          Aston Villa
# 26                <NA>            <NA>      1133203          Aston Villa
# 27                  33             AMF      1133203          Aston Villa
# 28                  50            LDMF      1133203          Aston Villa
# 29                  71              GK      1133203          Aston Villa
#
#    possession_types
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# 5              None
# 6              None
# 7              None
# 8        [throw_in]
# 9        [throw_in]
# 10       [throw_in]
# 11       [throw_in]
# 12       [throw_in]
# 13       [throw_in]
# 14       [throw_in]
# 15       [throw_in]
# 16       [throw_in]
# 17       [throw_in]
# 18       [throw_in]
# 19       [throw_in]
# 20       [throw_in]
# 21       [throw_in]
# 22       [throw_in]
# 23       [throw_in]
# 24       [throw_in]
# 25       [throw_in]
# 26       [throw_in]
# 27       [throw_in]
# 28       [throw_in]
# 29       [throw_in]

# %%
start_frame = 191  # Example frame number
end_frame = 222
target_player_id = id_map['M. Le Tissier']  # Target player_id
distance_threshold = 2

# %%
f = get_receive_frame(tracking_path, start_frame, end_frame, target_player_id)
# Out:
# 191
# 21.615929311505443
# 20.10224116858615
# 18.365037435300806
# 16.73526814843431
# 15.110013236261576
# 13.51719275589425
# 11.969214677663693
# 10.525991639745873
# 9.208800138997479
# 7.97295428307475
# 6.791178101036667
# 5.64825636811928
# 4.578995523037777
# 3.61311499955371
# 2.7985174646587443
# 2.1658485634965357
# 1.7262676501632066

# %%
f
# Out:
# 208

# %%
matching_line = None

with jsonlines.open(tracking_path, 'r') as file:
    start_checking = False  # Flag to start processing lines after the starting frame
    
    for line in file:
        frame = line.get('frame')
        
        # Stop processing if end_frame is reached
        if frame and frame >= end_frame:
            break
        
        # Check if we've reached the starting frame
        if not start_checking:
            if frame == start_frame:
                start_checking = True
                print(frame)
            continue

        # Process lines after the starting frame
        player_data = line.get('player_data', [])
        ball_data = line.get('ball_data', None)

        ball_x, ball_y = ball_data['x'], ball_data['y']
        
        for player in player_data:
            # Ensure the player_id matches
            if player.get('player_id') == target_player_id:
                # Extract player's coordinates
                player_x, player_y = player['x'], player['y']
                
                # Check the distance condition
                dist = euclidean_distance(player_x, player_y, ball_x, ball_y)
                print(dist)
                if dist <= distance_threshold:
                    matching_line = line
                    break

        if matching_line:
            break
# Out:
# 158
# 11.464065596462712
# 10.113317952086742
# 8.714883820223882
# 7.405356169692313
# 6.143850584120679
# 4.961370778323267
# 3.8657082145449086
# 2.912902332725902
# 2.0163581031156137
# 1.260158720161869

# %%
matching_line
# Out:
# {'frame': 168,
#  'timestamp': '00:00:06.80',
#  'period': 1,
#  'ball_data': {'x': 25.09, 'y': -15.82, 'z': 0.04, 'is_detected': True},
#  'possession': {'player_id': 63767, 'group': 'away team'},
#  'image_corners_projection': {'x_top_left': 6.67,
#   'y_top_left': 35.11,
#   'x_bottom_left': 1.42,
#   'y_bottom_left': -27.5,
#   'x_bottom_right': 20.55,
#   'y_bottom_right': -33.53,
#   'x_top_right': 53.26,
#   'y_top_right': 20.97},
#  'player_data': [{'x': -37.66,
#    'y': -2.31,
#    'player_id': 63552,
#    'is_detected': False},
#   {'x': -10.57, 'y': -11.08, 'player_id': 68719, 'is_detected': False},
#   {'x': -10.75, 'y': -1.59, 'player_id': 22628, 'is_detected': False},
#   {'x': -10.2, 'y': -21.86, 'player_id': 68672, 'is_detected': False},
#   {'x': -12.12, 'y': 11.49, 'player_id': 68680, 'is_detected': False},
#   {'x': 0.4, 'y': -5.01, 'player_id': 22624, 'is_detected': False},
#   {'x': -0.34, 'y': -14.84, 'player_id': 68661, 'is_detected': False},
#   {'x': 8.82, 'y': -12.65, 'player_id': 68675, 'is_detected': True},
#   {'x': 6.13, 'y': -21.63, 'player_id': 64130, 'is_detected': True},
#   {'x': 1.41, 'y': 4.85, 'player_id': 64066, 'is_detected': False},
#   {'x': 13.25, 'y': -3.09, 'player_id': 22618, 'is_detected': True},
#   {'x': 38.54, 'y': -1.09, 'player_id': 22622, 'is_detected': True},
#   {'x': 22.99, 'y': 9.01, 'player_id': 68697, 'is_detected': True},
#   {'x': 26.11, 'y': -15.08, 'player_id': 63767, 'is_detected': True},
#   {'x': 9.57, 'y': 21.0, 'player_id': 57096, 'is_detected': True},
#   {'x': 16.06, 'y': -25.84, 'player_id': 68681, 'is_detected': True},
#   {'x': 8.92, 'y': -9.16, 'player_id': 68743, 'is_detected': True},
#   {'x': 7.15, 'y': -18.79, 'player_id': 62411, 'is_detected': True},
#   {'x': 0.91, 'y': 2.05, 'player_id': 64166, 'is_detected': False},
#   {'x': -5.92, 'y': 21.45, 'player_id': 22457, 'is_detected': False},
#   {'x': -9.47, 'y': -23.13, 'player_id': 68744, 'is_detected': False},
#   {'x': -8.58, 'y': -8.48, 'player_id': 22555, 'is_detected': False}]}
