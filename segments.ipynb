# %%
from mplsoccer.pitch import Pitch
import matplotlib.pyplot as plt
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import os
import json
import jsonlines
from skillcorner.client import SkillcornerClient
import pyarrow.parquet as pq

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
load_dotenv()
username = os.getenv('U')
password = os.getenv('P')
client = SkillcornerClient(username=username, password=password)

# %%
def load_json_file(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

# %%
def load_jsonl_file(file_path):
    with jsonlines.open(file_path, 'r') as file:
        data = [line for line in file if line['timestamp'] is not None]
    return data

# %%
FA_matches = client.get_matches(params={'competition_edition': 574})
FA_match_ids = [m['id'] for m in FA_matches]

# %%
NWSL_matches = client.get_matches(params={'competition_edition': 800})
NWSL_match_ids = [m['id'] for m in NWSL_matches]

# %%
# Inspect the schema of the Parquet file
file_path = 'data/wyscout_events.parquet'
events_df = pd.read_parquet(file_path)

# %%
event_match_ids = list(set(events_df.sk_match_id))

# %%
FA_in_event = [i for i in FA_match_ids if i in event_match_ids]
len(FA_in_event)
# Out:
# 102

# %%
FA_not_in_event = [i for i in FA_match_ids if i not in event_match_ids]
len(FA_not_in_event)
# Out:
# 30

# %%
NWSL_in_event = [i for i in NWSL_match_ids if i in event_match_ids]
len(NWSL_in_event)
# Out:
# 0

# %%
NWSL_not_in_event = [i for i in NWSL_match_ids if i not in event_match_ids]
len(NWSL_not_in_event)
# Out:
# 189

# %%
cols = ['sk_match_id', 'frame', 'location_x', 'location_y', 'type_primary',
       'type_secondary', 'pass_angle',
       'pass_endlocation_x', 'pass_endlocation_y','pass_recipient_name',
       'pass_recipient_position', 'player_name','sk_player_id',
       'player_position']

# %%
FA_match_ids = FA_in_event

# %%
events_df = events_df[events_df['sk_match_id'].isin(FA_match_ids)][cols]

# %%
events_df.head()
# Out:
#         sk_match_id  frame  location_x  location_y matchtimestamp  \
# 106932      1133203    107          51          50   00:00:00.862
# 106933      1133203    126          38          40   00:00:02.903
# 106934      1133203    158          33          10   00:00:05.945
# 106935      1133203    191          29          39   00:00:09.187
# 106936      1133203    222          28          70   00:00:12.663
#
#         carry_endlocation_x type_primary  \
# 106932                 <NA>         pass
# 106933                 <NA>         pass
# 106934                 <NA>         pass
# 106935                 <NA>         pass
# 106936                 <NA>         pass
#
#                               type_secondary  pass_accurate  pass_angle  \
# 106932     [back_pass, short_or_medium_pass]           True        -153
# 106933  [lateral_pass, short_or_medium_pass]           True        -104
# 106934  [lateral_pass, short_or_medium_pass]           True         104
# 106935  [lateral_pass, short_or_medium_pass]           True          93
# 106936  [lateral_pass, short_or_medium_pass]           True         -88
#
#         pass_endlocation_x  pass_endlocation_y pass_height  pass_length  \
# 106932                  38                  40        <NA>           15
# 106933                  33                  10        <NA>           21
# 106934                  29                  39        <NA>           20
# 106935                  28                  70        <NA>           21
# 106936                  29                  37        <NA>           22
#
#         pass_recipient_id pass_recipient_name pass_recipient_position  \
# 106932             134338            K. Zelem                     DMF
# 106933             289914           G. George                      LB
# 106934             258929           M. Turner                     LCB
# 106935             559233       M. Le Tissier                     RCB
# 106936             258929           M. Turner                     LCB
#
#           player_name  sk_player_id player_position controlled_phase_name  \
# 106932        H. Ladd         64166            RCMF               Phase 1
# 106933       K. Zelem         68743             DMF               Phase 1
# 106934      G. George         68681              LB               Phase 1
# 106935      M. Turner         63767             LCB               Phase 1
# 106936  M. Le Tissier         68697             RCB               Phase 1
#
#         carry_endlocation_y  carry_progression
# 106932                 <NA>                NaN
# 106933                 <NA>                NaN
# 106934                 <NA>                NaN
# 106935                 <NA>                NaN
# 106936                 <NA>                NaN

# %%
match_id = 1133203

# %%
match_data = load_json_file(rf'data/FA/match/{match_id}.json')

# %%
home_p_ids = [p['id'] for p in match_data['players'] if p['team_id'] == home_id]
away_p_ids = [p['id'] for p in match_data['players'] if p['team_id'] == away_id]

# %%
match_event_df = events_df[(events_df['sk_match_id'] == match_id) & (events_df['type_primary'] == 'pass')]

# %%
match_event_df.head()
# Out:
#         sk_match_id  frame  location_x  location_y type_primary  \
# 106932      1133203    107          51          50         pass
# 106933      1133203    126          38          40         pass
# 106934      1133203    158          33          10         pass
# 106935      1133203    191          29          39         pass
# 106936      1133203    222          28          70         pass
#
#                               type_secondary  pass_angle  pass_endlocation_x  \
# 106932     [back_pass, short_or_medium_pass]        -153                  38
# 106933  [lateral_pass, short_or_medium_pass]        -104                  33
# 106934  [lateral_pass, short_or_medium_pass]         104                  29
# 106935  [lateral_pass, short_or_medium_pass]          93                  28
# 106936  [lateral_pass, short_or_medium_pass]         -88                  29
#
#         pass_endlocation_y pass_recipient_name pass_recipient_position  \
# 106932                  40            K. Zelem                     DMF
# 106933                  10           G. George                      LB
# 106934                  39           M. Turner                     LCB
# 106935                  70       M. Le Tissier                     RCB
# 106936                  37           M. Turner                     LCB
#
#           player_name  sk_player_id player_position
# 106932        H. Ladd         64166            RCMF
# 106933       K. Zelem         68743             DMF
# 106934      G. George         68681              LB
# 106935      M. Turner         63767             LCB
# 106936  M. Le Tissier         68697             RCB

# %%
field_length = 105
field_width = 68

# Adjust coordinates to center [0, 0]
match_event_df['pass_endlocation_x'] = match_event_df['pass_endlocation_x'] - field_length / 2
match_event_df['pass_endlocation_y'] = match_event_df['pass_endlocation_y'] - field_width / 2
match_event_df['location_x'] = match_event_df['location_x'] - field_length / 2
match_event_df['location_y'] = match_event_df['location_y'] - field_width / 2

# %%
match_event_df['team'] = match_event_df['sk_player_id'].apply(lambda x: 'home' if x in home_p_ids else
                                                                  'away' if x in away_p_ids else None)

# %%
tracking_path = f'data/FA/tracking/{match_id}.jsonl'

# %%
with jsonlines.open(tracking_path, 'r') as file:
    frame_to_period = {line['frame']: line['period'] for line in file}

# Map the period to each row using the pre-built dictionary
match_event_df['period'] = match_event_df['frame'].map(frame_to_period)

# %%
match_event_df.tail(20)
# Out:
#         sk_match_id  frame  location_x  location_y type_primary  \
# 310067      1133203  58791        -5.5        57.0         pass
# 310068      1133203  58800        -8.5        57.0         pass
# 310069      1133203  58823       -16.5        -9.0         pass
# 310074      1133203  58879         2.5        48.0         pass
# 310075      1133203  58892        -6.5        47.0         pass
# 310076      1133203  58915       -23.5       -12.0         pass
# 310077      1133203  58930        12.5        45.0         pass
# 310078      1133203  58939        22.5        56.0         pass
# 310080      1133203  58958       -25.5        -6.0         pass
# 310081      1133203  58993        19.5        27.0         pass
# 310082      1133203  59032         7.5         9.0         pass
# 310091      1133203  59264        43.5        49.0         pass
# 310097      1133203  59591        32.5         1.0         pass
# 310104      1133203  59879        34.5        40.0         pass
# 310107      1133203  59909        36.5        51.0         pass
# 310110      1133203  59946        42.5        58.0         pass
# 310111      1133203  59958        34.5        57.0         pass
# 310114      1133203  60032        -7.5        36.0         pass
# 310120      1133203  60326       -12.5       -29.0         pass
# 310126      1133203  60692        11.5        61.0         pass
#
#                                                                                                   type_secondary  \
# 310067                                                                         [back_pass, short_or_medium_pass]
# 310068                                                                           [forward_pass, long_pass, loss]
# 310069                                                       [head_pass, progressive_pass, short_or_medium_pass]
# 310074                                                                         [back_pass, short_or_medium_pass]
# 310075                                                      [forward_pass, long_pass, loss, pass_to_final_third]
# 310076                                   [forward_pass, head_pass, loss, progressive_pass, short_or_medium_pass]
# 310077  [forward_pass, head_pass, pass_to_final_third, recovery, counterpressing_recovery, short_or_medium_pass]
# 310078                                                                                    [short_or_medium_pass]
# 310080                                                            [loss, progressive_pass, short_or_medium_pass]
# 310081                                     [back_pass, recovery, counterpressing_recovery, short_or_medium_pass]
# 310082                                          [lateral_pass, long_pass, pass_to_final_third, progressive_pass]
# 310091                                                                                    [cross, cross_blocked]
# 310097                                                  [forward_pass, loss, short_or_medium_pass, touch_in_box]
# 310104                                                               [cross, cross_blocked, carry, touch_in_box]
# 310107                                                                      [forward_pass, short_or_medium_pass]
# 310110                                                                         [back_pass, short_or_medium_pass]
# 310111                                                         [cross, lateral_pass, loss, pass_to_penalty_area]
# 310114                                [forward_pass, long_pass, pass_to_final_third, progressive_pass, recovery]
# 310120                                                           [forward_pass, head_pass, short_or_medium_pass]
# 310126                                                         [loss, pass_to_final_third, short_or_medium_pass]
#
#         pass_angle  pass_endlocation_x  pass_endlocation_y  \
# 310067         180                -8.5                57.0
# 310068         -28                11.5                41.0
# 310069         -90               -16.5               -13.0
# 310074        -174                -6.5                47.0
# 310075          -4                18.5                44.0
# 310076          -8               -17.5               -13.0
# 310077          32                22.5                56.0
# 310078         -80                24.5                39.0
# 310080          83               -24.5                 5.0
# 310081        -137                 7.5                 9.0
# 310082          47                29.5                45.0
# 310091        -151               -52.5               -34.0
# 310097          29                40.5                 9.0
# 310104        -151               -52.5               -34.0
# 310107         -13                44.5                49.0
# 310110        -174                34.5                57.0
# 310111         -79                38.5                20.0
# 310114          24                19.5                56.0
# 310120         -14                -4.5               -32.0
# 310126         -45                17.5                51.0
#
#        pass_recipient_name pass_recipient_position  player_name  sk_player_id  \
# 310067           A. Patten                     RCB   S. Mayling         68672
# 310068           M. Turner                     LCB    A. Patten         68719
# 310069            J. Nobbs                    RCMF    M. Turner         63767
# 310074           A. Patten                     RCB      A. Leon         22735
# 310075           M. Turner                     LCB    A. Patten         68719
# 310076            J. Nobbs                    RCMF    M. Turner         63767
# 310077           E. Salmon                      LW     J. Nobbs         63765
# 310078             A. Leon                      RW    E. Salmon         62646
# 310080            J. Nobbs                    RCMF    M. Turner         63767
# 310081           R. Corsie                     LCB     J. Nobbs         63765
# 310082           E. Salmon                      LW    R. Corsie         22628
# 310091                <NA>                    <NA>      A. Leon         22735
# 310097           G. George                      LB      A. Leon         22735
# 310104                <NA>                    <NA>     J. Nobbs         63765
# 310107             A. Leon                      RW     J. Nobbs         63765
# 310110            J. Nobbs                    RCMF      A. Leon         22735
# 310111        Lucía García                      RW     J. Nobbs         63765
# 310114            J. Nobbs                    RCMF   S. Mayling         68672
# 310120        Lucía García                      LW  R. Williams         68734
# 310126            K. Zelem                     DMF   S. Mayling         68672
#
#        player_position  team  period
# 310067              RB  home     2.0
# 310068             RCB  home     2.0
# 310069             LCB  away     2.0
# 310074              RW  home     2.0
# 310075             RCB  home     2.0
# 310076             LCB  away     2.0
# 310077            RCMF  home     2.0
# 310078              LW  home     2.0
# 310080             LCB  away     2.0
# 310081            RCMF  home     2.0
# 310082             LCB  home     2.0
# 310091              RW  home     2.0
# 310097              RW  home     2.0
# 310104            RCMF  home     2.0
# 310107            RCMF  home     2.0
# 310110              RW  home     2.0
# 310111            RCMF  home     2.0
# 310114              RB  home     2.0
# 310120              CF  away     2.0
# 310126              RB  home     2.0

# %%
home_id = match_data['home_team']['id']
away_id = match_data['away_team']['id']

# %%
wt_json =[p for p in match_info['players'] if p['player_role']['position_group'] == 'Wide Attacker']

# %%
wt_info = [p['first_name']+ ' '+ p['last_name'] for p in wt_json]

# %%
wt_ids = [p['id'] for p in wt_json]
wt_ids
# Out:
# [22608, 64066, 22735, 68744, 22457, 64130]

# %%
pitch_length = 105  # Length of the pitch
pitch_width = 68    # Width of the pitch
box_width = 40.3 

def is_wide_channel(row):
    third_boundary = pitch_length / 6  # Boundary for attacking third
    half_width = pitch_width / 2
    wide_channel_limit = half_width - box_width  # Wide channel boundary on y-axis
    
    if row['team'] == 'home':
        if row['period'] == 1:  # Home team attacking right
            return (row['pass_endlocation_x'] > third_boundary) and (
                abs(row['pass_endlocation_y']) > wide_channel_limit)
        elif row['period'] == 2:  # Home team attacking left
            return (row['pass_endlocation_x'] < -third_boundary) and (
                abs(row['pass_endlocation_y']) > wide_channel_limit)
    elif row['team'] == 'away':
        if row['period'] == 1:  # Away team attacking left
            return (row['pass_endlocation_x'] < -third_boundary) and (
                abs(row['pass_endlocation_y']) > wide_channel_limit)
        elif row['period'] == 2:  # Away team attacking right
            return (row['pass_endlocation_x'] > third_boundary) and (
                abs(row['pass_endlocation_y']) > wide_channel_limit)
    return False

# %%
match_event_df['in_wide_channel'] = match_event_df.apply(is_wide_channel, axis=1)

# %%
match_event_df.in_wide_channel.value_counts()
# Out:
# in_wide_channel
# False    546
# True     229
# Name: count, dtype: int64

# %%
match_event_df[match_event_df['in_wide_channel'] == True]
# Out:
#         sk_match_id  frame  location_x  location_y type_primary  \
# 106933      1133203    126       -14.5         6.0         pass
# 106934      1133203    158       -19.5       -24.0         pass
# 106935      1133203    191       -23.5         5.0         pass
# 106936      1133203    222       -24.5        36.0         pass
# 106937      1133203    262       -23.5         3.0         pass
# 106971      1133203   1055       -15.5        49.0         pass
# 106972      1133203   1088       -25.5        25.0         pass
# 106973      1133203   1115       -23.5        15.0         pass
# 106985      1133203   1580        34.5        -8.0         pass
# 106990      1133203   1621       -43.5        28.0         pass
# 106996      1133203   2208        19.5       -16.0         pass
# 107001      1133203   2571       -46.5        16.0         pass
# 107003      1133203   2592       -44.5        48.0         pass
# 107004      1133203   2612       -34.5        62.0         pass
# 107010      1133203   2735       -20.5        45.0         pass
# 107012      1133203   2750       -20.5        62.0         pass
# 107015      1133203   2843       -13.5        63.0         pass
# 107049      1133203   3597       -17.5        21.0         pass
# 107104      1133203   5670       -22.5        56.0         pass
# 107105      1133203   5760       -29.5        22.0         pass
# 107106      1133203   5822       -22.5        27.0         pass
# 107110      1133203   5905        -3.5       -25.0         pass
# 107111      1133203   5926       -23.5       -31.0         pass
# 107112      1133203   5953       -25.5         6.0         pass
# 107119      1133203   6258       -22.5       -16.0         pass
# 107120      1133203   6307       -22.5        11.0         pass
# 107133      1133203   6784       -16.5       -21.0         pass
# 107136      1133203   6981       -27.5        34.0         pass
# 107151      1133203   7489       -15.5        50.0         pass
# 107157      1133203   7565       -15.5        47.0         pass
# 107158      1133203   7596       -21.5        56.0         pass
# 107159      1133203   7643       -48.5        25.0         pass
# 107160      1133203   7653       -40.5        21.0         pass
# 107177      1133203   8150         8.5        32.0         pass
# 107180      1133203   8189        24.5        34.0         pass
# 107206      1133203   9150       -22.5        11.0         pass
# 107220      1133203  10208        13.5        14.0         pass
# 107227      1133203  10369        17.5       -31.0         pass
# 107230      1133203  10439       -17.5        24.0         pass
# 107231      1133203  10458       -22.5        26.0         pass
# 107232      1133203  10486       -39.5        15.0         pass
# 107233      1133203  10554       -24.5         5.0         pass
# 107234      1133203  10577       -22.5        38.0         pass
# 107295      1133203  12214       -23.5       -23.0         pass
# 107296      1133203  12261       -40.5        12.0         pass
# 107297      1133203  12280       -40.5        27.0         pass
# 107298      1133203  12306       -28.5         0.0         pass
# 107299      1133203  12324       -25.5       -18.0         pass
# 107300      1133203  12349       -28.5         6.0         pass
# 107301      1133203  12398       -22.5        33.0         pass
# 107357      1133203  14414       -10.5        29.0         pass
# 107358      1133203  14448       -28.5        16.0         pass
# 107359      1133203  14486       -21.5         8.0         pass
# 107364      1133203  14582       -14.5        62.0         pass
# 107387      1133203  15342        32.5       -21.0         pass
# 107389      1133203  15396        21.5       -21.0         pass
# 107392      1133203  15469       -46.5        51.0         pass
# 107393      1133203  15478       -47.5        40.0         pass
# 308910      1133203  15512       -39.5        50.0         pass
# 308911      1133203  15547       -32.5        62.0         pass
# 308958      1133203  17400        -0.5       -28.0         pass
# 308961      1133203  17444       -22.5        51.0         pass
# 308962      1133203  17470       -38.5        56.0         pass
# 308963      1133203  17506       -44.5        26.0         pass
# 308965      1133203  17533       -32.5        35.0         pass
# 308969      1133203  17619       -17.5        37.0         pass
# 308970      1133203  17637       -20.5        21.0         pass
# 308986      1133203  18290       -15.5        16.0         pass
# 308988      1133203  18335       -33.5        16.0         pass
# 308989      1133203  18358       -27.5         5.0         pass
# 309091      1133203  21488         5.5        63.0         pass
# 309097      1133203  21645       -39.5        -6.0         pass
# 309099      1133203  21708       -30.5         8.0         pass
# 309100      1133203  21727       -28.5        -4.0         pass
# 309119      1133203  22529        13.5        30.0         pass
# 309126      1133203  23001        -9.5        62.0         pass
# 309127      1133203  23024       -20.5        60.0         pass
# 309128      1133203  23049       -37.5        55.0         pass
# 309129      1133203  23133       -40.5        21.0         pass
# 309131      1133203  23163       -29.5         6.0         pass
# 309132      1133203  23185       -31.5       -18.0         pass
# 309138      1133203  23267        11.5        46.0         pass
# 309139      1133203  23298        30.5        61.0         pass
# 309142      1133203  23338       -42.5        38.0         pass
# 309143      1133203  23387        21.5       -25.0         pass
# 309147      1133203  23418       -22.5         3.0         pass
# 309148      1133203  23451       -28.5         8.0         pass
# 309149      1133203  23467       -29.5        -2.0         pass
# 309150      1133203  23500       -40.5        10.0         pass
# 309151      1133203  23555       -40.5        30.0         pass
# 309153      1133203  23643       -21.5        10.0         pass
# 309154      1133203  23674       -24.5        44.0         pass
# 309155      1133203  23700       -22.5        60.0         pass
# 309156      1133203  23714       -27.5        44.0         pass
# 309157      1133203  23728       -28.5        53.0         pass
# 309159      1133203  23834       -33.5        17.0         pass
# 309248      1133203  26506        14.5        58.0         pass
# 309263      1133203  26793        28.5        56.0         pass
# 309275      1133203  27083        19.5        56.0         pass
# 309278      1133203  27106       -33.5       -24.0         pass
# 309296      1133203  27317        12.5        32.0         pass
# 309297      1133203  27335       -32.5        -4.0         pass
# 309299      1133203  27401        40.5        61.0         pass
# 309308      1133203  27858       -13.5         8.0         pass
# 309309      1133203  27894       -20.5        30.0         pass
# 309326      1133203  28444         3.5        48.0         pass
# 309327      1133203  28507       -48.5       -21.0         pass
# 309364      1133203  29518        10.5        60.0         pass
# 309367      1133203  29605        39.5        57.0         pass
# 309374      1133203  29746       -50.5       -17.0         pass
# 309375      1133203  29763       -48.5       -27.0         pass
# 309379      1133203  29792        39.5        50.0         pass
# 309380      1133203  29803        34.5        56.0         pass
# 309386      1133203  29974        30.5        53.0         pass
# 309387      1133203  29987        22.5        62.0         pass
# 309391      1133203  30010       -34.5       -24.0         pass
# 309392      1133203  30019       -39.5       -17.0         pass
# 309399      1133203  30090       -13.5        19.0         pass
# 309404      1133203  30126       -18.5        28.0         pass
# 309439      1133203  30869        36.5        40.0         pass
# 309442      1133203  30930        39.5        42.0         pass
# 309444      1133203  30967        20.5        31.0         pass
# 309448      1133203  31212        -8.5       -10.0         pass
# 309453      1133203  31323        28.5       -19.0         pass
# 309454      1133203  31342        35.5       -24.0         pass
# 309457      1133203  31373        35.5       -23.0         pass
# 309458      1133203  31388        33.5       -28.0         pass
# 309459      1133203  31396        36.5       -20.0         pass
# 309483      1133203  32372         6.5       -21.0         pass
# 309491      1133203  32561        15.5        21.0         pass
# 309496      1133203  32698        15.5       -21.0         pass
# 309502      1133203  32760       -40.5         9.0         pass
# 309505      1133203  32800       -33.5       -10.0         pass
# 309506      1133203  32819       -41.5         5.0         pass
# 309508      1133203  32864         5.5         1.0         pass
# 309511      1133203  32906       -18.5        13.0         pass
# 309518      1133203  33235       -45.5        -2.0         pass
# 309519      1133203  33264       -46.5        25.0         pass
# 309521      1133203  33308       -28.5        62.0         pass
# 309525      1133203  33524       -22.5        43.0         pass
# 309530      1133203  33661       -14.5       -27.0         pass
# 309532      1133203  33700       -12.5         1.0         pass
# 309533      1133203  33748       -22.5        -8.0         pass
# 309570      1133203  35507       -13.5        60.0         pass
# 309584      1133203  36221        -9.5        18.0         pass
# 309586      1133203  36302        36.5       -24.0         pass
# 309589      1133203  36361        28.5       -15.0         pass
# 309591      1133203  36550       -38.5        15.0         pass
# 309603      1133203  36909         3.5       -29.0         pass
# 309604      1133203  36942       -18.5       -22.0         pass
# 309605      1133203  36958       -25.5       -17.0         pass
# 309607      1133203  37010       -20.5       -29.0         pass
# 309616      1133203  37136        -7.5        17.0         pass
# 309628      1133203  38220       -44.5        49.0         pass
# 309629      1133203  38251       -45.5        15.0         pass
# 309657      1133203  39960        42.5        -9.0         pass
# 309704      1133203  43435       -34.5         2.0         pass
# 309705      1133203  43451       -27.5        27.0         pass
# 309709      1133203  43679       -27.5        29.0         pass
# 309713      1133203  43772        12.5         1.0         pass
# 309716      1133203  43819        22.5        -8.0         pass
# 309717      1133203  43836        20.5         0.0         pass
# 309718      1133203  43855        39.5        35.0         pass
# 309727      1133203  44112       -31.5        60.0         pass
# 309734      1133203  44212       -17.5        38.0         pass
# 309735      1133203  44222       -20.5        20.0         pass
# 309736      1133203  44247       -40.5        33.0         pass
# 309737      1133203  44272       -45.5        21.0         pass
# 309739      1133203  44313       -33.5        -7.0         pass
# 309749      1133203  44570        17.5       -11.0         pass
# 309762      1133203  45837        18.5        21.0         pass
# 309763      1133203  45870        41.5        50.0         pass
# 309774      1133203  46247       -39.5        -2.0         pass
# 309796      1133203  47395        19.5         9.0         pass
# 309797      1133203  47412        23.5        20.0         pass
# 309798      1133203  47439        38.5        39.0         pass
# 309802      1133203  47754        25.5        36.0         pass
# 309807      1133203  48200        40.5         7.0         pass
# 309810      1133203  48225        41.5        17.0         pass
# 309818      1133203  49034        11.5       -18.0         pass
# 309822      1133203  49099        44.5        -6.0         pass
# 309842      1133203  50768       -15.5        29.0         pass
# 309844      1133203  50876       -30.5        25.0         pass
# 309851      1133203  51065       -12.5       -29.0         pass
# 309854      1133203  51128        42.5        -8.0         pass
# 309863      1133203  51560        -7.5       -21.0         pass
# 309864      1133203  51593       -23.5         3.0         pass
# 309865      1133203  51676       -28.5        21.0         pass
# 309873      1133203  51839        12.5        -1.0         pass
# 309874      1133203  51863        20.5         1.0         pass
# 309875      1133203  51907        36.5       -27.0         pass
# 309903      1133203  52816        10.5         8.0         pass
# 309904      1133203  52872        30.5       -25.0         pass
# 309905      1133203  52892        38.5       -21.0         pass
# 309925      1133203  53618        17.5        42.0         pass
# 309928      1133203  53658        33.5        51.0         pass
# 309929      1133203  53732        40.5       -18.0         pass
# 309931      1133203  53750        35.5       -22.0         pass
# 309943      1133203  54259        11.5        38.0         pass
# 309944      1133203  54284        35.5        57.0         pass
# 309947      1133203  54334        43.5        39.0         pass
# 309949      1133203  54363        34.5        27.0         pass
# 309966      1133203  55213         9.5        33.0         pass
# 309968      1133203  55275        36.5        40.0         pass
# 309969      1133203  55288        25.5        43.0         pass
# 309971      1133203  55320       -29.5       -10.0         pass
# 309973      1133203  55368        16.5        21.0         pass
# 309974      1133203  55399        19.5       -24.0         pass
# 309981      1133203  55461        26.5         3.0         pass
# 309990      1133203  55855        29.5        38.0         pass
# 310005      1133203  56849        -9.5        30.0         pass
# 310006      1133203  56893       -26.5        30.0         pass
# 310007      1133203  56918       -38.5         5.0         pass
# 310008      1133203  56961       -26.5        -7.0         pass
# 310009      1133203  56985       -32.5        16.0         pass
# 310016      1133203  57219       -19.5        40.0         pass
# 310018      1133203  57296        26.5        29.0         pass
# 310019      1133203  57345        40.5        -4.0         pass
# 310020      1133203  57367        38.5        -2.0         pass
# 310022      1133203  57397        32.5       -20.0         pass
# 310023      1133203  57441        19.5        10.0         pass
# 310024      1133203  57470        22.5        37.0         pass
# 310025      1133203  57500        34.5        54.0         pass
# 310026      1133203  57507        31.5        33.0         pass
# 310036      1133203  58180         2.5       -29.0         pass
# 310040      1133203  58333       -22.5        52.0         pass
# 310048      1133203  58386         4.5       -20.0         pass
# 310091      1133203  59264        43.5        49.0         pass
# 310104      1133203  59879        34.5        40.0         pass
#
#                                                                                                                 type_secondary  \
# 106933                                                                                    [lateral_pass, short_or_medium_pass]
# 106934                                                                                    [lateral_pass, short_or_medium_pass]
# 106935                                                                                    [lateral_pass, short_or_medium_pass]
# 106936                                                                                    [lateral_pass, short_or_medium_pass]
# 106937                                                                                    [lateral_pass, short_or_medium_pass]
# 106971                                                                                    [lateral_pass, short_or_medium_pass]
# 106972                                                                                                  [short_or_medium_pass]
# 106973                                                                                                  [short_or_medium_pass]
# 106985                                                     [cross, deep_completed_cross, key_pass, lateral_pass, touch_in_box]
# 106990                                                       [forward_pass, long_pass, loss, progressive_pass, under_pressure]
# 106996                                            [forward_pass, pass_to_penalty_area, progressive_pass, short_or_medium_pass]
# 107001                                                                                    [lateral_pass, short_or_medium_pass]
# 107003                                                                                    [forward_pass, short_or_medium_pass]
# 107004                                                                                    [forward_pass, short_or_medium_pass]
# 107010                                                          [loss, progressive_pass, short_or_medium_pass, under_pressure]
# 107012                                                                [progressive_pass, short_or_medium_pass, under_pressure]
# 107015                                                                       [back_pass, short_or_medium_pass, under_pressure]
# 107049                                                                                    [lateral_pass, short_or_medium_pass]
# 107104                                                      [forward_pass, long_pass, loss, pass_to_final_third, through_pass]
# 107105                                                                          [forward_pass, recovery, short_or_medium_pass]
# 107106                                                                                                  [short_or_medium_pass]
# 107110                                                                                       [back_pass, short_or_medium_pass]
# 107111                                                                    [lateral_pass, short_or_medium_pass, under_pressure]
# 107112                                                                                    [lateral_pass, short_or_medium_pass]
# 107119                                                                                    [lateral_pass, short_or_medium_pass]
# 107120                                                                                    [lateral_pass, short_or_medium_pass]
# 107133                                                        [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 107136                                                                                    [lateral_pass, short_or_medium_pass]
# 107151                                                                       [back_pass, short_or_medium_pass, under_pressure]
# 107157                                                                                       [back_pass, short_or_medium_pass]
# 107158                                                                                       [back_pass, short_or_medium_pass]
# 107159                                                                                    [forward_pass, short_or_medium_pass]
# 107160                                                                                    [lateral_pass, short_or_medium_pass]
# 107177                                                               [forward_pass, pass_to_final_third, short_or_medium_pass]
# 107180                                                                                            [loss, short_or_medium_pass]
# 107206                                                        [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 107220  [forward_pass, loss, pass_to_final_third, pass_to_penalty_area, carry, short_or_medium_pass, smart_pass, through_pass]
# 107227                                                                                    [forward_pass, short_or_medium_pass]
# 107230                                                                       [back_pass, short_or_medium_pass, under_pressure]
# 107231                                                                       [back_pass, short_or_medium_pass, under_pressure]
# 107232                                                                                    [forward_pass, short_or_medium_pass]
# 107233                                                                                    [lateral_pass, short_or_medium_pass]
# 107234                                                                                                  [short_or_medium_pass]
# 107295                                                                                    [lateral_pass, short_or_medium_pass]
# 107296                                                                                                  [short_or_medium_pass]
# 107297                                                                                    [lateral_pass, short_or_medium_pass]
# 107298                                                                                    [lateral_pass, short_or_medium_pass]
# 107299                                                                                    [lateral_pass, short_or_medium_pass]
# 107300                                                                                    [lateral_pass, short_or_medium_pass]
# 107301                                                                                                  [short_or_medium_pass]
# 107357                                                                       [back_pass, short_or_medium_pass, under_pressure]
# 107358                                                                                    [forward_pass, short_or_medium_pass]
# 107359                                                                                    [lateral_pass, short_or_medium_pass]
# 107364                                                                                    [lateral_pass, short_or_medium_pass]
# 107387                                                                       [cross, lateral_pass, loss, pass_to_penalty_area]
# 107389                                                [forward_pass, recovery, counterpressing_recovery, short_or_medium_pass]
# 107392                                                                                                  [short_or_medium_pass]
# 107393                                                                    [forward_pass, short_or_medium_pass, under_pressure]
# 308910                                                                                                  [short_or_medium_pass]
# 308911                                                                                                  [short_or_medium_pass]
# 308958                                                        [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 308961                                                                            [back_pass, head_pass, short_or_medium_pass]
# 308962                                                                    [lateral_pass, short_or_medium_pass, under_pressure]
# 308963                                                                                                  [short_or_medium_pass]
# 308965                                                                                    [forward_pass, short_or_medium_pass]
# 308969                                                                                                  [short_or_medium_pass]
# 308970                                                                                    [lateral_pass, short_or_medium_pass]
# 308986                                   [back_pass, recovery, counterpressing_recovery, short_or_medium_pass, under_pressure]
# 308988                                                                                                  [short_or_medium_pass]
# 308989                                                                                    [lateral_pass, short_or_medium_pass]
# 309091                                             [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309097                                                                                                  [short_or_medium_pass]
# 309099                                                                                                  [short_or_medium_pass]
# 309100                                                                                    [lateral_pass, short_or_medium_pass]
# 309119                                   [forward_pass, key_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309126                                                                                       [back_pass, short_or_medium_pass]
# 309127                                                                                       [back_pass, short_or_medium_pass]
# 309128                                                                                    [lateral_pass, short_or_medium_pass]
# 309129                                                                                                  [short_or_medium_pass]
# 309131                                                                                    [lateral_pass, short_or_medium_pass]
# 309132                                                                                    [forward_pass, short_or_medium_pass]
# 309138                                                               [forward_pass, pass_to_final_third, short_or_medium_pass]
# 309139                                     [cross, deep_completed_cross, lateral_pass, pass_to_penalty_area, progressive_pass]
# 309142                                                                       [forward_pass, long_pass, loss, progressive_pass]
# 309143                                                                       [cross, lateral_pass, loss, pass_to_penalty_area]
# 309147                                                                                       [back_pass, short_or_medium_pass]
# 309148                                                                                                  [short_or_medium_pass]
# 309149                                                                       [back_pass, short_or_medium_pass, under_pressure]
# 309150                                                                                    [lateral_pass, short_or_medium_pass]
# 309151                                                                                    [lateral_pass, short_or_medium_pass]
# 309153                                                                                    [lateral_pass, short_or_medium_pass]
# 309154                                                                                                  [short_or_medium_pass]
# 309155                                                                                    [lateral_pass, short_or_medium_pass]
# 309156                                                                                  [short_or_medium_pass, under_pressure]
# 309157                                                                    [lateral_pass, short_or_medium_pass, under_pressure]
# 309159                                                                                                  [short_or_medium_pass]
# 309248                                                                  [forward_pass, progressive_pass, short_or_medium_pass]
# 309263                                                                                 [back_pass, loss, short_or_medium_pass]
# 309275                                                                                    [forward_pass, short_or_medium_pass]
# 309278                                                                                  [short_or_medium_pass, under_pressure]
# 309296                                                               [forward_pass, pass_to_final_third, short_or_medium_pass]
# 309297                                            [forward_pass, loss, progressive_pass, short_or_medium_pass, under_pressure]
# 309299                                                                                       [back_pass, short_or_medium_pass]
# 309308                                                                                    [lateral_pass, short_or_medium_pass]
# 309309                                                                                    [lateral_pass, short_or_medium_pass]
# 309326                                                                          [forward_pass, long_pass, pass_to_final_third]
# 309327                                                                          [forward_pass, recovery, short_or_medium_pass]
# 309364                                             [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309367                                                                                       [back_pass, short_or_medium_pass]
# 309374                                                                                                  [short_or_medium_pass]
# 309375                                                          [loss, progressive_pass, short_or_medium_pass, under_pressure]
# 309379                                                                                       [back_pass, short_or_medium_pass]
# 309380                                                        [lateral_pass, loss, pass_to_penalty_area, short_or_medium_pass]
# 309386                                                                                       [back_pass, short_or_medium_pass]
# 309387                                                                                                  [short_or_medium_pass]
# 309391                                                                                       [back_pass, short_or_medium_pass]
# 309392                                                                                    [forward_pass, short_or_medium_pass]
# 309399                                                                                       [back_pass, short_or_medium_pass]
# 309404                                                                                       [back_pass, short_or_medium_pass]
# 309439                                                                               [cross, lateral_pass, loss, touch_in_box]
# 309442                                                                               [cross, lateral_pass, loss, touch_in_box]
# 309444                                                           [forward_pass, long_pass, pass_to_penalty_area, through_pass]
# 309448                                        [forward_pass, long_pass, pass_to_final_third, progressive_pass, under_pressure]
# 309453                                                                          [forward_pass, recovery, short_or_medium_pass]
# 309454                                                                                       [back_pass, short_or_medium_pass]
# 309457                                                                                                  [short_or_medium_pass]
# 309458                                                                                                  [short_or_medium_pass]
# 309459                                                                                    [forward_pass, short_or_medium_pass]
# 309483                                               [forward_pass, pass_to_final_third, short_or_medium_pass, under_pressure]
# 309491                                                                                    [forward_pass, short_or_medium_pass]
# 309496                                                     [lateral_pass, progressive_pass, short_or_medium_pass, shot_assist]
# 309502                                                                                    [lateral_pass, short_or_medium_pass]
# 309505                                                                                    [lateral_pass, short_or_medium_pass]
# 309506                                                                       [back_pass, short_or_medium_pass, under_pressure]
# 309508                        [forward_pass, head_pass, pass_to_final_third, progressive_pass, recovery, short_or_medium_pass]
# 309511                                               [back_pass, loss, progressive_pass, short_or_medium_pass, under_pressure]
# 309518                                                                                    [lateral_pass, short_or_medium_pass]
# 309519                                                          [back_pass, long_pass, loss, progressive_pass, under_pressure]
# 309521                                                       [forward_pass, long_pass, loss, progressive_pass, under_pressure]
# 309525                                                                                    [lateral_pass, short_or_medium_pass]
# 309530                                                                                    [lateral_pass, short_or_medium_pass]
# 309532                                                                                       [back_pass, short_or_medium_pass]
# 309533                                                                                       [back_pass, short_or_medium_pass]
# 309570                                                                       [back_pass, short_or_medium_pass, under_pressure]
# 309584                                                        [forward_pass, long_pass, pass_to_final_third, progressive_pass]
# 309586                                                                                                  [short_or_medium_pass]
# 309589                                                                       [cross, lateral_pass, loss, pass_to_penalty_area]
# 309591                                                                         [hand_pass, lateral_pass, short_or_medium_pass]
# 309603                                                                                       [back_pass, short_or_medium_pass]
# 309604                                                                       [back_pass, short_or_medium_pass, under_pressure]
# 309605                                                          [loss, progressive_pass, short_or_medium_pass, under_pressure]
# 309607                                                   [back_pass, recovery, counterpressing_recovery, short_or_medium_pass]
# 309616                                                                                       [back_pass, short_or_medium_pass]
# 309628                                                                                    [lateral_pass, short_or_medium_pass]
# 309629                                                                                    [lateral_pass, short_or_medium_pass]
# 309657                                                                                    [cross, cross_blocked, touch_in_box]
# 309704                                                                                    [lateral_pass, short_or_medium_pass]
# 309705                                                                                    [lateral_pass, short_or_medium_pass]
# 309709                                                                    [forward_pass, long_pass, loss, pass_to_final_third]
# 309713                                                     [lateral_pass, pass_to_final_third, recovery, short_or_medium_pass]
# 309716                                                                                                  [short_or_medium_pass]
# 309717                        [deep_completion, lateral_pass, long_pass, pass_to_penalty_area, progressive_pass, through_pass]
# 309718                                                                   [head_pass, loss, short_or_medium_pass, touch_in_box]
# 309727                                                                          [loss, progressive_pass, short_or_medium_pass]
# 309734                                                                                    [lateral_pass, short_or_medium_pass]
# 309735                                                                                       [back_pass, short_or_medium_pass]
# 309736                                                                                                  [short_or_medium_pass]
# 309737                                                                                    [lateral_pass, short_or_medium_pass]
# 309739                                                                                    [forward_pass, short_or_medium_pass]
# 309749                                                                                    [forward_pass, short_or_medium_pass]
# 309762                                                                                               [forward_pass, long_pass]
# 309763                                                                                                  [cross, cross_blocked]
# 309774                                                                               [lateral_pass, long_pass, under_pressure]
# 309796                                                                                                  [short_or_medium_pass]
# 309797                                             [deep_completion, forward_pass, pass_to_penalty_area, short_or_medium_pass]
# 309798                                                                                    [cross, cross_blocked, touch_in_box]
# 309802                                     [cross, deep_completed_cross, forward_pass, pass_to_penalty_area, progressive_pass]
# 309807                                                                   [deep_completion, short_or_medium_pass, touch_in_box]
# 309810                                    [assist, deep_completion, key_pass, short_or_medium_pass, shot_assist, touch_in_box]
# 309818                                                               [forward_pass, pass_to_final_third, short_or_medium_pass]
# 309822                                                      [cross, deep_completed_cross, key_pass, shot_assist, touch_in_box]
# 309842                                                                                       [back_pass, short_or_medium_pass]
# 309844                                                                       [forward_pass, long_pass, loss, progressive_pass]
# 309851                 [deep_completion, forward_pass, long_pass, pass_to_final_third, pass_to_penalty_area, progressive_pass]
# 309854                                                                                    [cross, cross_blocked, touch_in_box]
# 309863                                                                                       [back_pass, short_or_medium_pass]
# 309864                                                                                    [lateral_pass, short_or_medium_pass]
# 309865                                                                       [forward_pass, long_pass, loss, progressive_pass]
# 309873                           [forward_pass, pass_to_final_third, recovery, counterpressing_recovery, short_or_medium_pass]
# 309874                                                                                    [lateral_pass, short_or_medium_pass]
# 309875                                                                       [cross, lateral_pass, loss, pass_to_penalty_area]
# 309903                                                                          [lateral_pass, long_pass, pass_to_final_third]
# 309904                                                                                    [forward_pass, short_or_medium_pass]
# 309905                                                                                             [cross, lateral_pass, loss]
# 309925                                                                          [forward_pass, recovery, short_or_medium_pass]
# 309928                                                                                        [cross, lateral_pass, long_pass]
# 309929                                                                            [pass_to_penalty_area, short_or_medium_pass]
# 309931                                                                                 [back_pass, loss, short_or_medium_pass]
# 309943                                             [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309944                           [deep_completion, lateral_pass, pass_to_penalty_area, progressive_pass, short_or_medium_pass]
# 309947                                                                               [cross, lateral_pass, loss, touch_in_box]
# 309949        [deep_completion, key_pass, recovery, counterpressing_recovery, short_or_medium_pass, shot_assist, touch_in_box]
# 309966                                             [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 309968                                                                         [back_pass, short_or_medium_pass, touch_in_box]
# 309969                                                                [cross, lateral_pass, loss, pass_to_penalty_area, carry]
# 309971                                               [head_pass, loss, progressive_pass, short_or_medium_pass, under_pressure]
# 309973                                                                                    [lateral_pass, short_or_medium_pass]
# 309974                                                                                    [forward_pass, short_or_medium_pass]
# 309981                                                                           [key_pass, short_or_medium_pass, shot_assist]
# 309990      [assist, cross, deep_completed_cross, key_pass, lateral_pass, pass_to_penalty_area, progressive_pass, shot_assist]
# 310005                                                                                       [back_pass, short_or_medium_pass]
# 310006                                                                                    [lateral_pass, short_or_medium_pass]
# 310007                                                                                    [forward_pass, short_or_medium_pass]
# 310008                                                                                    [lateral_pass, short_or_medium_pass]
# 310009                                                                                    [forward_pass, short_or_medium_pass]
# 310016                                                            [forward_pass, long_pass, pass_to_final_third, through_pass]
# 310018                                          [deep_completion, lateral_pass, long_pass, pass_to_penalty_area, through_pass]
# 310019                                                        [back_pass, deep_completion, short_or_medium_pass, touch_in_box]
# 310020                                                                                    [short_or_medium_pass, touch_in_box]
# 310022                                                                                    [lateral_pass, short_or_medium_pass]
# 310023                                                                                    [lateral_pass, short_or_medium_pass]
# 310024                                                                                    [forward_pass, short_or_medium_pass]
# 310025                                                                                    [lateral_pass, short_or_medium_pass]
# 310026                                                              [forward_pass, pass_to_penalty_area, short_or_medium_pass]
# 310036                                             [forward_pass, pass_to_final_third, progressive_pass, short_or_medium_pass]
# 310040                                                                                                  [short_or_medium_pass]
# 310048                                                                          [forward_pass, long_pass, pass_to_final_third]
# 310091                                                                                                  [cross, cross_blocked]
# 310104                                                                             [cross, cross_blocked, carry, touch_in_box]
#
#         pass_angle  pass_endlocation_x  pass_endlocation_y  \
# 106933        -104               -19.5               -24.0
# 106934         104               -23.5                 5.0
# 106935          93               -24.5                36.0
# 106936         -88               -23.5                 3.0
# 106937          79               -19.5                40.0
# 106971        -125               -25.5                25.0
# 106972         -74               -23.5                15.0
# 106973          61               -18.5                30.0
# 106985          90                34.5                23.0
# 106990         -22               -27.5                17.0
# 106996          11                43.5                -9.0
# 107001          79               -43.5                40.0
# 107003          39               -34.5                62.0
# 107004          -4               -22.5                60.0
# 107010          84               -19.5                60.0
# 107012          56               -18.5                66.0
# 107015        -162               -19.5                60.0
# 107049         -94               -18.5                 1.0
# 107104         -32                24.5                10.0
# 107105          21               -22.5                27.0
# 107106        -100               -23.5                10.0
# 107110        -169               -23.5               -31.0
# 107111          95               -25.5                 6.0
# 107112          76               -20.5                41.0
# 107119          90               -22.5                11.0
# 107120          80               -18.5                45.0
# 107133          -3                19.5               -24.0
# 107136         -85               -25.5                 0.0
# 107151         135               -19.5                55.0
# 107157         135               -21.5                56.0
# 107158        -144               -48.5                25.0
# 107159         -18               -40.5                21.0
# 107160         101               -43.5                50.0
# 107177         -24                18.5                25.0
# 107180         -95                23.5                17.0
# 107206          27                31.5                53.0
# 107220           0                34.5                14.0
# 107227          27                21.5               -28.0
# 107230         158               -22.5                26.0
# 107231        -156               -39.5                15.0
# 107232         -22               -24.5                 5.0
# 107233          82               -22.5                38.0
# ...
# 106934         68681              LB  away     1.0             True
# 106935         63767             LCB  away     1.0             True
# 106936         68697             RCB  away     1.0             True
# 106937         63767             LCB  away     1.0             True
# 106971         68697             RCB  away     1.0             True
# 106972         22622              GK  away     1.0             True
# 106973         63767             LCB  away     1.0             True
# 106985         64066            LAMF  home     1.0             True
# 106990         57096              RB  away     1.0             True
# 106996         68680              LB  home     1.0             True
# 107001         22622              GK  away     1.0             True
# 107003         68697             RCB  away     1.0             True
# 107004         57096              RB  away     1.0             True
# 107010         68743             DMF  away     1.0             True
# 107012         57096              RB  away     1.0             True
# 107015         22457              RW  away     1.0             True
# 107049         68697             RCB  away     1.0             True
# 107104         68719             RCB  home     1.0             True
# 107105         22622              GK  away     1.0             True
# 107106         68697             RCB  away     1.0             True
# 107110         68681              LB  away     1.0             True
# 107111         68743             DMF  away     1.0             True
# 107112         63767             LCB  away     1.0             True
# 107119         68681              LB  away     1.0             True
# 107120         63767             LCB  away     1.0             True
# 107133         22618              CF  home     1.0             True
# 107136         68697             RCB  away     1.0             True
# 107151         64166            RCMF  away     1.0             True
# 107157         68743             DMF  away     1.0             True
# 107158         57096              RB  away     1.0             True
# 107159         22622              GK  away     1.0             True
# 107160         63767             LCB  away     1.0             True
# 107177         68675             AMF  home     1.0             True
# 107180         22618              CF  home     1.0             True
# 107206         22624            LDMF  home     1.0             True
# 107220         68661            RDMF  home     1.0             True
# 107227         64066            LAMF  home     1.0             True
# 107230         62411            LCMF  away     1.0             True
# 107231         68743             DMF  away     1.0             True
# 107232         22622              GK  away     1.0             True
# 107233         63767             LCB  away     1.0             True
# 107234         68697             RCB  away     1.0             True
# 107295         68744              LW  away     1.0             True
# 107296         22622              GK  away     1.0             True
# 107297         68697             RCB  away     1.0             True
# 107298         63767             LCB  away     1.0             True
# 107299         68681              LB  away     1.0             True
# 107300         63767             LCB  away     1.0             True
# 107301         68697             RCB  away     1.0             True
# 107357         68697             RCB  away     1.0             True
# 107358         22622              GK  away     1.0             True
# 107359         63767             LCB  away     1.0             True
# 107364         57096              RB  away     1.0             True
# 107387         64066            LAMF  home     1.0             True
# 107389         64066            LAMF  home     1.0             True
# 107392         22457              RW  away     1.0             True
# 107393         57096              RB  away     1.0             True
# 308910         68743             DMF  away     1.0             True
# 308911         22457              RW  away     1.0             True
# 308958         64066            LAMF  home     1.0             True
# 308961         57096              RB  away     1.0             True
# 308962         68743             DMF  away     1.0             True
# 308963         22622              GK  away     1.0             True
# 308965         68697             RCB  away     1.0             True
# 308969         64166            RCMF  away     1.0             True
# 308970         68743             DMF  away     1.0             True
# 308986         68697             RCB  away     1.0             True
# 308988         22622              GK  away     1.0             True
# 308989         63767             LCB  away     1.0             True
# 309091         68661            RDMF  home     1.0             True
# 309097         63767             LCB  away     1.0             True
# 309099         68697             RCB  away     1.0             True
# 309100         63767             LCB  away     1.0             True
# 309119         68661            RDMF  home     1.0             True
# 309126         22457              RW  away     1.0             True
# 309127         57096              RB  away     1.0             True
# 309128         68697             RCB  away     1.0             True
# 309129         22622              GK  away     1.0             True
# 309131         63767             LCB  away     1.0             True
# 309132         68681              LB  away     1.0             True
# 309138         22624            LDMF  home     1.0             True
# 309139         68672              RB  home     1.0             True
# 309142         57096              RB  away     1.0             True
# 309143         68680              LB  home     1.0             True
# 309147         68744              LW  away     1.0             True
# 309148         62411            LCMF  away     1.0             True
# 309149         68681              LB  away     1.0             True
# 309150         63767             LCB  away     1.0             True
# 309151         68697             RCB  away     1.0             True
# 309153         63767             LCB  away     1.0             True
# 309154         68697             RCB  away     1.0             True
# 309155         57096              RB  away     1.0             True
# 309156         68697             RCB  away     1.0             True
# 309157         57096              RB  away     1.0             True
# 309159         22622              GK  away     1.0             True
# 309248         68672              RB  home     1.0             True
# 309263         68675             AMF  home     1.0             True
# 309275         22624            LDMF  home     1.0             True
# 309278         68744              LW  away     1.0             True
# 309296         22624            LDMF  home     1.0             True
# 309297         63767             LCB  away     1.0             True
# 309299         64130            RAMF  home     1.0             True
# 309308         22624            LDMF  home     2.0             True
# 309309         68719             RCB  home     2.0             True
# 309326         68743             DMF  away     2.0             True
# 309327         22628             LCB  home     2.0             True
# 309364         68697             RCB  away     2.0             True
# 309367         22555              CF  away     2.0             True
# 309374         22628             LCB  home     2.0             True
# 309375         64066            LAMF  home     2.0             True
# 309379         22555              CF  away     2.0             True
# 309380         57096              RB  away     2.0             True
# 309386         22457              RW  away     2.0             True
# 309387         57096              RB  away     2.0             True
# 309391         64066            LAMF  home     2.0             True
# 309392         68680              LB  home     2.0             True
# 309399         68661            RDMF  home     2.0             True
# 309404         64130            RAMF  home     2.0             True
# 309439         22555              CF  away     2.0             True
# 309442         57096              RB  away     2.0             True
# 309444         68743             DMF  away     2.0             True
# 309448         63767             LCB  away     2.0             True
# 309453         68681              LB  away     2.0             True
# 309454         68744              LW  away     2.0             True
# 309457         62411            LCMF  away     2.0             True
# 309458         68744              LW  away     2.0             True
# 309459         68681              LB  away     2.0             True
# 309483         63767             LCB  away     2.0             True
# 309491         62411            LCMF  away     2.0             True
# 309496         68681              LB  away     2.0             True
# 309502         22628             LCB  home     2.0             True
# 309505         64066            LAMF  home     2.0             True
# 309506         22628             LCB  home     2.0             True
# 309508         63767             LCB  away     2.0             True
# 309511         68661            RDMF  home     2.0             True
# 309518         22628             LCB  home     2.0             True
# 309519         63552              GK  home     2.0             True
# 309521         68672              RB  home     2.0             True
# 309525         22624            LDMF  home     2.0             True
# 309530         68680              LB  home     2.0             True
# 309532         22624            LDMF  home     2.0             True
# 309533         22628             LCB  home     2.0             True
# 309570         22618              CF  home     2.0             True
# 309584         68697             RCB  away     2.0             True
# 309586         68744              LW  away     2.0             True
# 309589         22555              CF  away     2.0             True
# 309591         63552              GK  home     2.0             True
# 309603         64066            LAMF  home     2.0             True
# 309604         68680              LB  home     2.0             True
# 309605         22628             LCB  home     2.0             True
# 309607         68680              LB  home     2.0             True
# 309616         22618              CF  home     2.0             True
# 309628         68719             RCB  home     2.0             True
# 309629         63552              GK  home     2.0             True
# 309657         64066            LAMF  home     2.0             True
# 309704         63552              GK  home     2.0             True
# 309705         68719             RCB  home     2.0             True
# 309709         22622              GK  away     2.0             True
# 309713         68734              CF  away     2.0             True
# 309716         22457              LW  away     2.0             True
# 309717         62411            LCMF  away     2.0             True
# 309718         22608              RW  away     2.0             True
# 309727         22735            RAMF  home     2.0             True
# 309734         68661            RDMF  home     2.0             True
# 309735         22624            LDMF  home     2.0             True
# 309736         68719             RCB  home     2.0             True
# 309737         63552              GK  home     2.0             True
# 309739         22628             LCB  home     2.0             True
# 309749         62411            LCMF  away     2.0             True
# 309762         62411            LCMF  away     2.0             True
# 309763         22608              RW  away     2.0             True
# 309774         22628             LCB  home     2.0             True
# 309796         68743             DMF  away     2.0             True
# 309797         62411            LCMF  away     2.0             True
# 309798         57096              RB  away     2.0             True
# 309802         62411            LCMF  away     2.0             True
# 309807         68697             RCB  away     2.0             True
# 309810         63767             LCB  away     2.0             True
# 309818         62411            LCMF  away     2.0             True
# 309822         22457              LW  away     2.0             True
# 309842         22628             LCB  home     2.0             True
# 309844         63552              GK  home     2.0             True
# 309851         68681              LB  away     2.0             True
# 309854         22457              LW  away     2.0             True
# 309863         68680              LB  home     2.0             True
# 309864         22628             LCB  home     2.0             True
# 309865         63552              GK  home     2.0             True
# 309873         22457              LW  away     2.0             True
# 309874         62411            LCMF  away     2.0             True
# 309875         68681              LB  away     2.0             True
# 309903         68743             DMF  away     2.0             True
# 309904         22457              LW  away     2.0             True
# 309905         68681              LB  away     2.0             True
# 309925         22608              RW  away     2.0             True
# 309928         62505            RCMF  away     2.0             True
# 309929         22457              LW  away     2.0             True
# 309931         62411            LCMF  away     2.0             True
# 309943         57096              RB  away     2.0             True
# 309944         22608              RW  away     2.0             True
# 309947         62411            LCMF  away     2.0             True
# 309949         22608              RW  away     2.0             True
# 309966         57096              RB  away     2.0             True
# 309968         22608              RW  away     2.0             True
# 309969         57096              RB  away     2.0             True
# 309971         62646              LW  home     2.0             True
# 309973         68743             DMF  away     2.0             True
# 309974         68681              LB  away     2.0             True
# 309981         22457              LW  away     2.0             True
# 309990         22608              RW  away     2.0             True
# 310005         68661            RCMF  home     2.0             True
# 310006         68719             RCB  home     2.0             True
# 310007         63552              GK  home     2.0             True
# 310008         22628             LCB  home     2.0             True
# 310009         63552              GK  home     2.0             True
# 310016         68743             DMF  away     2.0             True
# 310018         62411            LCMF  away     2.0             True
# 310019         22457              LW  away     2.0             True
# 310020         68734              CF  away     2.0             True
# 310022         22457              LW  away     2.0             True
# 310023         68743             DMF  away     2.0             True
# 310024         57096              RB  away     2.0             True
# 310025         22608              RW  away     2.0             True
# 310026         62505            RCMF  away     2.0             True
# 310036         68681              LB  away     2.0             True
# 310040         63765            RCMF  home     2.0             True
# 310048         68743             DMF  away     2.0             True
# 310091         22735              RW  home     2.0             True
# 310104         63765            RCMF  home     2.0             True
